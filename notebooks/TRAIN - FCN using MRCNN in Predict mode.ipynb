# %% [markdown]
# # Mask R-CNN - Train FCN using MRCNN in Predict Mode

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os, sys, math, io, time, gc, argparse, platform, pprint
import numpy as np
import tensorflow as tf
import keras
import keras.backend as KB
sys.path.append('../')
import mrcnn.model_mrcnn  as mrcnn_modellib
import mrcnn.model_fcn    as fcn_modellib
import mrcnn.visualize    as visualize
import mrcnn.new_shapes   as shapes
from datetime import datetime   
from mrcnn.utils        import command_line_parser, Paths
from mrcnn.config       import Config
from mrcnn.dataset      import Dataset 
from mrcnn.utils        import log, stack_tensors, stack_tensors_3d, write_stdout
from mrcnn.datagen      import data_generator, load_image_gt
from mrcnn.callbacks    import get_layer_output_1,get_layer_output_2
from mrcnn.coco         import CocoDataset, CocoConfig, CocoInferenceConfig, evaluate_coco, build_coco_results
from mrcnn.prep_notebook import mrcnn_coco_train, prep_coco_dataset

pp = pprint.PrettyPrinter(indent=2, width=100)
np.set_printoptions(linewidth=100,precision=4,threshold=1000, suppress = True)
start_time = datetime.now().strftime("%m-%d-%Y @ %H:%M:%S")
print()
print('--> Execution started at:', start_time)
print("    Tensorflow Version: {}   Keras Version : {} ".format(tf.__version__,keras.__version__))
# Out:
# <style>.container { width:95% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# --> Execution started at: 10-23-2018 @ 18:10:42
#     Tensorflow Version: 1.8.0   Keras Version : 2.2.0

# %% [markdown]
# ####  Pass input parameters to argparse

# %%
# args = parser.parse_args("--epochs 100 --steps_in_epoch 128  --last_epoch 1264 --batch_size 8  --lr 0.5               --logs_dir train_fcn_adagrad --model /home/kbardool/models/train_mrcnn/shapes20180621T1554/mask_rcnn_shapes_1119.h5 --fcn_model init".split())
# input_parms = "--epochs 100 --steps_in_epoch 100  --last_epoch 1264 --batch_size 25 --lr 0.8 --val_steps 5 --logs_dir train_fcn_adagrad --model /home/kbardool/models/train_mrcnn/shapes20180621T1554/mask_rcnn_shapes_1119.h5 --fcn_model /home/kbardool/models/train_fcn_adagrad/shapes20180709T1732/fcn_shapes_1167.h5"
# input_parms +=" --model     /home/kbardool/models/train_mrcnn/shapes20180621T1554/mask_rcnn_shapes_1119.h5 "
##------------------------------------------------------------------------------------
## Parse command line arguments
##------------------------------------------------------------------------------------
parser = command_line_parser()
input_parms = "--epochs 1 --steps_in_epoch 10  --last_epoch 0 --batch_size 2 --lr 0.001 --val_steps 4 " 
input_parms +="--mrcnn_logs_dir train_mrcnn_coco "
input_parms +="--fcn_logs_dir train_fcn_coco "
input_parms +="--model last "
input_parms +="--fcn_model vgg16 "
input_parms +="--opt adagrad"
# input_parms +="--fcn_model /home/kbardool/models/train_fcn_adagrad/shapes20180709T1732/fcn_shapes_1167.h5"
print(input_parms)

args = parser.parse_args(input_parms.split())
# args = parser.parse_args()
# Out:
# --epochs 1 --steps_in_epoch 10  --last_epoch 0 --batch_size 2 --lr 0.001 --val_steps 4 --mrcnn_logs_dir train_mrcnn_coco --fcn_logs_dir train_fcn_coco --model last --fcn_model vgg16 --opt adagrad

# %%
##----------------------------------------------------------------------------------------------
## if debug is true set stdout destination to stringIO
##----------------------------------------------------------------------------------------------            
# debug = False
args.sysout = args.sysout.upper()
if args.sysout == 'FILE':
    sys.stdout = io.StringIO()

# print("    Dataset            : ", args.dataset)
# print("    Logs               : ", args.logs)
# print("    Limit              : ", args.limit)
print("    MRCNN Model        : ", args.model)
print("    FCN Model          : ", args.fcn_model)
print("    MRCNN Log Dir      : ", args.mrcnn_logs_dir)
print("    FCN Log Dir        : ", args.fcn_logs_dir)
print("    Last Epoch         : ", args.last_epoch)
print("    Epochs to run      : ", args.epochs)
print("    Steps in each epoch: ", args.steps_in_epoch)
print("    Validation steps   : ", args.val_steps)
print("    Batch Size         : ", args.batch_size)
print("    Optimizer          : ", args.opt.upper())
# print("    OS Platform        : ", syst)
# Out:
#     MRCNN Model        :  last
#     FCN Model          :  vgg16
#     MRCNN Log Dir      :  train_mrcnn_coco
#     FCN Log Dir        :  train_fcn_coco
#     Last Epoch         :  0
#     Epochs to run      :  1
#     Steps in each epoch:  10
#     Validation steps   :  4
#     Batch Size         :  2
#     Optimizer          :  ADAGRAD

# %%
##------------------------------------------------------------------------------------
## setup project directories
##   ROOT_DIR         : Root directory of the project 
##   MODEL_DIR        : Directory to save logs and trained model
##   COCO_MODEL_PATH  : Path to COCO trained weights
##---------------------------------------------------------------------------------
paths = Paths()
paths.display()
# Out:
# >>> Initialize Paths
#  windows  Windows
#
# Paths:
# -------------------------
# COCO_DATASET_PATH              F:\MLDatasets\coco2014
# COCO_MODEL_PATH                F:\PretrainedModels\mask_rcnn_coco.h5
# DIR_DATASET                    F:\MLDatasets
# DIR_PRETRAINED                 F:\PretrainedModels
# DIR_ROOT                       F:\
# DIR_TRAINING                   F:\models
# FCN_TRAINING_PATH              F:\models\train_fcn_coco
# FCN_VGG16_MODEL_PATH           F:\PretrainedModels\fcn_vgg16_weights_tf_dim_ordering_tf_kernels.h5
# RESNET_MODEL_PATH              F:\PretrainedModels\resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# TRAINING_PATH                  F:\models\train_mrcnn_coco
# VGG16_MODEL_PATH               F:\PretrainedModels\vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
##------------------------------------------------------------------------------------
## Build configuration object 
##------------------------------------------------------------------------------------                          
mrcnn_config                    = CocoConfig()
mrcnn_config.NAME               = 'mrcnn'              
mrcnn_config.TRAINING_PATH      = paths.TRAINING_PATH
mrcnn_config.COCO_DATASET_PATH  = paths.COCO_DATASET_PATH 
mrcnn_config.COCO_MODEL_PATH    = paths.COCO_MODEL_PATH   
mrcnn_config.RESNET_MODEL_PATH  = paths.RESNET_MODEL_PATH 
mrcnn_config.VGG16_MODEL_PATH   = paths.VGG16_MODEL_PATH  
mrcnn_config.COCO_CLASSES       = None 
mrcnn_config.DETECTION_PER_CLASS = 200
mrcnn_config.HEATMAP_SCALE_FACTOR = 4

mrcnn_config.BATCH_SIZE         = int(args.batch_size)                  # Batch size is 2 (# GPUs * images/GPU).
mrcnn_config.IMAGES_PER_GPU     = int(args.batch_size)                  # Must match BATCH_SIZE
mrcnn_config.STEPS_PER_EPOCH    = int(args.steps_in_epoch)
mrcnn_config.LEARNING_RATE      = float(args.lr)
mrcnn_config.EPOCHS_TO_RUN      = int(args.epochs)
mrcnn_config.FCN_INPUT_SHAPE    = mrcnn_config.IMAGE_SHAPE[0:2]
mrcnn_config.LAST_EPOCH_RAN     = int(args.last_epoch)
mrcnn_config.WEIGHT_DECAY       = 2.0e-4
mrcnn_config.VALIDATION_STEPS   = int(args.val_steps)
mrcnn_config.REDUCE_LR_FACTOR   = 0.5
mrcnn_config.REDUCE_LR_COOLDOWN = 30
mrcnn_config.REDUCE_LR_PATIENCE = 40
mrcnn_config.EARLY_STOP_PATIENCE= 80
mrcnn_config.EARLY_STOP_MIN_DELTA = 1.0e-4
mrcnn_config.MIN_LR             = 1.0e-10
mrcnn_config.NEW_LOG_FOLDER     = False
mrcnn_config.OPTIMIZER          = args.opt.upper()
mrcnn_config.display()
# Out:
# Configuration Parameters:
# -------------------------
# BACKBONE_SHAPES                [[256 256]
#  [128 128]
#  [ 64  64]
#  [ 32  32]
#  [ 16  16]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COCO_CLASSES                   None
# COCO_DATASET_PATH              F:\MLDatasets\coco2014
# COCO_MODEL_PATH                F:\PretrainedModels\mask_rcnn_coco.h5
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# DETECTION_PER_CLASS            200
# EARLY_STOP_MIN_DELTA           0.0001
# EARLY_STOP_PATIENCE            80
# EPOCHS_TO_RUN                  1
# FCN_INPUT_SHAPE                [1024 1024]
# GPU_COUNT                      1
# HEATMAP_SCALE_FACTOR           4
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  1024
# IMAGE_MIN_DIM                  800
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [1024 1024    3]
# LAST_EPOCH_RAN                 0
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# MIN_LR                         1e-10
# NAME                           mrcnn
# NEW_LOG_FOLDER                 False
# NUM_CLASSES                    81
# OPTIMIZER                      ADAGRAD
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# REDUCE_LR_COOLDOWN             30
# REDUCE_LR_FACTOR               0.5
# REDUCE_LR_PATIENCE             40
# RESNET_MODEL_PATH              F:\PretrainedModels\resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# ROI_POSITIVE_RATIO             0.33
# ROI_PROPOSAL_AREA_THRESHOLD    0
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                10
# TRAINING_PATH                  F:\models\train_mrcnn_coco
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               4
# VGG16_MODEL_PATH               F:\PretrainedModels\vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# WEIGHT_DECAY                   0.0002

# %%
##------------------------------------------------------------------------------------
## Build Mask RCNN Model in TRAINFCN mode
##------------------------------------------------------------------------------------
mrcnn_model,mrcnn_config = mrcnn_coco_train(mode = 'trainfcn', mrcnn_config = mrcnn_config)
# Out:
# >>> Initialize ModelBase model
#    Mode      :  trainfcn
#    Model dir :  F:\models\train_mrcnn_coco
# >>> ModelBase initialiation complete
# >>> ---Initialize MRCNN model, mode:  trainfcn
#
# ----------------------------
# >>> Resnet Graph
# ----------------------------
#      Input_image shape : (?, 1024, 1024, 3)
#      After ZeroPadding2D  : (?, 1030, 1030, 3) (?, 1030, 1030, 3)
#      After Conv2D padding : (?, 512, 512, 64) (?, 512, 512, 64)
#      After BatchNorm      : (?, 512, 512, 64) (?, 512, 512, 64)
#      C1 Shape: (?, 256, 256, 64) (?, 256, 256, 64)
#      C2 Shape:  (?, 256, 256, 256) (?, 256, 256, 256)
#      C3 Shape:  (?, 128, 128, 512) (?, 128, 128, 512)
#      C4 Shape:  (?, 64, 64, 1024) (?, 64, 64, 1024)
#      C5 Shape:  (?, 32, 32, 2048) (?, 32, 32, 2048)
#
# >>> Feature Pyramid Network (FPN) Graph
#      FPN P2 shape : (None, 256, 256, 256)
#      FPN P3 shape : (None, 128, 128, 256)
#      FPN P4 shape : (None, 64, 64, 256)
#      FPN P5 shape : (None, 32, 32, 256)
#      FPN P6 shape : (None, 16, 16, 256)
#
# >>> RPN Layer
#      Input_feature_map shape : (?, ?, ?, 256)
#      anchors_per_location    : 3
#      depth                   : 256
#      Input_feature_map shape : (?, ?, ?, 256)
#      anchors_per_location    : 3
#      anchor_stride           : 1
#      append Tensor("fpn_p2/BiasAdd:0", shape=(?, 256, 256, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p3/BiasAdd:0", shape=(?, 128, 128, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p4/BiasAdd:0", shape=(?, 64, 64, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p5/BiasAdd:0", shape=(?, 32, 32, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p6/MaxPool:0", shape=(?, 16, 16, 256), dtype=float32) to layer_outputs
#
# >>> RPN Outputs  <class 'list'>
#       rpn_class_logits/rpn_class_logits:0
#       rpn_class/rpn_class:0
#       rpn_bbox/rpn_bbox:0
#
# >>> Proposal Layer - generate  2000  proposals
#     Init complete. Size of anchors:  (261888, 4)
#      Scores :  (2, 6000)
#      Deltas :  (2, 6000, 4)
#      Anchors:  (2, 6000, 4)
#      Boxes shape / type after processing:
#      Output: Prposals shape :  (2, ?, ?) (2, None, None)
#
# >>> Detection Target Layer (Training Mode)
#     Detection Target Layer : call()  <class 'list'> 3
#      proposals.shape    : (2, ?, ?) (2, ?, ?) (None, 2000, 4)
#      gt_class_ids.shape : (?, ?) (?, ?) (None, None)
#      gt_bboxes.shape    : (?, ?, 4) (?, ?, 4) (None, None, 4)
#
#     Detection Target Layer : return  <class 'list'> 4
#      output 0  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 1  shape (2, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 2  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 3  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#
# >>> FPN Classifier Graph
#      INPUT: rois shape          : (2, ?, ?)
#      INPUT: No of feature_maps  : 4
#         feature_maps shape  : (?, 256, 256, 256)
#         feature_maps shape  : (?, 128, 128, 256)
#         feature_maps shape  : (?, 64, 64, 256)
#         feature_maps shape  : (?, 32, 32, 256)
#      INPUT: image_shape         : [1024 1024    3]
#      INPUT: pool_size           : 7
#      INPUT: num_classes         : 81
#    > PyramidRoI Alignment Layer Call()  5
#      boxes.shape    : (None, 200, 4)
#      roi_align_classifier output shape is :  (1, ?, 7, 7, 256) (1, ?, 7, 7, 256)
#      mrcnn_class_conv1    output shape is :  (?, 200, 1, 1, 1024)
#      mrcnn_class_bn1      output shape is :  (?, 200, 1, 1, 1024)
#      mrcnn_class_relu1    output shape is :  (?, 200, 1, 1, 1024)
#      mrcnn_class_conv2 output shape is :  (?, 200, 1, 1, 1024)
#      mrcnn_class_bn2      output shape is :  (?, 200, 1, 1, 1024)
#      mrcnn_class_relu2    output shape is :  (?, 200, 1, 1, 1024)
#      pool_squeeze(Shared) output shape is :  (?, 200, 1024)
#      mrcnn_class_logits   output shape is :  (?, 200, 81)
#      mrcnn_class_probs    output shape is :  (?, 200, 81)
#      mrcnn_bbox_fc        output shape is :  (?, 200, 324)
#      mrcnn_bbox_fc        reshaped output :  (?, 200, 324)
#      mrcnn_bbox           output shape is :  (?, 200, 81, 4)
# --------------------------------
# >>>  CHM Layer
# --------------------------------
#   > CHMLayer Call()  3
#     mrcnn_class.shape    : (?, 200, 81) (None, 200, 81)
#     mrcnn_bbox.shape     : (?, 200, 81, 4) (None, 200, 81, 4)
#     output_rois.shape    : (2, ?, ?) (None, 200, 4)
#
#   > build_predictions()
#     num_rois               :  200
#     norm_input_rois.shape  :  <class 'tensorflow.python.framework.ops.Tensor'> (None, 200, 4)
#     scale.shape            :  <class 'tensorflow.python.framework.ops.Tensor'> (4,) (4,)
#     dup_scale.shape        :  <class 'tensorflow.python.framework.ops.Tensor'> (2, 200, 4) (2, 200, 4)
#
#     mrcnn_class shape      :  (None, 200, 81)
#     mrcnn_bbox.shape       :  (None, 200, 81, 4) (?, 200, 81, 4)
#     config image shape     :  [1024 1024    3] h: 1024 w: 1024
#     refined rois clipped   :  (2, 200, 4)
#     input_rois.shape       :  (2, 200, 4) (2, 200, 4)
#     refined_rois.shape     :  (2, 200, 4) (2, 200, 4)
#     shape of sequence      :  (2, 200, 1)
#     pred_array             :  (2, 200, 7)
#     scatter_ind            :  <class 'tensorflow.python.framework.ops.Tensor'> shape (2, 200, 3)
#     pred_scatter           :  (2, 81, 200, 7)
#     - Add normalized score --
#
#     normalizer             :  (2, 81, 1)
#     norm_score             :  (2, 81, 200, 1)
#     pred_scatter           :  (2, 81, 200, 8)
#     sort_inds              :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     class_grid             :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     batch_grid             :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     roi_grid shape         :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     roi_grid_exp           :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200, 1)
#     gather_inds            :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200, 3)
#     pred_tensor            :  (2, 81, 200, 8)
#
#
#   > build_heatmap() for  ['pred_heatmap']
#     in_tensor shape        :  (2, 81, 200, 8)
#     num bboxes per class   :  200
#     heatmap scale        :  4 Dimensions:  w: 256  h: 256
#     pt2_sum shape  :  (2, 81, 200)
#     pt2_ind shape  :  (?, 3)
#     pt2_dense shape:  (?, 8)
#     X/Y shapes : (256, 256) (256, 256)
#     Ones:     (?, 1, 1)
#     ones_exp * X (?, 1, 1) * (256, 256) =  (?, 256, 256)
#     ones_exp * Y (?, 1, 1) * (256, 256) =  (?, 256, 256)
#     pos_grid before transpse :  (?, 256, 256, 2)
#     pos_grid after transpose :  (256, 256, ?, 2)
#     >> input to MVN.PROB: pos_grid (meshgrid) shape:  (256, 256, ?, 2)
#      Prob_grid shape from mvn.probe:  (256, 256, ?)
#      Prob_grid shape after tanspose:  (?, 256, 256)
#     << output probabilities shape  :  (?, 256, 256)
#
#     normalization ------------------------------------------------------
#     normalizer     :  (?, 1, 1)
#     prob_grid_norm_scaled :  (?, 256, 256)
#
#     Scatter out the probability distributions based on class --------------
#     pt2_ind shape   :  (?, 3)
#     prob_grid shape :  (?, 256, 256)
#     gauss_scatt     :  (2, 81, 200, 256, 256)
#
#     Reduce sum based on class ---------------------------------------------
#     gaussian_heatmap :  (2, 81, 256, 256) Keras tensor  False
#
#     normalization ------------------------------------------------------
#     normalizer shape :  (2, 81, 1, 1)
#     gauss norm       :  (2, 81, 256, 256)  Keras tensor  False
#     gauss_heatmap_norm :  (2, 256, 256, 81)  Keras tensor  False
#     scores_scattered shape :  (2, 81, 200, 3)
#     gauss_scores           :  (2, 81, 200, 11)  Name:    cntxt_layer/pred_heatmap_scores:0
#     gauss_scores  (FINAL)  :  (2, 81, 200, 11)  Keras tensor  False
#     complete
#
#     pred_refined_heatmap        :  (2, 256, 256, 81) Keras tensor  False
#     pred_refnined_heatmap_scores:  (2, 81, 200, 11) Keras tensor  False
#     complete
#
# -----------------------------------------
# >>>  CHM Layer (Ground Truth Generation)
# -----------------------------------------
#   > CHMLayerTgt Call()  2
#     tgt_class_ids.shape  : (2, ?) (None, 200)
#     tgt_bboxes.shape     : (2, ?, ?) (None, 200, 4)
#
#
#   > BUILD_GROUND TRUTH_TF()
#     num_bboxes             :  200 (building  gt_tensor )
#     gt_class_ids shape     :  (2, ?)    (None, 200)
#     norm_gt_bboxes.shape   :  (2, ?, ?)    (None, 200, 4)
#     gt_bboxes.shape        :  (2, 200, 4)    (2, 200, 4)
#     gt_classes_exp         :  (2, ?, 1)
#     gt_scores_exp          :  (2, ?, 1)
#     gt_array shape         :  (2, 200, 8) (2, 200, 8)
#     scatter_ind shape      :  (2, 200, 3) (2, 200, 3)
#     tf.shape(gt_array)[-1] :  8 (2, 200, 8)
#     gt_scatter shape       :  (2, 81, 200, 8) (2, 81, 200, 8)
#     sort_inds              :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     class_grid             :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     batch_grid             :  <class 'tensorflow.python.framework.ops.Tensor'>  shape  (2, 81, 200)
#     gather_inds            :  (2, 81, 200, 3)
#     gt_tensor.shape        :  (2, 81, 200, 8) (2, 81, 200, 8)
#
#
#   > build_heatmap() for  ['gt_heatmap']
#     in_tensor shape        :  (2, 81, 200, 8)
#     num bboxes per class   :  200
#     heatmap scale        :  4 Dimensions:  w: 256  h: 256
#     pt2_sum shape  :  (2, 81, 200)
#     pt2_ind shape  :  (?, 3)
#     pt2_dense shape:  (?, 8)
#      Prob_grid shape :  (?, 256, 256)
#     prob_grid_clipped      :  (?, 256, 256)
#     scores_scattered shape :  (2, 81, 200, 3)
#     gauss_scores           :  (2, 81, 200, 11)  Name:    cntxt_layer_gt/gt_heatmap_scores:0
#     gauss_scores  (FINAL)  :  (2, 81, 200, 11)  Keras tensor  False
#
#     Scatter out the probability distributions based on class --------------
#     pt2_ind shape   :  (?, 3)
#     prob_grid shape :  (?, 256, 256)
#     gauss_scatt     :  (2, 81, 200, 256, 256)
#
#     Reduce MAX based on class ---------------------------------------------
#     gaussian_heatmap :  (2, 81, 256, 256) Keras tensor  False
#     gauss_heatmap :  (2, 256, 256, 81)  Keras tensor  False
#
#     gt_heatmap                  :  (2, 256, 256, 81) Keras tensor  False
#     gt_heatmap_scores           :  (2, 81, 200, 11) Keras tensor  False
#     complete
# <<<  shape of pred_heatmap   :  (2, 256, 256, 81)  Keras tensor  True
# <<<  shape of gt_heatmap     :  (2, 256, 256, 81)  Keras tensor  True
#
# >>> Build MaskRCNN build complete. mode:  trainfcn
# >>> MaskRCNN initialiation complete. Mode:  trainfcn
#
#
#  Inputs:
#  -------
#  index:  0    input name : input_image:0                              Type: float32           Shape: (?, 1024, 1024, 3)
#  index:  1    input name : input_image_meta:0                         Type: float32           Shape: (?, ?)
#  index:  2    input name : input_rpn_match:0                          Type: int32             Shape: (?, ?, 1)
#  index:  3    input name : input_rpn_bbox:0                           Type: float32           Shape: (?, ?, 4)
#  index:  4    input name : input_gt_class_ids:0                       Type: int32             Shape: (?, ?)
#  index:  5    input name : input_gt_boxes:0                           Type: float32           Shape: (?, ?, 4)
#
#
#  Outputs:
#  --------
#  layer:  0    output name: cntxt_layer/pred_heatmap_norm:0            Type: float32           Shape: (2, 256, 256, 81)
#  layer:  1    output name: cntxt_layer/pred_heatmap_scores:0          Type: float32           Shape: (2, 81, 200, 11)
#  layer:  2    output name: cntxt_layer_gt/gt_heatmap:0                Type: float32           Shape: (2, 256, 256, 81)
#  layer:  3    output name: cntxt_layer_gt/gt_heatmap_scores:0         Type: float32           Shape: (2, 81, 200, 11)
#  layer:  4    output name: cntxt_layer/pred_tensor:0                  Type: float32           Shape: (2, 81, 200, 8)
#  layer:  5    output name: cntxt_layer_gt/gt_tensor:0                 Type: float32           Shape: (2, 81, 200, 8)

# %%
##------------------------------------------------------------------------------------
## Build & Load Training and Validation datasets
##------------------------------------------------------------------------------------
dataset_train = prep_coco_dataset(["train",  "val35k"], mrcnn_config, generator = False)
dataset_val   = prep_coco_dataset(["minival"]         , mrcnn_config, generator = False)
# Out:
# Kevin loading annotations file F:\MLDatasets\coco2014\annotations/instances_train2014.json  into memory...
# Done (t=21.78s)
# creating index...
# index created!
#  image dir        :  F:\MLDatasets\coco2014\train2014
#  json_path_dir    :  F:\MLDatasets\coco2014\annotations/instances_train2014.json
#  number of images :  82081
# Kevin loading annotations file F:\MLDatasets\coco2014\annotations/instances_valminusminival2014.json  into memory...
# Done (t=10.02s)
# creating index...
# index created!
#  image dir        :  F:\MLDatasets\coco2014\val2014
#  json_path_dir    :  F:\MLDatasets\coco2014\annotations/instances_valminusminival2014.json
#  number of images :  35185
# Kevin loading annotations file F:\MLDatasets\coco2014\annotations/instances_minival2014.json  into memory...
# Done (t=4.94s)
# creating index...
# index created!
#  image dir        :  F:\MLDatasets\coco2014\val2014
#  json_path_dir    :  F:\MLDatasets\coco2014\annotations/instances_minival2014.json
#  number of images :  4952

# %%
##------------------------------------------------------------------------------------
## Load Mask RCNN Model Weight file
##------------------------------------------------------------------------------------
# exclude_list = ["mrcnn_class_logits"]
#load_model(model, init_with = args.model)   
exclude_list = []
mrcnn_model.load_model_weights(init_with = args.model, exclude = exclude_list)
# Out:
# -----------------------------------------------
#  Load Model with init parm: [ last ]
#  Exclude layers:
# -----------------------------------------------
#  ---> last
# >>> find_last checkpoint in :  F:\models\train_mrcnn_coco
#  Key : > mrcnn <
#  Dir names:  ['mrcnn20181011T1100', 'mrcnn20181022T1128']
#  Folder:  F:\models\train_mrcnn_coco\mrcnn20181022T1128  Checkpoints:  []
#  Folder:  F:\models\train_mrcnn_coco\mrcnn20181011T1100  Checkpoints:  ['mrcnn_0103.h5']
#     find_last():   dir_name: F:\models\train_mrcnn_coco\mrcnn20181011T1100
#     find_last(): checkpoint: F:\models\train_mrcnn_coco\mrcnn20181011T1100\mrcnn_0103.h5
#    Last file is : F:\models\train_mrcnn_coco\mrcnn20181011T1100\mrcnn_0103.h5
# >>> find_last checkpoint in :  F:\models\train_mrcnn_coco
#  Key : > mrcnn <
#  Dir names:  ['mrcnn20181011T1100', 'mrcnn20181022T1128']
#  Folder:  F:\models\train_mrcnn_coco\mrcnn20181022T1128  Checkpoints:  []
#  Folder:  F:\models\train_mrcnn_coco\mrcnn20181011T1100  Checkpoints:  ['mrcnn_0103.h5']
#     find_last():   dir_name: F:\models\train_mrcnn_coco\mrcnn20181011T1100
#     find_last(): checkpoint: F:\models\train_mrcnn_coco\mrcnn20181011T1100\mrcnn_0103.h5
# >>> load_weights() from : F:\models\train_mrcnn_coco\mrcnn20181011T1100\mrcnn_0103.h5
# =============================================================
#  List Model layers and matching hd5 layers, if present :
# =============================================================
#     0  input_image...................  1
#     1  zero_padding2d_1..............  1
#     2  conv1.........................  1
#     3  bn_conv1......................  1
#     4  activation_1..................  1
#     5  max_pooling2d_1...............  1
#     6  res2a_branch2a................  1
#     7  bn2a_branch2a.................  1
#     8  activation_2..................  1
#     9  res2a_branch2b................  1
#    10  bn2a_branch2b.................  1
#    11  activation_3..................  1
#    12  res2a_branch2c................  1
#    13  res2a_branch1.................  1
#    14  bn2a_branch2c.................  1
#    15  bn2a_branch1..................  1
#    16  add_1.........................  1
#    17  res2a_out.....................  1
#    18  res2b_branch2a................  1
#    19  bn2b_branch2a.................  1
#    20  activation_4..................  1
#    21  res2b_branch2b................  1
#    22  bn2b_branch2b.................  1
#    23  activation_5..................  1
#    24  res2b_branch2c................  1
#    25  bn2b_branch2c.................  1
#    26  add_2.........................  1
#    27  res2b_out.....................  1
#    28  res2c_branch2a................  1
#    29  bn2c_branch2a.................  1
#    30  activation_6..................  1
#    31  res2c_branch2b................  1
#    32  bn2c_branch2b.................  1
#    33  activation_7..................  1
#    34  res2c_branch2c................  1
#    35  bn2c_branch2c.................  1
#    36  add_3.........................  1
#    37  res2c_out.....................  1
#    38  res3a_branch2a................  1
#    39  bn3a_branch2a.................  1
#    40  activation_8..................  1
#    41  res3a_branch2b................  1
#    42  bn3a_branch2b.................  1
#    43  activation_9..................  1
#    44  res3a_branch2c................  1
#    45  res3a_branch1.................  1
#    46  bn3a_branch2c.................  1
#    47  bn3a_branch1..................  1
#    48  add_4.........................  1
#    49  res3a_out.....................  1
#    50  res3b_branch2a................  1
#    51  bn3b_branch2a.................  1
#    52  activation_10.................  1
#    53  res3b_branch2b................  1
#    54  bn3b_branch2b.................  1
#    55  activation_11.................  1
#    56  res3b_branch2c................  1
#    57  bn3b_branch2c.................  1
#    58  add_5.........................  1
#    59  res3b_out.....................  1
#    60  res3c_branch2a................  1
#    61  bn3c_branch2a.................  1
#    62  activation_12.................  1
#    63  res3c_branch2b................  1
#    64  bn3c_branch2b.................  1
#    65  activation_13.................  1
#    66  res3c_branch2c................  1
#    67  bn3c_branch2c.................  1
#    68  add_6.........................  1
#    69  res3c_out.....................  1
#    70  res3d_branch2a................  1
#    71  bn3d_branch2a.................  1
#    72  activation_14.................  1
#    73  res3d_branch2b................  1
#    74  bn3d_branch2b.................  1
#    75  activation_15.................  1
#    76  res3d_branch2c................  1
#    77  bn3d_branch2c.................  1
#    78  add_7.........................  1
#    79  res3d_out.....................  1
#    80  res4a_branch2a................  1
#    81  bn4a_branch2a.................  1
#    82  activation_16.................  1
#    83  res4a_branch2b................  1
#    84  bn4a_branch2b.................  1
#    85  activation_17.................  1
#    86  res4a_branch2c................  1
#    87  res4a_branch1.................  1
#    88  bn4a_branch2c.................  1
#    89  bn4a_branch1..................  1
#    90  add_8.........................  1
#    91  res4a_out.....................  1
#    92  res4b_branch2a................  1
#    93  bn4b_branch2a.................  1
#    94  activation_18.................  1
#    95  res4b_branch2b................  1
#    96  bn4b_branch2b.................  1
#    97  activation_19.................  1
#    98  res4b_branch2c................  1
#    99  bn4b_branch2c.................  1
#   100  add_9.........................  1
#   101  res4b_out.....................  1
#   102  res4c_branch2a................  1
#   103  bn4c_branch2a.................  1
#   104  activation_20.................  1
#   105  res4c_branch2b................  1
#   106  bn4c_branch2b.................  1
#   107  activation_21.................  1
#   108  res4c_branch2c................  1
#   109  bn4c_branch2c.................  1
#   110  add_10........................  1
#   111  res4c_out.....................  1
#   112  res4d_branch2a................  1
#   113  bn4d_branch2a.................  1
#   114  activation_22.................  1
#   115  res4d_branch2b................  1
#   116  bn4d_branch2b.................  1
#   117  activation_23.................  1
#   118  res4d_branch2c................  1
#   119  bn4d_branch2c.................  1
#   120  add_11........................  1
#   121  res4d_out.....................  1
#   122  res4e_branch2a................  1
#   123  bn4e_branch2a.................  1
#   124  activation_24.................  1
#   125  res4e_branch2b................  1
#   126  bn4e_branch2b.................  1
#   127  activation_25.................  1
#   128  res4e_branch2c................  1
#   129  bn4e_branch2c.................  1
#   130  add_12........................  1
#   131  res4e_out.....................  1
#   132  res4f_branch2a................  1
#   133  bn4f_branch2a.................  1
#   134  activation_26.................  1
#   135  res4f_branch2b................  1
#   136  bn4f_branch2b.................  1
#   137  activation_27.................  1
#   138  res4f_branch2c................  1
#   139  bn4f_branch2c.................  1
#   140  add_13........................  1
#   141  res4f_out.....................  1
#   142  res4g_branch2a................  1
#   143  bn4g_branch2a.................  1
#   144  activation_28.................  1
#   145  res4g_branch2b................  1
#   146  bn4g_branch2b.................  1
#   147  activation_29.................  1
#   148  res4g_branch2c................  1
#   149  bn4g_branch2c.................  1
#   150  add_14........................  1
#   151  res4g_out.....................  1
#   152  res4h_branch2a................  1
#   153  bn4h_branch2a.................  1
#   154  activation_30.................  1
#   155  res4h_branch2b................  1
#   156  bn4h_branch2b.................  1
#   157  activation_31.................  1
#   158  res4h_branch2c................  1
#   159  bn4h_branch2c.................  1
#   160  add_15........................  1
#   161  res4h_out.....................  1
#   162  res4i_branch2a................  1
#   163  bn4i_branch2a.................  1
#   164  activation_32.................  1
#   165  res4i_branch2b................  1
#   166  bn4i_branch2b.................  1
#   167  activation_33.................  1
#   168  res4i_branch2c................  1
#   169  bn4i_branch2c.................  1
#   170  add_16........................  1
#   171  res4i_out.....................  1
#   172  res4j_branch2a................  1
#   173  bn4j_branch2a.................  1
#   174  activation_34.................  1
#   175  res4j_branch2b................  1
#   176  bn4j_branch2b.................  1
#   177  activation_35.................  1
#   178  res4j_branch2c................  1
#   179  bn4j_branch2c.................  1
#   180  add_17........................  1
#   181  res4j_out.....................  1
#   182  res4k_branch2a................  1
#   183  bn4k_branch2a.................  1
#   184  activation_36.................  1
#   185  res4k_branch2b................  1
#   186  bn4k_branch2b.................  1
#   187  activation_37.................  1
#   188  res4k_branch2c................  1
#   189  bn4k_branch2c.................  1
#   190  add_18........................  1
#   191  res4k_out.....................  1
#   192  res4l_branch2a................  1
#   193  bn4l_branch2a.................  1
#   194  activation_38.................  1
#   195  res4l_branch2b................  1
#   196  bn4l_branch2b.................  1
#   197  activation_39.................  1
#   198  res4l_branch2c................  1
#   199  bn4l_branch2c.................  1
#   200  add_19........................  1
#   201  res4l_out.....................  1
#   202  res4m_branch2a................  1
#   203  bn4m_branch2a.................  1
#   204  activation_40.................  1
#   205  res4m_branch2b................  1
#   206  bn4m_branch2b.................  1
#   207  activation_41.................  1
#   208  res4m_branch2c................  1
#   209  bn4m_branch2c.................  1
#   210  add_20........................  1
#   211  res4m_out.....................  1
#   212  res4n_branch2a................  1
#   213  bn4n_branch2a.................  1
#   214  activation_42.................  1
#   215  res4n_branch2b................  1
#   216  bn4n_branch2b.................  1
#   217  activation_43.................  1
#   218  res4n_branch2c................  1
#   219  bn4n_branch2c.................  1
#   220  add_21........................  1
#   221  res4n_out.....................  1
#   222  res4o_branch2a................  1
#   223  bn4o_branch2a.................  1
#   224  activation_44.................  1
#   225  res4o_branch2b................  1
#   226  bn4o_branch2b.................  1
#   227  activation_45.................  1
#   228  res4o_branch2c................  1
#   229  bn4o_branch2c.................  1
#   230  add_22........................  1
#   231  res4o_out.....................  1
#   232  res4p_branch2a................  1
#   233  bn4p_branch2a.................  1
#   234  activation_46.................  1
#   235  res4p_branch2b................  1
#   236  bn4p_branch2b.................  1
#   237  activation_47.................  1
#   238  res4p_branch2c................  1
#   239  bn4p_branch2c.................  1
#   240  add_23........................  1
#   241  res4p_out.....................  1
#   242  res4q_branch2a................  1
#   243  bn4q_branch2a.................  1
#   244  activation_48.................  1
#   245  res4q_branch2b................  1
#   246  bn4q_branch2b.................  1
#   247  activation_49.................  1
#   248  res4q_branch2c................  1
#   249  bn4q_branch2c.................  1
#   250  add_24........................  1
#   251  res4q_out.....................  1
#   252  res4r_branch2a................  1
#   253  bn4r_branch2a.................  1
#   254  activation_50.................  1
#   255  res4r_branch2b................  1
#   256  bn4r_branch2b.................  1
#   257  activation_51.................  1
#   258  res4r_branch2c................  1
#   259  bn4r_branch2c.................  1
#   260  add_25........................  1
#   261  res4r_out.....................  1
#   262  res4s_branch2a................  1
#   263  bn4s_branch2a.................  1
#   264  activation_52.................  1
#   265  res4s_branch2b................  1
#   266  bn4s_branch2b.................  1
#   267  activation_53.................  1
#   268  res4s_branch2c................  1
#   269  bn4s_branch2c.................  1
#   270  add_26........................  1
#   271  res4s_out.....................  1
#   272  res4t_branch2a................  1
#   273  bn4t_branch2a.................  1
#   274  activation_54.................  1
#   275  res4t_branch2b................  1
#   276  bn4t_branch2b.................  1
#   277  activation_55.................  1
#   278  res4t_branch2c................  1
#   279  bn4t_branch2c.................  1
#   280  add_27........................  1
#   281  res4t_out.....................  1
#   282  res4u_branch2a................  1
#   283  bn4u_branch2a.................  1
#   284  activation_56.................  1
#   285  res4u_branch2b................  1
#   286  bn4u_branch2b.................  1
#   287  activation_57.................  1
#   288  res4u_branch2c................  1
#   289  bn4u_branch2c.................  1
#   290  add_28........................  1
#   291  res4u_out.....................  1
#   292  res4v_branch2a................  1
#   293  bn4v_branch2a.................  1
#   294  activation_58.................  1
#   295  res4v_branch2b................  1
#   296  bn4v_branch2b.................  1
#   297  activation_59.................  1
#   298  res4v_branch2c................  1
#   299  bn4v_branch2c.................  1
#   300  add_29........................  1
#   301  res4v_out.....................  1
#   302  res4w_branch2a................  1
#   303  bn4w_branch2a.................  1
#   304  activation_60.................  1
#   305  res4w_branch2b................  1
#   306  bn4w_branch2b.................  1
#   307  activation_61.................  1
#   308  res4w_branch2c................  1
#   309  bn4w_branch2c.................  1
#   310  add_30........................  1
#   311  res4w_out.....................  1
#   312  res5a_branch2a................  1
#   313  bn5a_branch2a.................  1
#   314  activation_62.................  1
#   315  res5a_branch2b................  1
#   316  bn5a_branch2b.................  1
#   317  activation_63.................  1
#   318  res5a_branch2c................  1
#   319  res5a_branch1.................  1
#   320  bn5a_branch2c.................  1
#   321  bn5a_branch1..................  1
#   322  add_31........................  1
#   323  res5a_out.....................  1
#   324  res5b_branch2a................  1
#   325  bn5b_branch2a.................  1
#   326  activation_64.................  1
#   327  res5b_branch2b................  1
#   328  bn5b_branch2b.................  1
#   329  activation_65.................  1
#   330  res5b_branch2c................  1
#   331  bn5b_branch2c.................  1
#   332  add_32........................  1
#   333  res5b_out.....................  1
#   334  res5c_branch2a................  1
#   335  bn5c_branch2a.................  1
#   336  activation_66.................  1
#   337  res5c_branch2b................  1
#   338  bn5c_branch2b.................  1
#   339  activation_67.................  1
#   340  res5c_branch2c................  1
#   341  bn5c_branch2c.................  1
#   342  add_33........................  1
#   343  res5c_out.....................  1
#   344  fpn_c5p5......................  1
#   345  fpn_p5upsampled...............  1
#   346  fpn_c4p4......................  1
#   347  fpn_p4add.....................  1
#   348  fpn_p4upsampled...............  1
#   349  fpn_c3p3......................  1
#   350  fpn_p3add.....................  1
#   351  fpn_p3upsampled...............  1
#   352  fpn_c2p2......................  1
#   353  fpn_p2add.....................  1
#   354  fpn_p5........................  1
#   355  fpn_p2........................  1
#   356  fpn_p3........................  1
#   357  fpn_p4........................  1
#   358  fpn_p6........................  1
#   359  rpn_model.....................  1
#   360  rpn_class.....................  1
#   361  rpn_bbox......................  1
#   362  input_gt_boxes................  1
#   363  ROI...........................  1
#   364  input_gt_class_ids............  1
#   365  input_normalized_gt_boxes.....  1
#   366  proposal_targets..............  1
#   367  roi_align_classifier..........  1
#   368  mrcnn_class_conv1.............  1
#   369  mrcnn_class_bn1...............  1
#   370  activation_68.................  1
#   371  mrcnn_class_conv2.............  1
#   372  mrcnn_class_bn2...............  1
#   373  activation_69.................  1
#   374  pool_squeeze..................  1
#   375  mrcnn_class_logits............  1
#   376  mrcnn_bbox_fc.................  1
#   377  mrcnn_class...................  0
#   378  mrcnn_bbox....................  1
#   379  cntxt_layer...................  0
#   380  cntxt_layer_gt................  0
# =============================================================
#  List hd5 layers and matching layers from Model, if present :
# =============================================================
#     0  input_image...................  input_image
#     1  zero_padding2d_1..............  zero_padding2d_1
#     2  conv1.........................  conv1
#     3  bn_conv1......................  bn_conv1
#     4  activation_1..................  activation_1
#     5  max_pooling2d_1...............  max_pooling2d_1
#     6  res2a_branch2a................  res2a_branch2a
#     7  bn2a_branch2a.................  bn2a_branch2a
#     8  activation_2..................  activation_2
#     9  res2a_branch2b................  res2a_branch2b
#    10  bn2a_branch2b.................  bn2a_branch2b
#    11  activation_3..................  activation_3
#    12  res2a_branch2c................  res2a_branch2c
#    13  res2a_branch1.................  res2a_branch1
#    14  bn2a_branch2c.................  bn2a_branch2c
#    15  bn2a_branch1..................  bn2a_branch1
#    16  add_1.........................  add_1
#    17  res2a_out.....................  res2a_out
#    18  res2b_branch2a................  res2b_branch2a
#    19  bn2b_branch2a.................  bn2b_branch2a
#    20  activation_4..................  activation_4
#    21  res2b_branch2b................  res2b_branch2b
#    22  bn2b_branch2b.................  bn2b_branch2b
#    23  activation_5..................  activation_5
#    24  res2b_branch2c................  res2b_branch2c
#    25  bn2b_branch2c.................  bn2b_branch2c
#    26  add_2.........................  add_2
#    27  res2b_out.....................  res2b_out
#    28  res2c_branch2a................  res2c_branch2a
#    29  bn2c_branch2a.................  bn2c_branch2a
#    30  activation_6..................  activation_6
#    31  res2c_branch2b................  res2c_branch2b
#    32  bn2c_branch2b.................  bn2c_branch2b
#    33  activation_7..................  activation_7
#    34  res2c_branch2c................  res2c_branch2c
#    35  bn2c_branch2c.................  bn2c_branch2c
#    36  add_3.........................  add_3
#    37  res2c_out.....................  res2c_out
#    38  res3a_branch2a................  res3a_branch2a
#    39  bn3a_branch2a.................  bn3a_branch2a
#    40  activation_8..................  activation_8
#    41  res3a_branch2b................  res3a_branch2b
#    42  bn3a_branch2b.................  bn3a_branch2b
#    43  activation_9..................  activation_9
#    44  res3a_branch2c................  res3a_branch2c
#    45  res3a_branch1.................  res3a_branch1
#    46  bn3a_branch2c.................  bn3a_branch2c
#    47  bn3a_branch1..................  bn3a_branch1
#    48  add_4.........................  add_4
#    49  res3a_out.....................  res3a_out
#    50  res3b_branch2a................  res3b_branch2a
#    51  bn3b_branch2a.................  bn3b_branch2a
#    52  activation_10.................  activation_10
#    53  res3b_branch2b................  res3b_branch2b
#    54  bn3b_branch2b.................  bn3b_branch2b
#    55  activation_11.................  activation_11
#    56  res3b_branch2c................  res3b_branch2c
#    57  bn3b_branch2c.................  bn3b_branch2c
#    58  add_5.........................  add_5
#    59  res3b_out.....................  res3b_out
#    60  res3c_branch2a................  res3c_branch2a
#    61  bn3c_branch2a.................  bn3c_branch2a
#    62  activation_12.................  activation_12
#    63  res3c_branch2b................  res3c_branch2b
#    64  bn3c_branch2b.................  bn3c_branch2b
#    65  activation_13.................  activation_13
#    66  res3c_branch2c................  res3c_branch2c
#    67  bn3c_branch2c.................  bn3c_branch2c
#    68  add_6.........................  add_6
#    69  res3c_out.....................  res3c_out
#    70  res3d_branch2a................  res3d_branch2a
#    71  bn3d_branch2a.................  bn3d_branch2a
#    72  activation_14.................  activation_14
#    73  res3d_branch2b................  res3d_branch2b
#    74  bn3d_branch2b.................  bn3d_branch2b
#    75  activation_15.................  activation_15
#    76  res3d_branch2c................  res3d_branch2c
#    77  bn3d_branch2c.................  bn3d_branch2c
#    78  add_7.........................  add_7
#    79  res3d_out.....................  res3d_out
#    80  res4a_branch2a................  res4a_branch2a
#    81  bn4a_branch2a.................  bn4a_branch2a
#    82  activation_16.................  activation_16
#    83  res4a_branch2b................  res4a_branch2b
#    84  bn4a_branch2b.................  bn4a_branch2b
#    85  activation_17.................  activation_17
#    86  res4a_branch2c................  res4a_branch2c
#    87  res4a_branch1.................  res4a_branch1
#    88  bn4a_branch2c.................  bn4a_branch2c
#    89  bn4a_branch1..................  bn4a_branch1
#    90  add_8.........................  add_8
#    91  res4a_out.....................  res4a_out
#    92  res4b_branch2a................  res4b_branch2a
#    93  bn4b_branch2a.................  bn4b_branch2a
#    94  activation_18.................  activation_18
#    95  res4b_branch2b................  res4b_branch2b
#    96  bn4b_branch2b.................  bn4b_branch2b
#    97  activation_19.................  activation_19
#    98  res4b_branch2c................  res4b_branch2c
#    99  bn4b_branch2c.................  bn4b_branch2c
#   100  add_9.........................  add_9
#   101  res4b_out.....................  res4b_out
#   102  res4c_branch2a................  res4c_branch2a
#   103  bn4c_branch2a.................  bn4c_branch2a
#   104  activation_20.................  activation_20
#   105  res4c_branch2b................  res4c_branch2b
#   106  bn4c_branch2b.................  bn4c_branch2b
#   107  activation_21.................  activation_21
#   108  res4c_branch2c................  res4c_branch2c
#   109  bn4c_branch2c.................  bn4c_branch2c
#   110  add_10........................  add_10
#   111  res4c_out.....................  res4c_out
#   112  res4d_branch2a................  res4d_branch2a
#   113  bn4d_branch2a.................  bn4d_branch2a
#   114  activation_22.................  activation_22
#   115  res4d_branch2b................  res4d_branch2b
#   116  bn4d_branch2b.................  bn4d_branch2b
#   117  activation_23.................  activation_23
#   118  res4d_branch2c................  res4d_branch2c
#   119  bn4d_branch2c.................  bn4d_branch2c
#   120  add_11........................  add_11
#   121  res4d_out.....................  res4d_out
#   122  res4e_branch2a................  res4e_branch2a
#   123  bn4e_branch2a.................  bn4e_branch2a
#   124  activation_24.................  activation_24
#   125  res4e_branch2b................  res4e_branch2b
#   126  bn4e_branch2b.................  bn4e_branch2b
#   127  activation_25.................  activation_25
#   128  res4e_branch2c................  res4e_branch2c
#   129  bn4e_branch2c.................  bn4e_branch2c
#   130  add_12........................  add_12
#   131  res4e_out.....................  res4e_out
#   132  res4f_branch2a................  res4f_branch2a
#   133  bn4f_branch2a.................  bn4f_branch2a
#   134  activation_26.................  activation_26
#   135  res4f_branch2b................  res4f_branch2b
#   136  bn4f_branch2b.................  bn4f_branch2b
#   137  activation_27.................  activation_27
#   138  res4f_branch2c................  res4f_branch2c
#   139  bn4f_branch2c.................  bn4f_branch2c
#   140  add_13........................  add_13
#   141  res4f_out.....................  res4f_out
#   142  res4g_branch2a................  res4g_branch2a
#   143  bn4g_branch2a.................  bn4g_branch2a
#   144  activation_28.................  activation_28
#   145  res4g_branch2b................  res4g_branch2b
#   146  bn4g_branch2b.................  bn4g_branch2b
#   147  activation_29.................  activation_29
#   148  res4g_branch2c................  res4g_branch2c
#   149  bn4g_branch2c.................  bn4g_branch2c
#   150  add_14........................  add_14
#   151  res4g_out.....................  res4g_out
#   152  res4h_branch2a................  res4h_branch2a
#   153  bn4h_branch2a.................  bn4h_branch2a
#   154  activation_30.................  activation_30
#   155  res4h_branch2b................  res4h_branch2b
#   156  bn4h_branch2b.................  bn4h_branch2b
#   157  activation_31.................  activation_31
#   158  res4h_branch2c................  res4h_branch2c
#   159  bn4h_branch2c.................  bn4h_branch2c
#   160  add_15........................  add_15
#   161  res4h_out.....................  res4h_out
#   162  res4i_branch2a................  res4i_branch2a
#   163  bn4i_branch2a.................  bn4i_branch2a
#   164  activation_32.................  activation_32
#   165  res4i_branch2b................  res4i_branch2b
#   166  bn4i_branch2b.................  bn4i_branch2b
#   167  activation_33.................  activation_33
#   168  res4i_branch2c................  res4i_branch2c
#   169  bn4i_branch2c.................  bn4i_branch2c
#   170  add_16........................  add_16
#   171  res4i_out.....................  res4i_out
#   172  res4j_branch2a................  res4j_branch2a
#   173  bn4j_branch2a.................  bn4j_branch2a
#   174  activation_34.................  activation_34
#   175  res4j_branch2b................  res4j_branch2b
#   176  bn4j_branch2b.................  bn4j_branch2b
#   177  activation_35.................  activation_35
#   178  res4j_branch2c................  res4j_branch2c
#   179  bn4j_branch2c.................  bn4j_branch2c
#   180  add_17........................  add_17
#   181  res4j_out.....................  res4j_out
#   182  res4k_branch2a................  res4k_branch2a
#   183  bn4k_branch2a.................  bn4k_branch2a
#   184  activation_36.................  activation_36
#   185  res4k_branch2b................  res4k_branch2b
#   186  bn4k_branch2b.................  bn4k_branch2b
#   187  activation_37.................  activation_37
#   188  res4k_branch2c................  res4k_branch2c
#   189  bn4k_branch2c.................  bn4k_branch2c
#   190  add_18........................  add_18
#   191  res4k_out.....................  res4k_out
#   192  res4l_branch2a................  res4l_branch2a
#   193  bn4l_branch2a.................  bn4l_branch2a
#   194  activation_38.................  activation_38
#   195  res4l_branch2b................  res4l_branch2b
#   196  bn4l_branch2b.................  bn4l_branch2b
#   197  activation_39.................  activation_39
#   198  res4l_branch2c................  res4l_branch2c
#   199  bn4l_branch2c.................  bn4l_branch2c
#   200  add_19........................  add_19
#   201  res4l_out.....................  res4l_out
#   202  res4m_branch2a................  res4m_branch2a
#   203  bn4m_branch2a.................  bn4m_branch2a
#   204  activation_40.................  activation_40
#   205  res4m_branch2b................  res4m_branch2b
#   206  bn4m_branch2b.................  bn4m_branch2b
#   207  activation_41.................  activation_41
#   208  res4m_branch2c................  res4m_branch2c
#   209  bn4m_branch2c.................  bn4m_branch2c
#   210  add_20........................  add_20
#   211  res4m_out.....................  res4m_out
#   212  res4n_branch2a................  res4n_branch2a
#   213  bn4n_branch2a.................  bn4n_branch2a
#   214  activation_42.................  activation_42
#   215  res4n_branch2b................  res4n_branch2b
#   216  bn4n_branch2b.................  bn4n_branch2b
#   217  activation_43.................  activation_43
#   218  res4n_branch2c................  res4n_branch2c
#   219  bn4n_branch2c.................  bn4n_branch2c
#   220  add_21........................  add_21
#   221  res4n_out.....................  res4n_out
#   222  res4o_branch2a................  res4o_branch2a
#   223  bn4o_branch2a.................  bn4o_branch2a
#   224  activation_44.................  activation_44
#   225  res4o_branch2b................  res4o_branch2b
#   226  bn4o_branch2b.................  bn4o_branch2b
#   227  activation_45.................  activation_45
#   228  res4o_branch2c................  res4o_branch2c
#   229  bn4o_branch2c.................  bn4o_branch2c
#   230  add_22........................  add_22
#   231  res4o_out.....................  res4o_out
#   232  res4p_branch2a................  res4p_branch2a
#   233  bn4p_branch2a.................  bn4p_branch2a
#   234  activation_46.................  activation_46
#   235  res4p_branch2b................  res4p_branch2b
#   236  bn4p_branch2b.................  bn4p_branch2b
#   237  activation_47.................  activation_47
#   238  res4p_branch2c................  res4p_branch2c
#   239  bn4p_branch2c.................  bn4p_branch2c
#   240  add_23........................  add_23
#   241  res4p_out.....................  res4p_out
#   242  res4q_branch2a................  res4q_branch2a
#   243  bn4q_branch2a.................  bn4q_branch2a
#   244  activation_48.................  activation_48
#   245  res4q_branch2b................  res4q_branch2b
#   246  bn4q_branch2b.................  bn4q_branch2b
#   247  activation_49.................  activation_49
#   248  res4q_branch2c................  res4q_branch2c
#   249  bn4q_branch2c.................  bn4q_branch2c
#   250  add_24........................  add_24
#   251  res4q_out.....................  res4q_out
#   252  res4r_branch2a................  res4r_branch2a
#   253  bn4r_branch2a.................  bn4r_branch2a
#   254  activation_50.................  activation_50
#   255  res4r_branch2b................  res4r_branch2b
#   256  bn4r_branch2b.................  bn4r_branch2b
#   257  activation_51.................  activation_51
#   258  res4r_branch2c................  res4r_branch2c
#   259  bn4r_branch2c.................  bn4r_branch2c
#   260  add_25........................  add_25
#   261  res4r_out.....................  res4r_out
#   262  res4s_branch2a................  res4s_branch2a
#   263  bn4s_branch2a.................  bn4s_branch2a
#   264  activation_52.................  activation_52
#   265  res4s_branch2b................  res4s_branch2b
#   266  bn4s_branch2b.................  bn4s_branch2b
#   267  activation_53.................  activation_53
#   268  res4s_branch2c................  res4s_branch2c
#   269  bn4s_branch2c.................  bn4s_branch2c
#   270  add_26........................  add_26
#   271  res4s_out.....................  res4s_out
#   272  res4t_branch2a................  res4t_branch2a
#   273  bn4t_branch2a.................  bn4t_branch2a
#   274  activation_54.................  activation_54
#   275  res4t_branch2b................  res4t_branch2b
#   276  bn4t_branch2b.................  bn4t_branch2b
#   277  activation_55.................  activation_55
#   278  res4t_branch2c................  res4t_branch2c
#   279  bn4t_branch2c.................  bn4t_branch2c
#   280  add_27........................  add_27
#   281  res4t_out.....................  res4t_out
#   282  res4u_branch2a................  res4u_branch2a
#   283  bn4u_branch2a.................  bn4u_branch2a
#   284  activation_56.................  activation_56
#   285  res4u_branch2b................  res4u_branch2b
#   286  bn4u_branch2b.................  bn4u_branch2b
#   287  activation_57.................  activation_57
#   288  res4u_branch2c................  res4u_branch2c
#   289  bn4u_branch2c.................  bn4u_branch2c
#   290  add_28........................  add_28
#   291  res4u_out.....................  res4u_out
#   292  res4v_branch2a................  res4v_branch2a
#   293  bn4v_branch2a.................  bn4v_branch2a
#   294  activation_58.................  activation_58
#   295  res4v_branch2b................  res4v_branch2b
#   296  bn4v_branch2b.................  bn4v_branch2b
#   297  activation_59.................  activation_59
#   298  res4v_branch2c................  res4v_branch2c
#   299  bn4v_branch2c.................  bn4v_branch2c
#   300  add_29........................  add_29
#   301  res4v_out.....................  res4v_out
#   302  res4w_branch2a................  res4w_branch2a
#   303  bn4w_branch2a.................  bn4w_branch2a
#   304  activation_60.................  activation_60
#   305  res4w_branch2b................  res4w_branch2b
#   306  bn4w_branch2b.................  bn4w_branch2b
#   307  activation_61.................  activation_61
#   308  res4w_branch2c................  res4w_branch2c
#   309  bn4w_branch2c.................  bn4w_branch2c
#   310  add_30........................  add_30
#   311  res4w_out.....................  res4w_out
#   312  res5a_branch2a................  res5a_branch2a
#   313  bn5a_branch2a.................  bn5a_branch2a
#   314  activation_62.................  activation_62
#   315  res5a_branch2b................  res5a_branch2b
#   316  bn5a_branch2b.................  bn5a_branch2b
#   317  activation_63.................  activation_63
#   318  res5a_branch2c................  res5a_branch2c
#   319  res5a_branch1.................  res5a_branch1
#   320  bn5a_branch2c.................  bn5a_branch2c
#   321  bn5a_branch1..................  bn5a_branch1
#   322  add_31........................  add_31
#   323  res5a_out.....................  res5a_out
#   324  res5b_branch2a................  res5b_branch2a
#   325  bn5b_branch2a.................  bn5b_branch2a
#   326  activation_64.................  activation_64
#   327  res5b_branch2b................  res5b_branch2b
#   328  bn5b_branch2b.................  bn5b_branch2b
#   329  activation_65.................  activation_65
#   330  res5b_branch2c................  res5b_branch2c
#   331  bn5b_branch2c.................  bn5b_branch2c
#   332  add_32........................  add_32
#   333  res5b_out.....................  res5b_out
#   334  res5c_branch2a................  res5c_branch2a
#   335  bn5c_branch2a.................  bn5c_branch2a
#   336  activation_66.................  activation_66
#   337  res5c_branch2b................  res5c_branch2b
#   338  bn5c_branch2b.................  bn5c_branch2b
#   339  activation_67.................  activation_67
#   340  res5c_branch2c................  res5c_branch2c
#   341  bn5c_branch2c.................  bn5c_branch2c
#   342  add_33........................  add_33
#   343  res5c_out.....................  res5c_out
#   344  fpn_c5p5......................  fpn_c5p5
#   345  fpn_p5upsampled...............  fpn_p5upsampled
#   346  fpn_c4p4......................  fpn_c4p4
#   347  fpn_p4add.....................  fpn_p4add
#   348  fpn_p4upsampled...............  fpn_p4upsampled
#   349  fpn_c3p3......................  fpn_c3p3
#   350  fpn_p3add.....................  fpn_p3add
#   351  fpn_p3upsampled...............  fpn_p3upsampled
#   352  fpn_c2p2......................  fpn_c2p2
#   353  fpn_p2add.....................  fpn_p2add
#   354  fpn_p5........................  fpn_p5
#   355  fpn_p2........................  fpn_p2
#   356  fpn_p3........................  fpn_p3
#   357  fpn_p4........................  fpn_p4
#   358  fpn_p6........................  fpn_p6
#   359  rpn_model.....................  rpn_model
#   360  rpn_bbox......................  rpn_bbox
#   361  rpn_class.....................  rpn_class
#   362  input_gt_boxes................  input_gt_boxes
#   363  ROI...........................  ROI
#   364  input_gt_class_ids............  input_gt_class_ids
#   365  input_normalized_gt_boxes.....  input_normalized_gt_boxes
#   366  proposal_targets..............  proposal_targets
#   367  roi_align_classifier..........  roi_align_classifier
#   368  mrcnn_class_conv1.............  mrcnn_class_conv1
#   369  mrcnn_class_bn1...............  mrcnn_class_bn1
#   370  activation_68.................  activation_68
#   371  mrcnn_class_conv2.............  mrcnn_class_conv2
#   372  mrcnn_class_bn2...............  mrcnn_class_bn2
#   373  activation_69.................  activation_69
#   374  pool_squeeze..................  pool_squeeze
#   375  input_image_meta..............  !!! NotFound !!!
#   376  mrcnn_bbox_fc.................  mrcnn_bbox_fc
#   377  input_rpn_match...............  !!! NotFound !!!
#   378  rpn_class_logits..............  !!! NotFound !!!
#   379  input_rpn_bbox................  !!! NotFound !!!
#   380  mrcnn_class_logits............  mrcnn_class_logits
#   381  lambda_3......................  !!! NotFound !!!
#   382  mrcnn_bbox....................  mrcnn_bbox
#   383  rpn_class_loss................  !!! NotFound !!!
#   384  rpn_bbox_loss.................  !!! NotFound !!!
#   385  mrcnn_class_loss..............  !!! NotFound !!!
#   386  mrcnn_bbox_loss...............  !!! NotFound !!!
#
#   0 input_image               Model Layer Name/Type : [('input_image', <keras.engine.input_layer.InputLayer object at 0x000000D1641B7DA0>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#   1 zero_padding2d_1          Model Layer Name/Type : [('zero_padding2d_1', <keras.layers.convolutional.ZeroPadding2D object at 0x000000D164219400>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#   2 conv1                     Model Layer Name/Type : [('conv1', <keras.layers.convolutional.Conv2D object at 0x000000D1642194A8>)]
#                               Weights     : ['conv1/kernel:0', 'conv1/bias:0']
#                                Symbolic Weights from Model
#                                 0 (7, 7, 3, 64)
#                                 1 (64,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (7, 7, 3, 64)   symb wgt shp: (7, 7, 3, 64)
#                                 0 conv1/kernel:0                       hdf5 Weights: (7, 7, 3, 64)  Symbolic Wghts: (7, 7, 3, 64)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 conv1/bias:0                         hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#   3 bn_conv1                  Model Layer Name/Type : [('bn_conv1', <mrcnn.batchnorm_layer.BatchNorm object at 0x000000D16441AD68>)]
#                               Weights     : ['bn_conv1/gamma:0', 'bn_conv1/beta:0', 'bn_conv1/moving_mean:0', 'bn_conv1/moving_variance:0']
#                                Symbolic Weights from Model
#                                 0 (64,)
#                                 1 (64,)
#                                 2 (64,)
#                                 3 (64,)
#                                len weight_values: 4   len symbolic_weights: 4
#                                i: 0  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 0 bn_conv1/gamma:0                     hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 bn_conv1/beta:0                      hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 2  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 2 bn_conv1/moving_mean:0               hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 3  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 3 bn_conv1/moving_variance:0           hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#   4 activation_1              Model Layer Name/Type : [('activation_1', <keras.layers.core.Activation object at 0x000000D16443E550>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#   5 max_pooling2d_1           Model Layer Name/Type : [('max_pooling2d_1', <keras.layers.pooling.MaxPooling2D object at 0x000000D16441AF98>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#   6 res2a_branch2a            Model Layer Name/Type : [('res2a_branch2a', <keras.layers.convolutional.Conv2D object at 0x000000D16443EBE0>)]
#                               Weights     : ['res2a_branch2a/kernel:0', 'res2a_branch2a/bias:0']
#                                Symbolic Weights from Model
#                                 0 (1, 1, 64, 64)
#                                 1 (64,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (1, 1, 64, 64)   symb wgt shp: (1, 1, 64, 64)
#                                 0 res2a_branch2a/kernel:0              hdf5 Weights: (1, 1, 64, 64)  Symbolic Wghts: (1, 1, 64, 64)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 res2a_branch2a/bias:0                hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#   7 bn2a_branch2a             Model Layer Name/Type : [('bn2a_branch2a', <mrcnn.batchnorm_layer.BatchNorm object at 0x000000D16443E8D0>)]
#                               Weights     : ['bn2a_branch2a/gamma:0', 'bn2a_branch2a/beta:0', 'bn2a_branch2a/moving_mean:0', 'bn2a_branch2a/moving_variance:0']
#                                Symbolic Weights from Model
#                                 0 (64,)
#                                 1 (64,)
#                                 2 (64,)
#                                 3 (64,)
#                                len weight_values: 4   len symbolic_weights: 4
#                                i: 0  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 0 bn2a_branch2a/gamma:0                hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 bn2a_branch2a/beta:0                 hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 2  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 2 bn2a_branch2a/moving_mean:0          hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 3  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 3 bn2a_branch2a/moving_variance:0      hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#   8 activation_2              Model Layer Name/Type : [('activation_2', <keras.layers.core.Activation object at 0x000000D16444ACF8>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#   9 res2a_branch2b            Model Layer Name/Type : [('res2a_branch2b', <keras.layers.convolutional.Conv2D object at 0x000000D16443E5F8>)]
#                               Weights     : ['res2a_branch2b/kernel:0', 'res2a_branch2b/bias:0']
#                                Symbolic Weights from Model
#                                 0 (3, 3, 64, 64)
#                                 1 (64,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (3, 3, 64, 64)   symb wgt shp: (3, 3, 64, 64)
#                                 0 res2a_branch2b/kernel:0              hdf5 Weights: (3, 3, 64, 64)  Symbolic Wghts: (3, 3, 64, 64)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 res2a_branch2b/bias:0                hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#  10 bn2a_branch2b             Model Layer Name/Type : [('bn2a_branch2b', <mrcnn.batchnorm_layer.BatchNorm object at 0x000000D16443EE10>)]
#                               Weights     : ['bn2a_branch2b/gamma:0', 'bn2a_branch2b/beta:0', 'bn2a_branch2b/moving_mean:0', 'bn2a_branch2b/moving_variance:0']
#                                Symbolic Weights from Model
#                                 0 (64,)
#                                 1 (64,)
#                                 2 (64,)
#                                 3 (64,)
#                                len weight_values: 4   len symbolic_weights: 4
#                                i: 0  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 0 bn2a_branch2b/gamma:0                hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 1  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 1 bn2a_branch2b/beta:0                 hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 2  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 2 bn2a_branch2b/moving_mean:0          hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#                                i: 3  hdf5 weight shape: (64,)   symb wgt shp: (64,)
#                                 3 bn2a_branch2b/moving_variance:0      hdf5 Weights: (64,)  Symbolic Wghts: (64,)
#
#  11 activation_3              Model Layer Name/Type : [('activation_3', <keras.layers.core.Activation object at 0x000000D164472240>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
#  12 res2a_branch2c            Model Layer Name/Type : [('res2a_branch2c', <keras.layers.convolutional.Conv2D object at 0x000000D164482278>)]
#                               Weights     : ['res2a_branch2c/kernel:0', 'res2a_branch2c/bias:0']
#                                Symbolic Weights from Model
#                                 0 (1, 1, 64, 256)
#                                 1 (256,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (1, 1, 64, 256)   symb wgt shp: (1, 1, 64, 256)
#                                 0 res2a_branch2c/kernel:0              hdf5 Weights: (1, 1, 64, 256)  Symbolic Wghts: (1, 1, 64, 256)
#                                i: 1  hdf5 weight shape: (256,)   symb wgt shp: (256,)
#                                 1 res2a_branch2c/bias:0                hdf5 Weights: (256,)  Symbolic Wghts: (256,)
#
# ...
#                               Weights     : ['fpn_p3/kernel:0', 'fpn_p3/bias:0']
#                                Symbolic Weights from Model
#                                 0 (3, 3, 256, 256)
#                                 1 (256,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (3, 3, 256, 256)   symb wgt shp: (3, 3, 256, 256)
#                                 0 fpn_p3/kernel:0                      hdf5 Weights: (3, 3, 256, 256)  Symbolic Wghts: (3, 3, 256, 256)
#                                i: 1  hdf5 weight shape: (256,)   symb wgt shp: (256,)
#                                 1 fpn_p3/bias:0                        hdf5 Weights: (256,)  Symbolic Wghts: (256,)
#
# 357 fpn_p4                    Model Layer Name/Type : [('fpn_p4', <keras.layers.convolutional.Conv2D object at 0x000000D166B19E10>)]
#                               Weights     : ['fpn_p4/kernel:0', 'fpn_p4/bias:0']
#                                Symbolic Weights from Model
#                                 0 (3, 3, 256, 256)
#                                 1 (256,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (3, 3, 256, 256)   symb wgt shp: (3, 3, 256, 256)
#                                 0 fpn_p4/kernel:0                      hdf5 Weights: (3, 3, 256, 256)  Symbolic Wghts: (3, 3, 256, 256)
#                                i: 1  hdf5 weight shape: (256,)   symb wgt shp: (256,)
#                                 1 fpn_p4/bias:0                        hdf5 Weights: (256,)  Symbolic Wghts: (256,)
#
# 358 fpn_p6                    Model Layer Name/Type : [('fpn_p6', <keras.layers.pooling.MaxPooling2D object at 0x000000D166B514E0>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 359 rpn_model                 Model Layer Name/Type : [('rpn_model', <keras.engine.training.Model object at 0x000000D166C1BF98>)]
#                               Weights     : ['rpn_conv_shared/kernel:0', 'rpn_conv_shared/bias:0', 'rpn_class_raw/kernel:0', 'rpn_class_raw/bias:0', 'rpn_bbox_pred/kernel:0', 'rpn_bbox_pred/bias:0']
#                                Symbolic Weights from Model
#                                 0 (3, 3, 256, 512)
#                                 1 (512,)
#                                 2 (1, 1, 512, 6)
#                                 3 (6,)
#                                 4 (1, 1, 512, 12)
#                                 5 (12,)
#                                len weight_values: 6   len symbolic_weights: 6
#                                i: 0  hdf5 weight shape: (3, 3, 256, 512)   symb wgt shp: (3, 3, 256, 512)
#                                 0 rpn_conv_shared/kernel:0             hdf5 Weights: (3, 3, 256, 512)  Symbolic Wghts: (3, 3, 256, 512)
#                                i: 1  hdf5 weight shape: (512,)   symb wgt shp: (512,)
#                                 1 rpn_conv_shared/bias:0               hdf5 Weights: (512,)  Symbolic Wghts: (512,)
#                                i: 2  hdf5 weight shape: (1, 1, 512, 6)   symb wgt shp: (1, 1, 512, 6)
#                                 2 rpn_class_raw/kernel:0               hdf5 Weights: (1, 1, 512, 6)  Symbolic Wghts: (1, 1, 512, 6)
#                                i: 3  hdf5 weight shape: (6,)   symb wgt shp: (6,)
#                                 3 rpn_class_raw/bias:0                 hdf5 Weights: (6,)  Symbolic Wghts: (6,)
#                                i: 4  hdf5 weight shape: (1, 1, 512, 12)   symb wgt shp: (1, 1, 512, 12)
#                                 4 rpn_bbox_pred/kernel:0               hdf5 Weights: (1, 1, 512, 12)  Symbolic Wghts: (1, 1, 512, 12)
#                                i: 5  hdf5 weight shape: (12,)   symb wgt shp: (12,)
#                                 5 rpn_bbox_pred/bias:0                 hdf5 Weights: (12,)  Symbolic Wghts: (12,)
#
# 360 rpn_bbox                  Model Layer Name/Type : [('rpn_bbox', <keras.layers.core.Lambda object at 0x000000D167599048>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 361 rpn_class                 Model Layer Name/Type : [('rpn_class', <keras.layers.core.Lambda object at 0x000000D167599F60>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 362 input_gt_boxes            Model Layer Name/Type : [('input_gt_boxes', <keras.engine.input_layer.InputLayer object at 0x000000D1641B7470>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 363 ROI                       Model Layer Name/Type : [('ROI', <mrcnn.proposal_layer.ProposalLayer object at 0x000000D1675AF550>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 364 input_gt_class_ids        Model Layer Name/Type : [('input_gt_class_ids', <keras.engine.input_layer.InputLayer object at 0x000000D1641B74A8>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 365 input_normalized_gt_boxes Model Layer Name/Type : [('input_normalized_gt_boxes', <keras.layers.core.Lambda object at 0x000000D1641B73C8>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 366 proposal_targets          Model Layer Name/Type : [('proposal_targets', <mrcnn.detect_tgt_layer_mod.DetectionTargetLayer_mod object at 0x000000D16762EEB8>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 367 roi_align_classifier      Model Layer Name/Type : [('roi_align_classifier', <mrcnn.roialign_layer.PyramidROIAlign object at 0x000000D168277710>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 368 mrcnn_class_conv1         Model Layer Name/Type : [('mrcnn_class_conv1', <keras.layers.wrappers.TimeDistributed object at 0x000000D16832FA90>)]
#                               Weights     : ['mrcnn_class_conv1/kernel:0', 'mrcnn_class_conv1/bias:0']
#                                Symbolic Weights from Model
#                                 0 (7, 7, 256, 1024)
#                                 1 (1024,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (7, 7, 256, 1024)   symb wgt shp: (7, 7, 256, 1024)
#                                 0 mrcnn_class_conv1/kernel:0           hdf5 Weights: (7, 7, 256, 1024)  Symbolic Wghts: (7, 7, 256, 1024)
#                                i: 1  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 1 mrcnn_class_conv1/bias:0             hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#
# 369 mrcnn_class_bn1           Model Layer Name/Type : [('mrcnn_class_bn1', <keras.layers.wrappers.TimeDistributed object at 0x000000D167FCC9B0>)]
#                               Weights     : ['mrcnn_class_bn1/gamma:0', 'mrcnn_class_bn1/beta:0', 'mrcnn_class_bn1/moving_mean:0', 'mrcnn_class_bn1/moving_variance:0']
#                                Symbolic Weights from Model
#                                 0 (1024,)
#                                 1 (1024,)
#                                 2 (1024,)
#                                 3 (1024,)
#                                len weight_values: 4   len symbolic_weights: 4
#                                i: 0  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 0 mrcnn_class_bn1/gamma:0              hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 1  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 1 mrcnn_class_bn1/beta:0               hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 2  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 2 mrcnn_class_bn1/moving_mean:0        hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 3  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 3 mrcnn_class_bn1/moving_variance:0    hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#
# 370 activation_68             Model Layer Name/Type : [('activation_68', <keras.layers.core.Activation object at 0x000000D168360BE0>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 371 mrcnn_class_conv2         Model Layer Name/Type : [('mrcnn_class_conv2', <keras.layers.wrappers.TimeDistributed object at 0x000000D168360DD8>)]
#                               Weights     : ['mrcnn_class_conv2/kernel:0', 'mrcnn_class_conv2/bias:0']
#                                Symbolic Weights from Model
#                                 0 (1, 1, 1024, 1024)
#                                 1 (1024,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (1, 1, 1024, 1024)   symb wgt shp: (1, 1, 1024, 1024)
#                                 0 mrcnn_class_conv2/kernel:0           hdf5 Weights: (1, 1, 1024, 1024)  Symbolic Wghts: (1, 1, 1024, 1024)
#                                i: 1  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 1 mrcnn_class_conv2/bias:0             hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#
# 372 mrcnn_class_bn2           Model Layer Name/Type : [('mrcnn_class_bn2', <keras.layers.wrappers.TimeDistributed object at 0x000000D168380DA0>)]
#                               Weights     : ['mrcnn_class_bn2/gamma:0', 'mrcnn_class_bn2/beta:0', 'mrcnn_class_bn2/moving_mean:0', 'mrcnn_class_bn2/moving_variance:0']
#                                Symbolic Weights from Model
#                                 0 (1024,)
#                                 1 (1024,)
#                                 2 (1024,)
#                                 3 (1024,)
#                                len weight_values: 4   len symbolic_weights: 4
#                                i: 0  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 0 mrcnn_class_bn2/gamma:0              hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 1  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 1 mrcnn_class_bn2/beta:0               hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 2  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 2 mrcnn_class_bn2/moving_mean:0        hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#                                i: 3  hdf5 weight shape: (1024,)   symb wgt shp: (1024,)
#                                 3 mrcnn_class_bn2/moving_variance:0    hdf5 Weights: (1024,)  Symbolic Wghts: (1024,)
#
# 373 activation_69             Model Layer Name/Type : [('activation_69', <keras.layers.core.Activation object at 0x000000D1683A9B38>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 374 pool_squeeze              Model Layer Name/Type : [('pool_squeeze', <keras.layers.core.Lambda object at 0x000000D1683A9E10>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 375 input_image_meta          *** No corresponding layers found in model ***
#                               Weights     : []
#
# 376 mrcnn_bbox_fc             Model Layer Name/Type : [('mrcnn_bbox_fc', <keras.layers.wrappers.TimeDistributed object at 0x000000D1683DE978>)]
#                               Weights     : ['mrcnn_bbox_fc/kernel:0', 'mrcnn_bbox_fc/bias:0']
#                                Symbolic Weights from Model
#                                 0 (1024, 324)
#                                 1 (324,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (1024, 324)   symb wgt shp: (1024, 324)
#                                 0 mrcnn_bbox_fc/kernel:0               hdf5 Weights: (1024, 324)  Symbolic Wghts: (1024, 324)
#                                i: 1  hdf5 weight shape: (324,)   symb wgt shp: (324,)
#                                 1 mrcnn_bbox_fc/bias:0                 hdf5 Weights: (324,)  Symbolic Wghts: (324,)
#
# 377 input_rpn_match           *** No corresponding layers found in model ***
#                               Weights     : []
#
# 378 rpn_class_logits          *** No corresponding layers found in model ***
#                               Weights     : []
#
# 379 input_rpn_bbox            *** No corresponding layers found in model ***
#                               Weights     : []
#
# 380 mrcnn_class_logits        Model Layer Name/Type : [('mrcnn_class_logits', <keras.layers.wrappers.TimeDistributed object at 0x000000D1683B8908>)]
#                               Weights     : ['mrcnn_class_logits/kernel:0', 'mrcnn_class_logits/bias:0']
#                                Symbolic Weights from Model
#                                 0 (1024, 81)
#                                 1 (81,)
#                                len weight_values: 2   len symbolic_weights: 2
#                                i: 0  hdf5 weight shape: (1024, 81)   symb wgt shp: (1024, 81)
#                                 0 mrcnn_class_logits/kernel:0          hdf5 Weights: (1024, 81)  Symbolic Wghts: (1024, 81)
#                                i: 1  hdf5 weight shape: (81,)   symb wgt shp: (81,)
#                                 1 mrcnn_class_logits/bias:0            hdf5 Weights: (81,)  Symbolic Wghts: (81,)
#
# 381 lambda_3                  *** No corresponding layers found in model ***
#                               Weights     : []
#
# 382 mrcnn_bbox                Model Layer Name/Type : [('mrcnn_bbox', <keras.layers.core.Reshape object at 0x000000D168404208>)]
#                               Weights     : []
#                                Symbolic Weights from Model
#                                len weight_values: 0   len symbolic_weights: 0
#
# 383 rpn_class_loss            *** No corresponding layers found in model ***
#                               Weights     : []
#
# 384 rpn_bbox_loss             *** No corresponding layers found in model ***
#                               Weights     : []
#
# 385 mrcnn_class_loss          *** No corresponding layers found in model ***
#                               Weights     : []
#
# 386 mrcnn_bbox_loss           *** No corresponding layers found in model ***
#                               Weights     : []
# Wrap it up...
#    Weights file loaded: F:\models\train_mrcnn_coco\mrcnn20181011T1100\mrcnn_0103.h5
# ==========================================
# MRCNN  MODEL Load weight file COMPLETE
# ==========================================
# ==========================================
#  MRCNN MODEL Load weight file COMPLETE
# ==========================================

# %%
##------------------------------------------------------------------------------------
## Build configuration for FCN model
##------------------------------------------------------------------------------------
fcn_config = CocoConfig()
# fcn_config.IMAGE_MAX_DIM        = 600
# fcn_config.IMAGE_MIN_DIM        = 480      
fcn_config.NAME                 = 'fcn'              
fcn_config.BATCH_SIZE           = mrcnn_config.BATCH_SIZE                 # Batch size is 2 (# GPUs * images/GPU).
fcn_config.IMAGES_PER_GPU       = mrcnn_config.BATCH_SIZE               # Must match BATCH_SIZE
fcn_config.STEPS_PER_EPOCH      = int(args.steps_in_epoch)
fcn_config.LEARNING_RATE        = float(args.lr)
fcn_config.EPOCHS_TO_RUN        = int(args.epochs)
fcn_config.FCN_INPUT_SHAPE      = mrcnn_config.IMAGE_SHAPE[0:2] // mrcnn_config.HEATMAP_SCALE_FACTOR 
fcn_config.IMAGE_MAX_DIM        = mrcnn_config.IMAGE_SHAPE[0] 
fcn_config.IMAGE_MIN_DIM        = mrcnn_config.IMAGE_SHAPE[1] 
fcn_config.LAST_EPOCH_RAN       = int(args.last_epoch)
fcn_config.WEIGHT_DECAY         = 2.0e-4
fcn_config.VALIDATION_STEPS     = int(args.val_steps)
fcn_config.REDUCE_LR_FACTOR     = 0.5
fcn_config.REDUCE_LR_COOLDOWN   = 50
fcn_config.REDUCE_LR_PATIENCE   = 33
fcn_config.EARLY_STOP_PATIENCE  = 50
fcn_config.EARLY_STOP_MIN_DELTA = 1.0e-4
fcn_config.MIN_LR               = 1.0e-10
fcn_config.NEW_LOG_FOLDER       = True  
fcn_config.OPTIMIZER            = args.opt.upper()
fcn_config.FCN_TRAINING_PATH    = FCN_TRAINING_PATH

fcn_config.display()
# Out:
# Configuration Parameters:
# -------------------------
# BACKBONE_SHAPES                [[256 256]
#  [128 128]
#  [ 64  64]
#  [ 32  32]
#  [ 16  16]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# EARLY_STOP_MIN_DELTA           0.0001
# EARLY_STOP_PATIENCE            50
# EPOCHS_TO_RUN                  1
# FCN_INPUT_SHAPE                [256 256]
# FCN_TRAINING_PATH              /users/students/r0653928/models/train_fcn_coco
# GPU_COUNT                      1
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  1024
# IMAGE_MIN_DIM                  1024
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [1024 1024    3]
# LAST_EPOCH_RAN                 0
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# MIN_LR                         1e-10
# NAME                           fcn
# NEW_LOG_FOLDER                 True
# NUM_CLASSES                    81
# OPTIMIZER                      ADAGRAD
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# REDUCE_LR_COOLDOWN             50
# REDUCE_LR_FACTOR               0.5
# REDUCE_LR_PATIENCE             33
# ROI_POSITIVE_RATIO             0.33
# ROI_PROPOSAL_AREA_THRESHOLD    0
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                10
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0002

# %%
##------------------------------------------------------------------------------------
## Build FCN Model in Training Mode
##------------------------------------------------------------------------------------
try :
    del fcn_model
    gc.collect()
except: 
    pass    
fcn_model = fcn_modellib.FCN(mode="training", config=fcn_config, model_dir=fcn_config.FCN_TRAINING_PATH)
# Out:
# >>> Initialize ModelBase model
#    Mode:  training
#    Model dir :  /users/students/r0653928/models/train_fcn_coco
# >>> ModelBase initialiation complete
# >>> Initialize FCN model, mode:  training
#   set_log_dir(): self.Checkpoint_path: /users/students/r0653928/models/train_fcn_coco/fcn20181015T1615/fcn_{epoch:04d}.h5
#   set_log_dir(): self.log_dir        : /users/students/r0653928/models/train_fcn_coco/fcn20181015T1615
#   set_log_dir(): Last completed epoch (self.epoch): 0
#
#
# ---------------------------------------------------
#     Adding  FCN layers
# ---------------------------------------------------
#
# >>> FCN Layer
#      feature map      : (?, 256, 256, 81)
#      height : 256 width : 256 classes : 81
#      image_data_format:  channels_last
#      rois_per_class   :  channels_last
#    FCN Block 11 shape is :  (?, 256, 256, 64)
#    FCN Block 12 shape is :  (?, 256, 256, 64)
#    FCN Block 13 shape is :  (?, 128, 128, 64)
#    FCN Block 21 shape is :  (?, 128, 128, 128)
#    FCN Block 22 shape is :  (?, 128, 128, 128)
#    FCN Block 23 (Max pooling) shape is :  (?, 64, 64, 128)
#    FCN Block 31 shape is :  (?, 64, 64, 256)
#    FCN Block 32 shape is :  (?, 64, 64, 256)
#    FCN Block 33 shape is :  (?, 64, 64, 256)
#    FCN Block 34 (Max pooling) shape is :  (?, 32, 32, 256)
#    FCN Block 41 shape is :  (?, 32, 32, 512)
#    FCN Block 42 shape is :  (?, 32, 32, 512)
#    FCN Block 43 shape is :  (?, 32, 32, 512)
#    FCN Block 44 (Max pooling) shape is :  (?, 16, 16, 512)
#    FCN Block 51 shape is :  (?, 16, 16, 512)
#    FCN Block 52 shape is :  (?, 16, 16, 512)
#    FCN Block 53 shape is :  (?, 16, 16, 512)
#    FCN Block 54 (Max pooling) shape is :  (?, 8, 8, 512)
#    FCN fully connected 1 (fcn_fc1) shape is :  (?, 8, 8, 4096)
#    FCN fully connected 2 (fcn_fc2) shape is :  (?, 8, 8, 4096)
#    FCN final conv2d (fcn_classify) shape is :  (?, 8, 8, 81)  keras_tensor  True
#    h_factor :  32.0 w_factor :  32.0
#
# >>> BilinearUpSampling2D layer
#      data_format :  channels_last
#      size        :  (32.0, 32.0)
#      target_size :  None
#      input_spec  :  [InputSpec(ndim=4)]
#      call resize_images_bilinear with size:  (32.0, 32.0)
#      CHANNELS LAST: X:  (?, 8, 8, 81)  KB.int_shape() :  (None, 8, 8, 81)
#      target_height   :  None  target_width  :  None
#      new_shape (2):  (2,) (2,)
#      new_shape (3):  (2,) (2,)
#      X after image.resize_bilinear:  (?, ?, ?, 81)
#      Dimensions of X after set_shape() :  (?, 256, 256, 81)
#      BilinearUpSampling2D. compute_output_shape()
#      Bilinear output shape is: None , 256 , 256 , 81
#    FCN Bilinear upsmapling layer  shape is :  (?, 256, 256, 81)  Keras tensor  True
#
#     fcn_heatmap       :  (?, 256, 256, 81)  Keras tensor  True
#    fcn_heatmap      :  (None, 256, 256, 81)  Keras tensor  True
#
#
# ---------------------------------------------------
#     building Loss Functions
# ---------------------------------------------------
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-80026cbb7523> in <module>()
#       8 except:
#       9     pass
# ---> 10 fcn_model = fcn_modellib.FCN(mode="training", config=fcn_config, model_dir=fcn_config.FCN_TRAINING_PATH)
#
# ../mrcnn/model_fcn.py in __init__(self, mode, config, model_dir)
#     135             "all": ".*",
#     136         }
# --> 137         self.keras_model = self.build(mode=mode, config=config  )
#     138
#     139         print('>>> FCN initialization complete. mode: ',mode)
#
# ../mrcnn/model_fcn.py in build(self, mode, config, FCN_layers)
#     210
#     211                 fcn_norm_loss  = KL.Lambda(lambda x: loss.fcn_norm_loss_graph(*x),  name="fcn_norm_loss") \
# --> 212                                  ([gt_hm_scores, fcn_hm_scores])
#     213                 # fcn_score_loss = KL.Lambda(lambda x: loss.fcn_loss_graph(*x), name="fcn_loss") \
#     214                                 # ([gt_hm, fcn_hm_norm])
#
# UnboundLocalError: local variable 'fcn_hm_scores' referenced before assignment

# %%
def train_in_batches_dev(self,
          mrcnn_model,
          train_dataset, 
          val_dataset, 
          learning_rate, 
          layers            = None,
          losses            = None,              
          epochs            = 0,
          epochs_to_run     = 1, 
          batch_size        = 0, 
          steps_per_epoch   = 0,
          min_LR            = 0.00001):

    '''
    Train the model.
    train_dataset, 
    val_dataset:    Training and validation Dataset objects.

    learning_rate:  The learning rate to train with

    epochs:         Number of training epochs. Note that previous training epochs
                    are considered to be done already, so this actually determines
                    the epochs to train in total rather than in this particaular
                    call.

    layers:         Allows selecting wich layers to train. It can be:
                    - A regular expression to match layer names to train
                    - One of these predefined values:
                    heads: The RPN, classifier and mask heads of the network
                    all: All the layers
                    3+: Train Resnet stage 3 and up
                    4+: Train Resnet stage 4 and up
                    5+: Train Resnet stage 5 and up
    '''
    assert self.mode == "training", "Create model in training mode."

    if batch_size == 0 :
        batch_size = self.config.BATCH_SIZE

    # if epochs_to_run > 0 :
    epochs = self.epoch + epochs_to_run

    if steps_per_epoch == 0:
        steps_per_epoch = self.config.STEPS_PER_EPOCH

    # use Pre-defined layer regular expressions
    # if layers in self.layer_regex.keys():
        # layers = self.layer_regex[layers]
    print(layers)
    # train_regex_list = []
    # for x in layers:
        # print( ' layers ias : ',x)
        # train_regex_list.append(x)
    train_regex_list = [self.layer_regex[x] for x in layers]
    print(train_regex_list)
    layers = '|'.join(train_regex_list)        
    print('layers regex :', layers)


    ##--------------------------------------------------------------------------------
    ## Data generators
    ##--------------------------------------------------------------------------------
    train_generator = data_generator(train_dataset, self.config, shuffle=True,
                                     batch_size=batch_size)
    val_generator   = data_generator(val_dataset, self.config, shuffle=True,
                                     batch_size=batch_size,
                                     augment=False)

    ##--------------------------------------------------------------------------------
    ## Set trainable layers and compile
    ##--------------------------------------------------------------------------------
    self.set_trainable(layers)            
    self.compile(learning_rate, self.config.LEARNING_MOMENTUM, losses)        


    ##--------------------------------------------------------------------------------
    ## Create checkpoint folder if it doesn't exists
    ##--------------------------------------------------------------------------------
    from tensorflow.python.platform import gfile
    if not gfile.IsDirectory(self.log_dir):
        log('Creating checkpoint folder : {}'.format(self.log_dir))
        gfile.MakeDirs(self.log_dir)
    else:
        log('Checkpoint folder already exists: {}'.format(self.log_dir))                                   
    # my_callback = MyCallback()

    ##--------------------------------------------------------------------------------
    ## Callbacks
    ##--------------------------------------------------------------------------------
    # call back for model checkpoint was originally (?) loss. chanegd to val_loss (which is default) 2-5-18

    # copied from \keras\engine\training.py
    # def _get_deduped_metrics_names(self):
    ## get metrics from keras_model.metrics_names
    out_labels = self.get_deduped_metrics_names()
    print()
    print(' out_labels from get_deduped_metrics_names() : ')
    print(' --------------------------------------------- ')
    print(out_labels)

    ## setup Progress Bar callback
    callback_metrics = out_labels + ['val_' + n for n in out_labels]
    print()
    print(' Callback metrics monitored by progbar :')
    print(' ---------------------------------------')
    pp.pprint(callback_metrics)

    # progbar = keras.callbacks.ProgbarLogger(count_mode='steps')
    # progbar.set_model(self.keras_model)
    # progbar.set_params({
        # 'epochs': epochs,
        # 'steps': steps_per_epoch,
        # 'verbose': 1,
        # 'do_validation': False,
        # 'metrics': callback_metrics,
    # })


    # progbar.set_model(self.keras_model) 

    ## setup Checkpoint callback
    # chkpoint = keras.callbacks.ModelCheckpoint(self.checkpoint_path, 
                                               # monitor='val_loss', 
                                               # verbose=1, 
                                               # save_best_only = True, 
                                               # save_weights_only=True)
    # chkpoint.set_model(self.keras_model)

    # progbar.on_train_begin()



    callbacks_list = [
        keras.callbacks.ProgbarLogger(count_mode='steps'),

        keras.callbacks.TensorBoard(log_dir=self.log_dir,
                                      histogram_freq=0,
                                      batch_size=32,
                                      write_graph=True,
                                      write_grads=False,
                                      write_images=True,
                                      embeddings_freq=0,
                                      embeddings_layer_names=None,
                                      embeddings_metadata=None)

        , keras.callbacks.ModelCheckpoint(self.checkpoint_path, 
                                          mode = 'auto', 
                                          period = 1, 
                                          monitor='val_loss', 
                                          verbose=1, 
                                          save_best_only = True, 
                                          save_weights_only=True)

        , keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                            mode     = 'auto', 
                                            factor   = self.config.REDUCE_LR_FACTOR,   
                                            cooldown = self.config.REDUCE_LR_COOLDOWN,
                                            patience = self.config.REDUCE_LR_PATIENCE,
                                            min_lr   = self.config.MIN_LR, 
                                            verbose  = 1)                                            

        , keras.callbacks.EarlyStopping(monitor='val_loss', 
                                            mode      = 'auto', 
                                            min_delta = 0.00001, 
                                            patience  = self.config.EARLY_STOP_PATIENCE, 
                                            verbose   = 1)                                            
        # , my_callback
    ]


    callbacks =  keras.callbacks.CallbackList(callbacks = callbacks_list)
    callbacks.set_model(self.keras_model)
    callbacks.set_params({
        'epochs': epochs,
        'steps': steps_per_epoch,
        'verbose': 1,
        'do_validation': False,
        'metrics': callback_metrics,
    })



    log("Starting at epoch {} of {} epochs. LR={}\n".format(self.epoch, epochs, learning_rate))
    log("Steps per epochs {} ".format(steps_per_epoch))
    log("    Last epoch completed : {} ".format(self.epoch))
    log("    Starting from epoch  : {} for {} epochs".format(self.epoch, epochs_to_run))
    log("    Learning Rate        : {} ".format(learning_rate))
    log("    Steps per epoch      : {} ".format(steps_per_epoch))
    log("    Batch Size           : {} ".format(batch_size))
    log("    Checkpoint Folder    : {} ".format(self.checkpoint_path))



    ##--------------------------------------------------------------------------------
    ## Start main training loop
    ##--------------------------------------------------------------------------------
    epoch_idx = self.epoch
    # progbar.on_train_begin()
    callbacks.on_train_begin()

    if epoch_idx >= epochs:
        print('Final epoch {} has already completed - Training will not proceed'.format(epochs))
    else:

        while epoch_idx < epochs :
            # progbar.on_epoch_begin(epoch_idx)
            callbacks.on_epoch_begin(epoch_idx)

            for steps_index in range(steps_per_epoch):

                batch_logs = {}
                print(' self.epoch {}   epochs {}  step {} '.format(self.epoch, epochs, steps_index))
                batch_logs['batch'] = steps_index
                batch_logs['size']  = batch_size
                # progbar.on_batch_begin(steps_index, batch_logs)
                callbacks.on_batch_begin(steps_index, batch_logs)

                train_batch_x, train_batch_y = next(train_generator)
                # print('length of train_batch_x:', len(train_batch_x))
                # print('length of train_batch_y:', len(train_batch_y))


                # # model_output   = get_layer_output_2(mrcnn_model.keras_model, train_batch_x, training_flag = False)
                # # model_output = get_layer_output_1(model.keras_model, train_batch_x, [ 26], 1)

                # print(len(model_output))
                # # print(type(output_rois))
                # for i in model_output:
                    # print( i.shape)                    

                results = mrcnn_model.keras_model.predict(train_batch_x)
#                 print('# of items in results:', len(results))


                pr_hm_norm, gt_hm_norm, pr_hm_scores, gt_hm_scores = results[11:]                 

                # print('pr_hm_norm shape   :', pr_hm_norm.shape)
                # print('pr_hm_scores shape :', pr_hm_scores.shape)
                # print('gt_hm_norm shape   :', gt_hm_norm.shape)
                # print('gt_hm_scores shape :', gt_hm_scores.shape)

                outs = self.keras_model.train_on_batch([pr_hm_norm,  pr_hm_scores,gt_hm_norm, gt_hm_scores], train_batch_y)

#                 print(' outs: ', outs)
                if not isinstance(outs, list):
                    outs = [outs]
                for l, o in zip(out_labels, outs):
                    batch_logs[l] = o

                # progbar.on_batch_end(steps_index, batch_logs)
                callbacks.on_batch_end(steps_index, batch_logs)

                # print(outs)

            ## end of epoch operations     
            ##-------------------------------
            val_batch_x, val_batch_y = next(val_generator)
            val_outs = self.keras_model.test_on_batch(X_val, Y_val)
            # write_log(callback, val_names, logs, batch_no//10)
            print(' validation logs output: ', val_outs)
            if not isinstance(val_outs, list):
                val_outs = [val_outs]
            for l, o in zip(out_labels, outs):
                batch_logs[l] = o




            # progbar.on_epoch_end(epoch_idx, {})
            # if (epoch_idx % 10) == 0:
            # chkpoint.on_epoch_end(epoch_idx  , batch_logs)
            callbacks.on_epoch_end(epoch_idx, batch_logs)
            epoch_idx += 1

        ## end of all epochs operations
        ##--------------------------------
        # if epoch_idx != self.epoch:
        # chkpoint.on_epoch_end(epoch_idx -1, batch_logs)
        callbacks.on_train_end()
        self.epoch = max(epoch_idx - 1, epochs)
        print('Final : self.epoch {}   epochs {}'.format(self.epoch, epochs))

    ##--------------------------------------------------------------------------------
    ## End main training loop
    ##--------------------------------------------------------------------------------

# %%
print(train_layers)
# train_regex_list = []
# for x in layers:
    # print( ' layers ias : ',x)
    # train_regex_list.append(x)
train_regex_list = [fcn_model.layer_regex[x] for x in train_layers]
print(train_regex_list)
layers = '|'.join(train_regex_list)        
print('layers regex :', layers)

##--------------------------------------------------------------------------------
## Set trainable layers and compile
##--------------------------------------------------------------------------------
fcn_model.set_trainable(layers)            
fcn_model.compile(learning_rate, fcn_model.config.LEARNING_MOMENTUM, loss_names)

# %%
out_labels = fcn_model.get_deduped_metrics_names()
print()
print(' out_labels from get_deduped_metrics_names() : ')
print(' --------------------------------------------- ')
print(out_labels)
# Out:
#  out_labels from get_deduped_metrics_names() :
#  ---------------------------------------------
# ['loss', 'fcn_norm_loss']

# %%
##--------------------------------------------------------------------------------
## Data generators
##--------------------------------------------------------------------------------
train_generator = data_generator(dataset_train, mrcnn_model.config, shuffle=True,
                                 batch_size=batch_size)
val_generator   = data_generator(dataset_val, mrcnn_model.config, shuffle=True,
                                 batch_size=batch_size,
                                 augment=False)

# %%
fcn_config.EPOCHS_TO_RUN

# %%
epochs = fcn_model.epoch + epochs_to_run
log("Starting at epoch {} of {} epochs. LR={}\n".format(fcn_model.epoch, epochs, learning_rate))
log("Steps per epochs {} ".format(steps_per_epoch))
log("    Last epoch completed : {} ".format(fcn_model.epoch))
log("    Starting from epoch  : {} for {} epochs".format(fcn_model.epoch, epochs_to_run))
log("    Learning Rate        : {} ".format(learning_rate))
log("    Steps per epoch      : {} ".format(steps_per_epoch))
log("    Batch Size           : {} ".format(batch_size))
log("    Checkpoint Folder    : {} ".format(fcn_model.checkpoint_path))
# Out:
# Starting at epoch 0 of 100 epochs. LR=0.005
#
# Steps per epochs 128
#     Last epoch completed : 0
#     Starting from epoch  : 0 for 100 epochs
#     Learning Rate        : 0.005
#     Steps per epoch      : 128
#     Batch Size           : 8
#     Checkpoint Folder    : /home/kbardool/models/train_fcn_alt/shapes20180709T1458/fcn_shapes_{epoch:04d}.h5

# %%
steps_index = 0

# %%
batch_logs = {}
print(' self.epoch {}   epochs {}  step {} '.format(fcn_model.epoch, epochs, steps_index))
batch_logs['batch'] = steps_index
batch_logs['size']  = batch_size
# progbar.on_batch_begin(steps_index, batch_logs)
callbacks.on_batch_begin(steps_index, batch_logs)
# Out:
#  self.epoch 0   epochs 100  step 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d49075fba920> in <module>()
#       4 batch_logs['size']  = batch_size
#       5 # progbar.on_batch_begin(steps_index, batch_logs)
# ----> 6 callbacks.on_batch_begin(steps_index, batch_logs)
#
# NameError: name 'callbacks' is not defined

# %%
train_batch_x, train_batch_y = next(train_generator)

for i in train_batch_x:
    print( i.shape)
# Out:
# (8, 128, 128, 3)
# (8, 15)
# (8, 4092, 1)
# (8, 256, 4)
# (8, 100)
# (8, 100, 4)
# (8, 56, 56, 100)

# %% [markdown]
# ### Run MRCNN model predictions
#
#      Outputs:
#      --------
#      layer:  0    output : rpn_class_logits/rpn_class_logits:0        Type: float32           Shape: (?, ?, 2)
#      layer:  1    output : rpn_class/rpn_class:0                      Type: float32           Shape: (?, ?, 2)
#      layer:  2    output : rpn_bbox/rpn_bbox:0                        Type: float32           Shape: (?, ?, 4)
#      layer:  3    output : rpn_proposal_rois/rpn_roi_proposals:0      Type: float32           Shape: (8, ?, ?)
#      layer:  4    output : proposal_targets/output_rois:0             Type: float32           Shape: (8, ?, ?)
#      layer:  5    output : proposal_targets/target_class_ids:0        Type: int32             Shape: (8, ?)
#      layer:  6    output : proposal_targets/target_bbox_deltas:0      Type: float32           Shape: (8, ?, ?)
#      layer:  7    output : proposal_targets/roi_gt_boxes:0            Type: float32           Shape: (8, ?, ?)
#      layer:  8    output : mrcnn_class_logits/mrcnn_class_logits:0    Type: float32           Shape: (?, 32, 7)
#      layer:  9    output : mrcnn_class/mrcnn_class:0                  Type: float32           Shape: (?, 32, 7)
#      layer: 10    output : mrcnn_bbox_regression/mrcnn_bbox:0         Type: float32           Shape: (?, 32, 7, 4)
#      layer: 11    output : cntxt_layer/pred_heatmap_norm:0            Type: float32           Shape: (8, 128, 128, 7)
#      layer: 12    output : cntxt_layer/gt_heatmap_norm:0              Type: float32           Shape: (8, 128, 128, 7)
#      layer: 13    output : cntxt_layer/pred_heatmap_scores:0          Type: float32           Shape: (?, ?, ?, ?)
#      layer: 14    output : cntxt_layer/gt_heatmap_scores:0            Type: float32           Shape: (?, ?, ?, ?)
#
#
#      Inputs:
#      -------
#      layer:  0    output : input_pr_hm_norm:0                         Type: float32           Shape: (?, 128, 128, 7)
#      layer:  1    output : input_pr_hm_scores:0                       Type: float32           Shape: (?, 7, 32, 11)
#      layer:  2    output : input_gt_hm_norm:0                         Type: float32           Shape: (?, 128, 128, 7)
#      layer:  3    output : input_gt_hm_scores:0                       Type: float32           Shape: (?, 7, 32, 11)
#
#
#      Outputs:
#      --------
#      layer:  0    output : fcn_heatmap_norm/fcn_heatmap_norm:0        Type: float32           Shape: (?, 128, 128, 7)
#      layer:  1    output : fcn_scoring/fcn_heatmap_scores:0           Type: float32           Shape: (?, ?, ?, ?)
#      layer:  2    output : fcn_heatmap/fcn_heatmap:0                  Type: float32           Shape: (?, 128, 128, 7)
#      layer:  3    output : fcn_norm_loss/fcn_norm_loss:0              Type: float32           Shape: (1, 1)

# %%
results = mrcnn_model.keras_model.predict(train_batch_x)
print('# of items in results:', len(results))

for i in results:
    print( i.shape)
# Out:
# # of items in results: 15
# (8, 4092, 2)
# (8, 4092, 2)
# (8, 4092, 4)
# (8, 1000, 4)
# (8, 32, 4)
# (8, 32)
# (8, 32, 4)
# (8, 32, 4)
# (8, 32, 7)
# (8, 32, 7)
# (8, 32, 7, 4)
# (8, 128, 128, 7)
# (8, 128, 128, 7)
# (8, 7, 32, 11)
# (8, 7, 32, 11)

# %%
pr_hm_norm, gt_hm_norm, pr_hm_scores, gt_hm_scores = results[11:]                 
print(pr_hm_norm.shape)
print(gt_hm_norm.shape)
print(pr_hm_scores.shape)
print(gt_hm_scores.shape)
# Out:
# (8, 128, 128, 7)
# (8, 128, 128, 7)
# (8, 7, 32, 11)
# (8, 7, 32, 11)

# %%
outs = fcn_model.keras_model.train_on_batch([pr_hm_norm,  pr_hm_scores,gt_hm_norm, gt_hm_scores], train_batch_y)
# Out:
#   Make training function -------------------------------
#  self.total_loss : loss_1/add_1:0
# <tf.Tensor 'loss_1/add_1:0' shape=(1, 1) dtype=float32>
#  self.metrics_tensors : Mean_3:0
# [<tf.Tensor 'Mean_3:0' shape=(1, 1) dtype=float32>]
#  updates :
# [   <tf.Tensor 'training/SGD/AssignAdd:0' shape=() dtype=int64_ref>,
#     <tf.Tensor 'training/SGD/Assign:0' shape=(3, 3, 7, 64) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_1:0' shape=(3, 3, 7, 64) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_2:0' shape=(64,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_3:0' shape=(64,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_4:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_5:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_6:0' shape=(64,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_7:0' shape=(64,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_8:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_9:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_10:0' shape=(128,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_11:0' shape=(128,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_12:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_13:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_14:0' shape=(128,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_15:0' shape=(128,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_16:0' shape=(3, 3, 128, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_17:0' shape=(3, 3, 128, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_18:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_19:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_20:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_21:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_22:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_23:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_24:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_25:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_26:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_27:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_28:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_29:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_30:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_31:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_32:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_33:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_34:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_35:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_36:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_37:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_38:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_39:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_40:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_41:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_42:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_43:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_44:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_45:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_46:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_47:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_48:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_49:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_50:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_51:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_52:0' shape=(7, 7, 512, 2048) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_53:0' shape=(7, 7, 512, 2048) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_54:0' shape=(2048,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_55:0' shape=(2048,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_56:0' shape=(1, 1, 2048, 2048) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_57:0' shape=(1, 1, 2048, 2048) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_58:0' shape=(2048,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_59:0' shape=(2048,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_60:0' shape=(1, 1, 2048, 7) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_61:0' shape=(1, 1, 2048, 7) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_62:0' shape=(7,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_63:0' shape=(7,) dtype=float32_ref>]
#   ------------------------------------------------------
# train_on_batch(1929) outputs:  <class 'list'>  len:  2
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0041]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0041]]

# %%
pp.pprint(outs)
print(' outs: ', outs)
if not isinstance(outs, list):
    outs = [outs]
for l, o in zip(out_labels, outs):
    batch_logs[l] = o
# Out:
# [array([[0.0041]], dtype=float32), array([[0.0041]], dtype=float32)]
#  outs:  [array([[0.0041]], dtype=float32), array([[0.0041]], dtype=float32)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4f1a8c148282> in <module>()
#       4     outs = [outs]
#       5 for l, o in zip(out_labels, outs):
# ----> 6     batch_logs[l] = o
#
# NameError: name 'batch_logs' is not defined

# %%
fcn_output = get_layer_output_2(fcn_model.keras_model, [pr_hm_norm,  pr_hm_scores,gt_hm_norm, gt_hm_scores], True)

# %%
fcn_model.keras_model.metrics_names
# Out:
# ['loss', 'fcn_norm_loss']

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %% [markdown]
# ### Training FPN, RPN and MRCNN heads using  Keras.model.fit_generator()
#
# print(config.BATCH_SIZE)
# print(model.config.BATCH_SIZE)
# print(model.config.LEARNING_RATE)
# import keras
# keras.__version__

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.

# model.train(dataset_train, dataset_val, 
#             learning_rate=config.LEARNING_RATE, 
# #             epochs = 69,
#             epochs_to_run =2, 
#             layers='heads')
## Last run prior to FCN training was 3699, last checkpoint was 3892  ...start at 3899

train_layers = [ 'mrcnn', 'fpn','rpn']
loss_names   = [ "rpn_class_loss", "rpn_bbox_loss" , "mrcnn_class_loss", "mrcnn_bbox_loss"]
model.epoch = 1233
model.config.LEARNING_RATE = 1.0e-4
model.config.STEPS_PER_EPOCH = 7

model.train(dataset_train, dataset_val, 
            learning_rate=model.config.LEARNING_RATE, 
            epochs_to_run =3000, 
#             epochs = 25,            
#             batch_size = 0
#             steps_per_epoch = 0 
            layers = train_layers,
            losses = loss_names,
            min_LR = 1.0e-6,
            )

# %% [markdown]
# ###  Train FCN head layers

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.

# model.train(dataset_train, dataset_val, 
#             learning_rate=config.LEARNING_RATE, 
# #             epochs = 69,
#             epochs_to_run =2, 
#             layers='heads')

## Last run prior to FCN training was 3699, last checkpoint was 3892

train_layers = ['fcn']
loss_names   = [  "fcn_norm_loss"]
model.epoch = 1668
model.config.LEARNING_RATE = 1.0e-4
model.config.STEPS_PER_EPOCH = 8 

model.train(dataset_train, dataset_val, 
            learning_rate=model.config.LEARNING_RATE, 
            epochs_to_run = 500, 
#             epochs = 25,            
#             batch_size = 6,
#             steps_per_epoch = 0 
            layers = train_layers,
            losses = loss_names,
            min_LR = 1.0e-9
            )

# %%
model.keras_model.losses
print(model.keras_model.metrics_names)

# %% [markdown]
# ## - Training heads using train_in_batches ()
#
# We need to use this method for the time being as the fit generator does not have provide EASY access to the output in Keras call backs. By training in batches, we pass a batch through the network, pick up the generated RoI detections and bounding boxes and generate our semantic / gaussian tensors ...

# %%
model.train_in_batches(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/6, 
            epochs_to_run = 3,
            layers='heads')

# %% [markdown]
# ## Fine Tuning
# Fine tune all layers

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=211,
            layers="all")

# train_layers = ['fcn']
# loss_names   = [  "fcn_norm_loss"]
# model.epoch = 208
# model.config.LEARNING_RATE = 1.0e-4
# model.config.STEPS_PER_EPOCH = 8 

# model.train(dataset_train, dataset_val, 
#             learning_rate=model.config.LEARNING_RATE, 
#             epochs_to_run = 500, 
# #             epochs = 25,            
# #             batch_size = 6,
# #             steps_per_epoch = 0 
#             layers = train_layers,
#             losses = loss_names,
#             min_LR = 1.0e-7
#             )

# %% [markdown]
# ## Save

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes_post_training.h5")
model.keras_model.save_weights(model_path)

# %%
# model.keras_model.summary(line_length=132, positions=[0.30,0.75, .83, 1. ])

# %%
train_batch_x, train_batch_y = next(train_generator)
imgmeta_idx = model.keras_model.input_names.index('input_image_meta')
img_meta    = train_batch_x[imgmeta_idx]

for img_idx in range(config.BATCH_SIZE):
    image_id = img_meta[img_idx,0]
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    print('Image id: ',image_id)
    print('Image meta', img_meta[img_idx])
    print('Classes (1: circle, 2: square, 3: triangle ): ',class_ids)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %%
model.layer_info()

# %%
# train_batch_x, train_batch_y = next(train_generator)

model_output = get_layer_output_2(model.keras_model, train_batch_x, 1)
# model_output = get_layer_output_1(model.keras_model, train_batch_x, [ 26], 1)

print(len(model_output))

# rpn_class_loss            = model_output[0]          # layer: 11   shape: (1, 1)
# rpn_bbox_loss             = model_output[1]          # layer: 12   shape: (1, 1)
# mrcnn_class_loss          = model_output[2]          # layer: 13   shape: (1, 1)
# mrcnn_bbox_loss           = model_output[3]          # layer: 14   shape: (1, 1)
# fcn_normalized_loss       = model_output[0]          # layer: 26   shape: (1, 1)

# print(type(output_rois))
for i in model_output:
    print( i.shape)
# print('FCN Normalized Loss is :', fcn_normalized_loss)

# %%
input_image      =  train_batch_x[0]
input_image_meta =  train_batch_x[1]
input_rpn_match  =  train_batch_x[2]
input_rpn_bbox   =  train_batch_x[3]
input_gt_class_ids = train_batch_x[4]
input_gt_bboxes    = train_batch_x[5]
input_gt_masks     = train_batch_x[6]
print(' Input image shape is :', input_image.shape)
h, w = input_image.shape[1], input_image.shape[2]      #  tf.shape(input_image)[1], tf.shape(input_image)[2]
input_normlzd_gt_bboxes = tf.identity(input_gt_bboxes / [h,w,h,w])

# gt_masks   =  train_batch_x[6]
print(' input_rpn_match    ', input_rpn_match.shape)
print(' input_rpn_bbox     ', input_rpn_bbox.shape)
print(' input_gt_class_ids ', input_gt_class_ids.shape)
print(' input_gt_bboxes    ', input_gt_bboxes.shape)
print(' input_normlzd_gt_bboxes    ', input_normlzd_gt_bboxes.shape)
