# %% [markdown]
# # Mask R-CNN - Train on NewShapes Dataset
#
# ### Notes from implementation
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
import tensorflow as tf
import keras.backend as KB
import numpy as np
from mrcnn.datagen     import data_generator, load_image_gt
from mrcnn.callbacks   import get_layer_output_1,get_layer_output_2
from mrcnn.utils       import mask_string
import mrcnn.visualize as visualize
import mrcnn.new_shapes as new_shapes
from mrcnn.prep_notebook import prep_newshapes_train2
import pprint
pp = pprint.PrettyPrinter(indent=2, width=100)


##------------------------------------------------------------------------------------
## Build configuration object 
##------------------------------------------------------------------------------------
config                    = new_shapes.NewShapesConfig()
config.FCN_LAYERS         = False
config.BATCH_SIZE         = 2                                 # Batch size is 2 (# GPUs * images/GPU).
config.IMAGES_PER_GPU     = config.BATCH_SIZE                 # Must match BATCH_SIZE
config.STEPS_PER_EPOCH    = 2
config.LEARNING_RATE      = 0.000001
                          
config.EPOCHS_TO_RUN      = 300
config.FCN_INPUT_SHAPE    = config.IMAGE_SHAPE[0:2]
config.LAST_EPOCH_RAN     = 0
config.WEIGHT_DECAY       = 2.0e-4
config.VALIDATION_STEPS   = 100
config.REDUCE_LR_FACTOR   = 0.2
config.REDUCE_LR_COOLDOWN = 30
config.REDUCE_LR_PATIENCE = 40
config.MIN_LR             = 1.0e-10
config.TRAINING_IMAGES    = 10000
config.VALIDATION_IMAGES  = 2500
config.CHECKPOINT_FOLDER  = 'newshape_fcn' 

model_file  = '/home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5'

model, dataset_train, dataset_val, train_generator, val_generator, config = \
    prep_newshapes_train2(init_with = model_file, config=config)
# Out:
# <style>.container { width:95% !important; }</style>
# Using TensorFlow backend.
#  Linx  Linux
# Tensorflow Version: 1.6.0   Keras Version : 2.1.4
# >>> Initialize MRCNN model, mode:  training
#     set_log_dir(): Checkpoint path/filename set to          : /home/kbardool/models/newshape_fcn/shapes20180709T1451/mask_rcnn_shapes_{epoch:04d}.h5
#     set_log_dir(): Last completed epoch (self.epoch) set to : 0
#
# >>> Resnet Graph
#      Input_image shape : (?, 128, 128, 3)
#      After ZeroPadding2D  : (?, 134, 134, 3) (?, 134, 134, 3)
#      After Conv2D padding : (?, 64, 64, 64) (?, 64, 64, 64)
#      After BatchNorm      : (?, 64, 64, 64) (?, 64, 64, 64)
#      C1 Shape: (?, 32, 32, 64) (?, 32, 32, 64)
#      C2 Shape:  (?, 32, 32, 256) (?, 32, 32, 256)
#      C3 Shape:  (?, 16, 16, 512) (?, 16, 16, 512)
#      C4 Shape:  (?, 8, 8, 1024) (?, 8, 8, 1024)
#      C5 Shape:  (?, 4, 4, 2048) (?, 4, 4, 2048)
#
# >>> Feature Pyramid Network (FPN) Graph
#      FPN P2 shape : (None, 32, 32, 256)
#      FPN P3 shape : (None, 16, 16, 256)
#      FPN P4 shape : (None, 8, 8, 256)
#      FPN P5 shape : (None, 4, 4, 256)
#      FPN P6 shape : (None, 2, 2, 256)
#
# >>> RPN Layer
#      Input_feature_map shape : (?, ?, ?, 256)
#      anchors_per_location    : 3
#      depth                   : 256
#      Input_feature_map shape : (?, ?, ?, 256)
#      anchors_per_location    : 3
#      anchor_stride           : 1
#
# >>> RPN Outputs  <class 'list'>
#       rpn_class_logits/rpn_class_logits:0
#       rpn_class/rpn_class:0
#       rpn_bbox/rpn_bbox:0
#
# >>> Proposal Layer - generate  2000  proposals
#     Init complete. Size of anchors:  (4092, 4)
#      Scores :  (2, 4092)
#      Deltas :  (2, 4092, 4)
#      Anchors:  (2, 4092, 4)
#      Boxes shape / type after processing:
#      Output: Prposals shape :  (2, ?, ?) (2, None, None)
#
# >>> Detection Target Layer (Training Mode)
#     Detection Target Layer : call()  <class 'list'> 3
#      proposals.shape    : (2, ?, ?) (2, ?, ?) (None, 2000, 4)
#      gt_class_ids.shape : (?, ?) (?, ?) (None, None)
#      gt_bboxes.shape    : (?, ?, 4) (?, ?, 4) (None, None, 4)
#
#     Detection Target Layer : return  <class 'list'> 4
#      output 0  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 1  shape (2, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 2  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 3  shape (2, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#
# >>> FPN Classifier Graph
#      rois shape          : (2, ?, ?)
#      No of feature_maps  : 4
#         feature_maps shape  : (?, 32, 32, 256)
#         feature_maps shape  : (?, 16, 16, 256)
#         feature_maps shape  : (?, 8, 8, 256)
#         feature_maps shape  : (?, 4, 4, 256)
#      input_shape         : [128 128   3]
#      pool_size           : 7
#    > PyramidRoI Alignment Layer Call()  5
#      boxes.shape    : (None, 32, 4)
#      roi_align_classifier output shape is :  (1, ?, 7, 7, 256) (1, ?, 7, 7, 256)
#      mrcnn_class_conv1    output shape is :  (?, 32, 1, 1, 1024)
#      mrcnn_class_bn1      output shape is :  (?, 32, 1, 1, 1024)
#      mrcnn_class_relu1    output shape is :  (?, 32, 1, 1, 1024)
#      mrcnn_class_conv2 output shape is :  (?, 32, 1, 1, 1024)
#      mrcnn_class_bn2      output shape is :  (?, 32, 1, 1, 1024)
#      mrcnn_class_relu2    output shape is :  (?, 32, 1, 1, 1024)
#      pool_squeeze(Shared) output shape is :  (?, 32, 1024)
#      mrcnn_class_logits   output shape is :  (?, 32, 7)
#      mrcnn_class_probs    output shape is :  (?, 32, 7)
#    mrcnn_bbox_fc        output shape is :  (?, 32, 28)
#    mrcnn_bbox           output shape is :  (?, 32, 7, 4)
#
# >>> CHM Layer
#    > CHMLayer Call()  5
#      mrcnn_class.shape    : (?, 32, 7) (None, 32, 7)
#      mrcnn_bbox.shape     : (?, 32, 7, 4) (None, 32, 7, 4)
#      output_rois.shape    : (2, ?, ?) (None, 32, 4)
#      tgt_class_ids.shape  : (2, ?) (None, 32)
#      gt_bboxes.shape      : (2, ?, ?) (None, 32, 4)
#  config image shape:  [128 128   3] h: 128 w: 128
#
#   > build_predictions()
#     num_rois          :  32
#     mrcnn_class shape :  Tensor("cntxt_layer/Shape:0", shape=(3,), dtype=int32) (None, 32, 7)
#     mrcnn_bbox.shape  :  Tensor("cntxt_layer/Shape_1:0", shape=(4,), dtype=int32) (None, 32, 7, 4) (?, 32, 7, 4)
#     input_rois.shape :  Tensor("cntxt_layer/Shape_2:0", shape=(3,), dtype=int32) (2, None, 4)
#     pred_array        (2, 32, 6)
# scatter_ind <class 'tensorflow.python.framework.ops.Tensor'> shape (2, 32, 3)
#     pred_scatter shape is  (2, 7, 32, 6)
# (2, 7, 32)
#
#
#   > BUILD_GROUND TRUTH_TF()
#
#     num_rois           :  32 (building  gt_tensor )
#     gt_class_ids shape :  (2, ?)
#     gt_bboxes.shape    :  (2, ?, 4)
#     gt_classes_exp shape  (2, ?, 1)
#     gt_scores_exp shape  (2, ?, 1)
#     gt_array shape : (2, 32, 7) (2, 32, 7)
#      gt_tensor final shape  :  (2, 7, 32, ?)
#
#
#   > NEW build_heatmap() for  ['pred_heatmap']
#     orignal in_tensor shape :  (2, 7, 32, 6)
#     num of bboxes per class is :  32
#     pt2_sum shape  (2, 7, 32)
#     dense shape  (?, 6)
#     X/Y shapes : (128, 128) (128, 128)
#     Ones:     (?, 1, 1)
#     ones_exp * X (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     ones_exp * Y (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     before transpse  (?, 128, 128, 2)
#     after transpose  (128, 128, ?, 2)
#      Prob_grid shape before tanspose:  (128, 128, ?)
#      Prob_grid shape after tanspose:  (?, 128, 128)
#     >> input to MVN.PROB: pos_grid (meshgrid) shape:  (128, 128, ?, 2)
#     << output probabilities shape: (?, 128, 128)
#
#     Scatter out the probability distributions based on class --------------
#     pt2_ind shape   :  (?, 3)
#     prob_grid shape :  (?, 128, 128)
#     gauss_scatt     :  (2, 7, 32, 128, 128)
#
#     Reduce sum based on class ---------------------------------------------
#     gaussian_sum shape     :  (2, 7, 128, 128) Keras tensor  False
# WARNING:tensorflow:From /home/kbardool/anaconda3/envs/TFG/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
#     gauss L2 norm   :  (2, 7, 128, 128)  Keras tensor  False
#
#     normalization ------------------------------------------------------
#     gauss norm   :  (2, 7, 128, 128)  Keras tensor  False
#     in_tensor                (2, 7, 32, 6)
#     in_tensorr_flattened is  (?, ?)
#     boxes shape              (?, ?)
#     Rois per image        :  32
#     heatmap original shape  :  (2, 7, 128, 128)
#     heatmap replicated      :  (2, 7, 32, 128, 128)
#     heatmap flattened       :  (448, 128, 128)
#     in_tensor_flattened     :  (?, ?)
#     Scores shape            :  (448, 3)
#     boxes_scores (rehspaed) :  (?, ?, ?, ?)
#     gauss_heatmap final shape :  (2, 128, 128, 7)  Keras tensor  False
#     gauss_scores  final shape :  (?, ?, ?, ?)  Keras tensor  False
#     complete
#
#
#   > NEW build_heatmap() for  ['gt_heatmap']
#     orignal in_tensor shape :  (2, 7, 32, ?)
#     num of bboxes per class is :  32
#     pt2_sum shape  (2, 7, 32)
#     dense shape  (?, ?)
#     X/Y shapes : (128, 128) (128, 128)
#     Ones:     (?, 1, 1)
#     ones_exp * X (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     ones_exp * Y (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     before transpse  (?, 128, 128, 2)
#     after transpose  (128, 128, ?, 2)
#      Prob_grid shape before tanspose:  (128, 128, ?)
#      Prob_grid shape after tanspose:  (?, 128, 128)
#     >> input to MVN.PROB: pos_grid (meshgrid) shape:  (128, 128, ?, 2)
#     << output probabilities shape: (?, 128, 128)
#
#     Scatter out the probability distributions based on class --------------
#     pt2_ind shape   :  (?, 3)
#     prob_grid shape :  (?, 128, 128)
#     gauss_scatt     :  (2, 7, 32, 128, 128)
#
#     Reduce sum based on class ---------------------------------------------
#     gaussian_sum shape     :  (2, 7, 128, 128) Keras tensor  False
#     gauss L2 norm   :  (2, 7, 128, 128)  Keras tensor  False
#
#     normalization ------------------------------------------------------
#     gauss norm   :  (2, 7, 128, 128)  Keras tensor  False
#     in_tensor                (2, 7, 32, ?)
#     in_tensorr_flattened is  (?, ?)
#     boxes shape              (?, ?)
#     Rois per image        :  32
#     heatmap original shape  :  (2, 7, 128, 128)
#     heatmap replicated      :  (2, 7, 32, 128, 128)
#     heatmap flattened       :  (448, 128, 128)
#     in_tensor_flattened     :  (?, ?)
#     Scores shape            :  (448, 3)
#     boxes_scores (rehspaed) :  (?, ?, ?, ?)
#     gauss_heatmap final shape :  (2, 128, 128, 7)  Keras tensor  False
#     gauss_scores  final shape :  (?, ?, ?, ?)  Keras tensor  False
#     complete
#      pred_cls_cnt shape :  (2, 7) Keras tensor  True
#      gt_cls_cnt shape   :  (2, 7) Keras tensor  True
#      pred_heatmap_norm  :  (2, 128, 128, 7) Keras tensor  False
#      pred_heatmap_scores:  (?, ?, ?, ?) Keras tensor  False
#      gt_heatmap_norm    :  (2, 128, 128, 7) Keras tensor  False
#      gt_heatmap_scores  :  (?, ?, ?, ?) Keras tensor  False
#      complete
# <<<  shape of pred_heatmap   :  (2, 128, 128, 7)  Keras tensor  True
# <<<  shape of gt_heatmap     :  (2, 128, 128, 7)  Keras tensor  True
#
#
# ---------------------------------------------------
#     building Loss Functions
# ---------------------------------------------------
#
# >>> rpn_bbox_loss_graph
#     rpn_match size : (?, ?)
#     rpn_bbox  size : (?, ?, 4)
#     tf default session:  None
#
# >>> rpn_bbox_loss_graph
#     rpn_match size : (?, ?)
#     rpn_bbox  size : (?, ?, 4)
#     tf default session:  None
#
# >>> mrcnn_class_loss_graph
#     target_class_ids  size : (2, ?)
#     pred_class_logits size : (?, 32, 7)
#     active_class_ids  size : (?, ?)
#
# >>> mrcnn_class_loss_graph
#     target_class_ids  size : (?, 32)
#     pred_class_logits size : (?, 32, 7)
#     active_class_ids  size : (?, ?)
#
# >>> mrcnn_bbox_loss_graph
#     target_class_ids  size : (2, ?)
#     pred_bbox size         : (?, 32, 7, 4)
#     target_bbox size       : (2, ?, ?)
#     reshpaed pred_bbox size         : (?, 7, 4)
#     reshaped target_bbox size       : (?, 4)
#     pred_bbox size         : (?, 4)
#     target_bbox size       : (?, 4)
#
# >>> mrcnn_bbox_loss_graph
#     target_class_ids  size : (?, 32)
#     pred_bbox size         : (?, 32, 7, 4)
#     target_bbox size       : (?, 32, 4)
#     reshpaed pred_bbox size         : (?, 7, 4)
#     reshaped target_bbox size       : (?, 4)
#     pred_bbox size         : (?, 4)
#     target_bbox size       : (?, 4)
#  ================================================================
#  self.keras_model.losses :  0
# []
#  ================================================================
#
# >>> Build MaskRCNN build complete. mode:  training
# >>> MaskRCNN initialiation complete. Mode:  training
# MODEL_PATH        :  /home/kbardool/models
# COCO_MODEL_PATH   :  /home/kbardool/models/mask_rcnn_coco.h5
# RESNET_MODEL_PATH :  /home/kbardool/models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# CHECKPOINT_DIR    :  /home/kbardool/models/newshape_fcn
# >>> find_last checkpoint in :  /home/kbardool/models/newshape_fcn
# Last Saved Model  :  ('/home/kbardool/models/newshape_fcn/shapes20180621T1554', '/home/kbardool/models/newshape_fcn/shapes20180621T1554/mask_rcnn_shapes_0586.h5')
# -----------------------------------------------
#  Load model with init parm:  /home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5
#  Exclude layers:
# None
# -----------------------------------------------
# Loading weights from  /home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5
#
# >>> load_weights()
#     load_weights: Loading weights from: /home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5
#    ----------------
#     layers to load
#    ----------------
#     >layer 0 : name : input_image                               type: <keras.engine.topology.InputLayer object at 0x7f4f5a9340b8>
#     >layer 1 : name : zero_padding2d_1                          type: <keras.layers.convolutional.ZeroPadding2D object at 0x7f4f52adf668>
#     >layer 2 : name : conv1                                     type: <keras.layers.convolutional.Conv2D object at 0x7f4f52a72588>
#     >layer 3 : name : bn_conv1                                  type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52a724e0>
#     >layer 4 : name : activation_1                              type: <keras.layers.core.Activation object at 0x7f4f52a87da0>
#     >layer 5 : name : max_pooling2d_1                           type: <keras.layers.pooling.MaxPooling2D object at 0x7f4f52a87898>
#     >layer 6 : name : res2a_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52a36a20>
#     >layer 7 : name : bn2a_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52a369b0>
#     >layer 8 : name : activation_2                              type: <keras.layers.core.Activation object at 0x7f4f52a47828>
#     >layer 9 : name : res2a_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52a62c50>
#     >layer 10 : name : bn2a_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52a62a90>
#     >layer 11 : name : activation_3                              type: <keras.layers.core.Activation object at 0x7f4f52a06630>
#     >layer 12 : name : res2a_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f529b4780>
#     >layer 13 : name : res2a_branch1                             type: <keras.layers.convolutional.Conv2D object at 0x7f4f529d8160>
#     >layer 14 : name : bn2a_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f529b45c0>
#     >layer 15 : name : bn2a_branch1                              type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52989978>
#     >layer 16 : name : add_1                                     type: <keras.layers.merge.Add object at 0x7f4f529ab5f8>
#     >layer 17 : name : res2a_out                                 type: <keras.layers.core.Activation object at 0x7f4f529499b0>
#     >layer 18 : name : res2b_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52949ac8>
#     >layer 19 : name : bn2b_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f5296ee48>
#     >layer 20 : name : activation_4                              type: <keras.layers.core.Activation object at 0x7f4f52904438>
#     >layer 21 : name : res2b_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5291c908>
#     >layer 22 : name : bn2b_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f5291c748>
#     >layer 23 : name : activation_5                              type: <keras.layers.core.Activation object at 0x7f4f528c22e8>
#     >layer 24 : name : res2b_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52870438>
#     >layer 25 : name : bn2b_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52870278>
#     >layer 26 : name : add_2                                     type: <keras.layers.merge.Add object at 0x7f4f528940f0>
#     >layer 27 : name : res2b_out                                 type: <keras.layers.core.Activation object at 0x7f4f528ae9e8>
#     >layer 28 : name : res2c_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f528aed68>
#     >layer 29 : name : bn2c_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52857cc0>
#     >layer 30 : name : activation_6                              type: <keras.layers.core.Activation object at 0x7f4f5286b4a8>
#     >layer 31 : name : res2c_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5281aba8>
#     >layer 32 : name : bn2c_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52805780>
#     >layer 33 : name : activation_7                              type: <keras.layers.core.Activation object at 0x7f4f5282cbe0>
#     >layer 34 : name : res2c_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f527d9908>
#     >layer 35 : name : bn2c_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f527d9748>
#     >layer 36 : name : add_3                                     type: <keras.layers.merge.Add object at 0x7f4f52780438>
#     >layer 37 : name : res2c_out                                 type: <keras.layers.core.Activation object at 0x7f4f527ad390>
#     >layer 38 : name : res3a_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f527adc18>
#     >layer 39 : name : bn3a_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52769c18>
#     >layer 40 : name : activation_8                              type: <keras.layers.core.Activation object at 0x7f4f52751d30>
#     >layer 41 : name : res3a_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52710da0>
#     >layer 42 : name : bn3a_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52700ba8>
#     >layer 43 : name : activation_9                              type: <keras.layers.core.Activation object at 0x7f4f52723438>
#     >layer 44 : name : res3a_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f526bbf98>
#     >layer 45 : name : res3a_branch1                             type: <keras.layers.convolutional.Conv2D object at 0x7f4f526772b0>
#     >layer 46 : name : bn3a_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f526d4a20>
#     >layer 47 : name : bn3a_branch1                              type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52693b00>
#     >layer 48 : name : add_4                                     type: <keras.layers.merge.Add object at 0x7f4f5263a6a0>
#     >layer 49 : name : res3a_out                                 type: <keras.layers.core.Activation object at 0x7f4f52669518>
#     >layer 50 : name : res3b_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52669da0>
#     >layer 51 : name : bn3b_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52623d30>
#     >layer 52 : name : activation_10                             type: <keras.layers.core.Activation object at 0x7f4f5260cc88>
#     >layer 53 : name : res3b_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f525cce10>
#     >layer 54 : name : bn3b_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f525bbc18>
#     >layer 55 : name : activation_11                             type: <keras.layers.core.Activation object at 0x7f4f52575c18>
#     >layer 56 : name : res3b_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5258e358>
#     >layer 57 : name : bn3b_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f5259eba8>
#     >layer 58 : name : add_5                                     type: <keras.layers.merge.Add object at 0x7f4f525335c0>
#     >layer 59 : name : res3b_out                                 type: <keras.layers.core.Activation object at 0x7f4f52550860>
#     >layer 60 : name : res3c_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52550be0>
#     >layer 61 : name : bn3c_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f524f4f28>
#     >layer 62 : name : activation_12                             type: <keras.layers.core.Activation object at 0x7f4f52507400>
#     >layer 63 : name : res3c_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52523c50>
#     >layer 64 : name : bn3c_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52523a90>
#     >layer 65 : name : activation_13                             type: <keras.layers.core.Activation object at 0x7f4f524c9b00>
#     >layer 66 : name : res3c_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f524758d0>
#     >layer 67 : name : bn3c_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52475710>
#     >layer 68 : name : add_6                                     type: <keras.layers.merge.Add object at 0x7f4f5249c390>
#     >layer 69 : name : res3c_out                                 type: <keras.layers.core.Activation object at 0x7f4f5244a2e8>
#     >layer 70 : name : res3d_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5244ab70>
#     >layer 71 : name : bn3d_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f5245add8>
#     >layer 72 : name : activation_14                             type: <keras.layers.core.Activation object at 0x7f4f5246dc88>
#     >layer 73 : name : res3d_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5242ce10>
#     >layer 74 : name : bn3d_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f5241da58>
#     >layer 75 : name : activation_15                             type: <keras.layers.core.Activation object at 0x7f4f523c2128>
#     >layer 76 : name : res3d_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f523d6f98>
#     >layer 77 : name : bn3d_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f523ee940>
#     >layer 78 : name : add_7                                     type: <keras.layers.merge.Add object at 0x7f4f523955f8>
#     >layer 79 : name : res3d_out                                 type: <keras.layers.core.Activation object at 0x7f4f523afa20>
#     >layer 80 : name : res4a_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f523afb38>
#     >layer 81 : name : bn4a_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f523565c0>
#     >layer 82 : name : activation_16                             type: <keras.layers.core.Activation object at 0x7f4f52369240>
#     >layer 83 : name : res4a_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52304b00>
#     >layer 84 : name : bn4a_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52304e10>
#     >layer 85 : name : activation_17                             type: <keras.layers.core.Activation object at 0x7f4f523285f8>
#     >layer 86 : name : res4a_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f522d5710>
#     >layer 87 : name : res4a_branch1                             type: <keras.layers.convolutional.Conv2D object at 0x7f4f5227b0f0>
#     >layer 88 : name : bn4a_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f522d5550>
#     >layer 89 : name : bn4a_branch1                              type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f522ac9e8>
#     >layer 90 : name : add_8                                     type: <keras.layers.merge.Add object at 0x7f4f5224e908>
#     >layer 91 : name : res4a_out                                 type: <keras.layers.core.Activation object at 0x7f4f52265c18>
#     >layer 92 : name : res4b_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52265b38>
#     >layer 93 : name : bn4b_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52210c18>
#     >layer 94 : name : activation_18                             type: <keras.layers.core.Activation object at 0x7f4f522223c8>
#     >layer 95 : name : res4b_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f521bdba8>
#     >layer 96 : name : bn4b_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f521bd9e8>
#     >layer 97 : name : activation_19                             type: <keras.layers.core.Activation object at 0x7f4f521e55c0>
#     >layer 98 : name : res4b_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f521917f0>
#     >layer 99 : name : bn4b_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f52191630>
#     >layer 100 : name : add_9                                     type: <keras.layers.merge.Add object at 0x7f4f52136198>
#     >layer 101 : name : res4b_out                                 type: <keras.layers.core.Activation object at 0x7f4f521652b0>
#     >layer 102 : name : res4c_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f52165b38>
#     >layer 103 : name : bn4c_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f520f6d30>
#     >layer 104 : name : activation_20                             type: <keras.layers.core.Activation object at 0x7f4f52109be0>
#     >layer 105 : name : res4c_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f520cabe0>
#     >layer 106 : name : bn4c_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f520ba9e8>
#     >layer 107 : name : activation_21                             type: <keras.layers.core.Activation object at 0x7f4f520dc2b0>
#     >layer 108 : name : res4c_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5208c8d0>
#     >layer 109 : name : bn4c_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f520739e8>
#     >layer 110 : name : add_10                                    type: <keras.layers.merge.Add object at 0x7f4f5209cdd8>
#     >layer 111 : name : res4c_out                                 type: <keras.layers.core.Activation object at 0x7f4f5204d978>
#     >layer 112 : name : res4d_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f5204da90>
#     >layer 113 : name : bn4d_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51ff3550>
#     >layer 114 : name : activation_22                             type: <keras.layers.core.Activation object at 0x7f4f520062b0>
#     >layer 115 : name : res4d_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f520209b0>
#     >layer 116 : name : bn4d_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f520207f0>
#     >layer 117 : name : activation_23                             type: <keras.layers.core.Activation object at 0x7f4f51fc53c8>
#     >layer 118 : name : res4d_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51f735f8>
#     >layer 119 : name : bn4d_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51f73438>
#     >layer 120 : name : add_11                                    type: <keras.layers.merge.Add object at 0x7f4f51f970f0>
#     >layer 121 : name : res4d_out                                 type: <keras.layers.core.Activation object at 0x7f4f51f47048>
#     >layer 122 : name : res4e_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51f47908>
#     >layer 123 : name : bn4e_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51f55cf8>
#     >layer 124 : name : activation_24                             type: <keras.layers.core.Activation object at 0x7f4f51f69860>
#     >layer 125 : name : res4e_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51f05fd0>
#     >layer 126 : name : bn4e_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51f18a58>
#     >layer 127 : name : activation_25                             type: <keras.layers.core.Activation object at 0x7f4f51ebe518>
#     >layer 128 : name : res4e_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51eed3c8>
#     >layer 129 : name : bn4e_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51edb7b8>
#     >layer 130 : name : add_12                                    type: <keras.layers.merge.Add object at 0x7f4f51e80c18>
#     >layer 131 : name : res4e_out                                 type: <keras.layers.core.Activation object at 0x7f4f51ead780>
#     >layer 132 : name : res4f_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51eadf60>
#     >layer 133 : name : bn4f_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51e54860>
#     >layer 134 : name : activation_26                             type: <keras.layers.core.Activation object at 0x7f4f51e67160>
#     >layer 135 : name : res4f_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51e01828>
#     >layer 136 : name : bn4f_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51e01668>
#     >layer 137 : name : activation_27                             type: <keras.layers.core.Activation object at 0x7f4f51e265c0>
#     >layer 138 : name : res4f_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51de4d30>
#     >layer 139 : name : bn4f_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51dd2b38>
#     >layer 140 : name : add_13                                    type: <keras.layers.merge.Add object at 0x7f4f51d77390>
#     >layer 141 : name : res4f_out                                 type: <keras.layers.core.Activation object at 0x7f4f51d8ff28>
#     >layer 142 : name : res5a_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51d8ff98>
#     >layer 143 : name : bn5a_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51d39940>
#     >layer 144 : name : activation_28                             type: <keras.layers.core.Activation object at 0x7f4f51d4d8d0>
#     >layer 145 : name : res5a_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51d66f98>
#     >layer 146 : name : bn5a_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51cf9a90>
#     >layer 147 : name : activation_29                             type: <keras.layers.core.Activation object at 0x7f4f51d0ae48>
#     >layer 148 : name : res5a_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51cbaba8>
#     >layer 149 : name : res5a_branch1                             type: <keras.layers.convolutional.Conv2D object at 0x7f4f51ce0588>
#     >layer 150 : name : bn5a_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51cba9e8>
#     >layer 151 : name : bn5a_branch1                              type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51c8fe48>
#     >layer 152 : name : add_14                                    type: <keras.layers.merge.Add object at 0x7f4f51c33f28>
#     >layer 153 : name : res5a_out                                 type: <keras.layers.core.Activation object at 0x7f4f51c64b38>
#     >layer 154 : name : res5b_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51c64898>
#     >layer 155 : name : bn5b_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51bf5c88>
#     >layer 156 : name : activation_30                             type: <keras.layers.core.Activation object at 0x7f4f51c087f0>
#     >layer 157 : name : res5b_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51c22f60>
#     >layer 158 : name : bn5b_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51bb79e8>
#     >layer 159 : name : activation_31                             type: <keras.layers.core.Activation object at 0x7f4f51bda4a8>
#     >layer 160 : name : res5b_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51b75748>
#     >layer 161 : name : bn5b_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51b75c88>
#     >layer 162 : name : add_15                                    type: <keras.layers.merge.Add object at 0x7f4f51b9eba8>
#     >layer 163 : name : res5b_out                                 type: <keras.layers.core.Activation object at 0x7f4f51b4a710>
#     >layer 164 : name : res5c_branch2a                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51b4af98>
#     >layer 165 : name : bn5c_branch2a                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51af17f0>
#     >layer 166 : name : activation_32                             type: <keras.layers.core.Activation object at 0x7f4f51b050f0>
#     >layer 167 : name : res5c_branch2b                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51b1e7b8>
#     >layer 168 : name : bn5c_branch2b                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51b1e5f8>
#     >layer 169 : name : activation_33                             type: <keras.layers.core.Activation object at 0x7f4f51ac2198>
#     >layer 170 : name : res5c_branch2c                            type: <keras.layers.convolutional.Conv2D object at 0x7f4f51a714a8>
#     >layer 171 : name : bn5c_branch2c                             type: <mrcnn.batchnorm_layer.BatchNorm object at 0x7f4f51a712e8>
#     >layer 172 : name : add_16                                    type: <keras.layers.merge.Add object at 0x7f4f51a95160>
#     >layer 173 : name : res5c_out                                 type: <keras.layers.core.Activation object at 0x7f4f51a44978>
#     >layer 174 : name : fpn_c5p5                                  type: <keras.layers.convolutional.Conv2D object at 0x7f4f51a44358>
#     >layer 175 : name : fpn_p5upsampled                           type: <keras.layers.convolutional.UpSampling2D object at 0x7f4f51a6a630>
#     >layer 176 : name : fpn_c4p4                                  type: <keras.layers.convolutional.Conv2D object at 0x7f4f51a046a0>
#     >layer 177 : name : fpn_p4add                                 type: <keras.layers.merge.Add object at 0x7f4f51a57eb8>
#     >layer 178 : name : fpn_p4upsampled                           type: <keras.layers.convolutional.UpSampling2D object at 0x7f4f51a288d0>
#     >layer 179 : name : fpn_c3p3                                  type: <keras.layers.convolutional.Conv2D object at 0x7f4f51a28a90>
#     >layer 180 : name : fpn_p3add                                 type: <keras.layers.merge.Add object at 0x7f4f51a04940>
#     >layer 181 : name : fpn_p3upsampled                           type: <keras.layers.convolutional.UpSampling2D object at 0x7f4f519e91d0>
#     >layer 182 : name : fpn_c2p2                                  type: <keras.layers.convolutional.Conv2D object at 0x7f4f519e9828>
#     >layer 183 : name : fpn_p2add                                 type: <keras.layers.merge.Add object at 0x7f4f519c0400>
#     >layer 184 : name : fpn_p5                                    type: <keras.layers.convolutional.Conv2D object at 0x7f4f51949048>
#     >layer 185 : name : fpn_p2                                    type: <keras.layers.convolutional.Conv2D object at 0x7f4f519e9710>
#     >layer 186 : name : fpn_p3                                    type: <keras.layers.convolutional.Conv2D object at 0x7f4f5198ca58>
#     >layer 187 : name : fpn_p4                                    type: <keras.layers.convolutional.Conv2D object at 0x7f4f519a2470>
#     >layer 188 : name : fpn_p6                                    type: <keras.layers.pooling.MaxPooling2D object at 0x7f4f5196e470>
#     >layer 189 : name : rpn_model                                 type: <keras.engine.training.Model object at 0x7f4f51843080>
#     >layer 190 : name : rpn_class                                 type: <keras.layers.core.Lambda object at 0x7f4f518afeb8>
#     >layer 191 : name : rpn_bbox                                  type: <keras.layers.core.Lambda object at 0x7f4f5186d630>
#     >layer 192 : name : input_gt_boxes                            type: <keras.engine.topology.InputLayer object at 0x7f4f540078d0>
#     >layer 193 : name : rpn_proposal_rois                         type: <mrcnn.proposal_layer.ProposalLayer object at 0x7f4f518afef0>
#     >layer 194 : name : input_gt_class_ids                        type: <keras.engine.topology.InputLayer object at 0x7f4f54007cf8>
#     >layer 195 : name : lambda_1                                  type: <keras.layers.core.Lambda object at 0x7f4f54007fd0>
#     >layer 196 : name : proposal_targets                          type: <mrcnn.detect_tgt_layer_mod.DetectionTargetLayer_mod object at 0x7f4f5161cfd0>
#     >layer 197 : name : roi_align_classifier                      type: <mrcnn.roialign_layer.PyramidROIAlign object at 0x7f4f50c8fa90>
#     >layer 198 : name : mrcnn_class_conv1                         type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50c8ff28>
#     >layer 199 : name : mrcnn_class_bn1                           type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50b87f60>
#     >layer 200 : name : activation_34                             type: <keras.layers.core.Activation object at 0x7f4f50b9b588>
#     >layer 201 : name : mrcnn_class_conv2                         type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50b9b940>
#     >layer 202 : name : mrcnn_class_bn2                           type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50b40860>
#     >layer 203 : name : activation_35                             type: <keras.layers.core.Activation object at 0x7f4f50b6eb00>
#     >layer 204 : name : pool_squeeze                              type: <keras.layers.core.Lambda object at 0x7f4f50b01320>
#     >layer 205 : name : time_distributed_1                        type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50ad5668>
#     >layer 206 : name : mrcnn_class_logits                        type: <keras.layers.core.Lambda object at 0x7f4f50ad5208>
#     >layer 207 : name : mrcnn_bbox_fc                             type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50a77cf8>
#     >layer 208 : name : time_distributed_2                        type: <keras.layers.wrappers.TimeDistributed object at 0x7f4f50ad5fd0>
#     >layer 209 : name : reshape_1                                 type: <keras.layers.core.Reshape object at 0x7f4f50a77f28>
#     >layer 210 : name : input_image_meta                          type: <keras.engine.topology.InputLayer object at 0x7f4f5a934160>
#     >layer 211 : name : rpn_class_logits                          type: <keras.layers.core.Lambda object at 0x7f4f518aff60>
#     >layer 212 : name : mrcnn_class                               type: <keras.layers.core.Lambda object at 0x7f4f50ad52e8>
#     >layer 213 : name : mrcnn_bbox_regression                     type: <keras.layers.core.Lambda object at 0x7f4f50a77e80>
#     >layer 214 : name : input_rpn_match                           type: <keras.engine.topology.InputLayer object at 0x7f4f54007c50>
#     >layer 215 : name : input_rpn_bbox                            type: <keras.engine.topology.InputLayer object at 0x7f4f54007d68>
#     >layer 216 : name : lambda_4                                  type: <keras.layers.core.Lambda object at 0x7f4f5186d780>
#     >layer 217 : name : rpn_class_loss                            type: <keras.layers.core.Lambda object at 0x7f4f50a77630>
#     >layer 218 : name : rpn_bbox_loss                             type: <keras.layers.core.Lambda object at 0x7f4f50208e80>
#     >layer 219 : name : mrcnn_class_loss                          type: <keras.layers.core.Lambda object at 0x7f4f50aa2278>
#     >layer 220 : name : mrcnn_bbox_loss                           type: <keras.layers.core.Lambda object at 0x7f4f4fffa710>
#     >layer 221 : name : cntxt_layer                               type: <mrcnn.chm_layer.CHMLayer object at 0x7f4f50a90ba8>
#     load_weights: Log directory set to : /home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5
#     set_log_dir(): Checkpoint path/filename set to          : /home/kbardool/models/newshape_fcn/shapes20180621T1554/mask_rcnn_shapes_{epoch:04d}.h5
#     set_log_dir(): Last completed epoch (self.epoch) set to : 566
#     Load weights complete :  /home/kbardool/models/newshape_mrcnn/shapes20180621T1554/mask_rcnn_shapes_0565.h5
#
# Configuration Parameters:
# -------------------------
# BACKBONE_SHAPES                [[32 32]
#  [16 16]
#  [ 8  8]
#  [ 4  4]
#  [ 2  2]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# CHECKPOINT_FOLDER              /home/kbardool/models/newshape_fcn
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# EPOCHS_TO_RUN                  300
# FCN_INPUT_SHAPE                [128 128]
# FCN_LAYERS                     False
# GPU_COUNT                      1
# IMAGES_PER_GPU                 2
# IMAGE_BUFFER                   20
# IMAGE_MAX_DIM                  128
# IMAGE_MIN_DIM                  128
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [128 128   3]
# LAST_EPOCH_RAN                 0
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  1e-06
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MAX_SHAPES_PER_IMAGE           15
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# MIN_LR                         1e-10
# MIN_SHAPES_PER_IMAGE           1
# NAME                           shapes
# NUM_CLASSES                    7
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# REDUCE_LR_COOLDOWN             30
# REDUCE_LR_FACTOR               0.2
# REDUCE_LR_PATIENCE             40
# ROI_POSITIVE_RATIO             0.33
# ROI_PROPOSAL_AREA_THRESHOLD    0
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                2
# TRAINING_IMAGES                10000
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_IMAGES              2500
# VALIDATION_STEPS               100
# WEIGHT_DECAY                   0.0002

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names, limit=6)

# %% [markdown]
# ###  Print some model information

# %%
print('\n Inputs: ') 
for i, out in enumerate(model.keras_model.inputs):
    print(i , '    ', out)

print('\n Outputs: ') 
for i, out in enumerate(model.keras_model.outputs):
    print(i , '    ', out)
# Out:
#  Inputs:
# 0      Tensor("input_image:0", shape=(?, 128, 128, 3), dtype=float32)
# 1      Tensor("input_image_meta:0", shape=(?, ?), dtype=float32)
# 2      Tensor("input_rpn_match:0", shape=(?, ?, 1), dtype=int32)
# 3      Tensor("input_rpn_bbox:0", shape=(?, ?, 4), dtype=float32)
# 4      Tensor("input_gt_class_ids:0", shape=(?, ?), dtype=int32)
# 5      Tensor("input_gt_boxes:0", shape=(?, ?, 4), dtype=float32)
# 6      Tensor("input_gt_masks:0", shape=(?, 56, 56, ?), dtype=bool)
#
#  Outputs:
# 0      Tensor("rpn_class_logits/rpn_class_logits:0", shape=(?, ?, 2), dtype=float32)
# 1      Tensor("rpn_class/rpn_class:0", shape=(?, ?, 2), dtype=float32)
# 2      Tensor("rpn_bbox/rpn_bbox:0", shape=(?, ?, 4), dtype=float32)
# 3      Tensor("rpn_proposal_rois/rpn_roi_proposals:0", shape=(2, ?, ?), dtype=float32)
# 4      Tensor("proposal_targets/output_rois:0", shape=(2, ?, ?), dtype=float32)
# 5      Tensor("proposal_targets/target_class_ids:0", shape=(2, ?), dtype=int32)
# 6      Tensor("proposal_targets/target_bbox_deltas:0", shape=(2, ?, ?), dtype=float32)
# 7      Tensor("proposal_targets/roi_gt_boxes:0", shape=(2, ?, ?), dtype=float32)
# 8      Tensor("mrcnn_class_logits/mrcnn_class_logits:0", shape=(?, 32, 7), dtype=float32)
# 9      Tensor("mrcnn_class/mrcnn_class:0", shape=(?, 32, 7), dtype=float32)
# 10      Tensor("mrcnn_bbox_regression/mrcnn_bbox:0", shape=(?, 32, 7, 4), dtype=float32)
# 11      Tensor("rpn_class_loss/rpn_class_loss:0", shape=(1, 1), dtype=float32)
# 12      Tensor("rpn_bbox_loss/rpn_bbox_loss:0", shape=(1, 1), dtype=float32)
# 13      Tensor("mrcnn_class_loss/mrcnn_class_loss:0", shape=(1, 1), dtype=float32)
# 14      Tensor("mrcnn_bbox_loss/mrcnn_bbox_loss:0", shape=(1, 1), dtype=float32)
# 15      Tensor("cntxt_layer/pred_heatmap_norm:0", shape=(2, 128, 128, 7), dtype=float32)
# 16      Tensor("cntxt_layer/gt_heatmap_norm:0", shape=(2, 128, 128, 7), dtype=float32)
# 17      Tensor("cntxt_layer/pred_heatmap_scores:0", shape=(?, ?, ?, ?), dtype=float32)
# 18      Tensor("cntxt_layer/gt_heatmap_scores:0", shape=(?, ?, ?, ?), dtype=float32)

# %%
print('\n Outputs: ') 
pp.pprint(model.keras_model.outputs)
# print('\n Losses (model.metrics_names): ') 
# pp.pprint(model.get_deduped_metrics_names())
# model.keras_model.summary(line_length = 150)

# %% [markdown]
# ## Training mrcnn, fpn, rpn layers

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
# Wed 09-05-2018
# train_layers = ['mrcnn', 'fpn','rpn']
# loss_names   = [  "rpn_class_loss", "rpn_bbox_loss" , "mrcnn_class_loss", "mrcnn_bbox_loss", "mrcnn_mask_loss"]
train_layers = ['mrcnn', 'fpn','rpn']
loss_names   = [  "rpn_class_loss", "rpn_bbox_loss" , "mrcnn_class_loss", "mrcnn_bbox_loss" ]
config.STEPS_PER_EPOCH        = 8
config.EARLY_STOP_PATIENCE    = 70
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs_to_run = config.EPOCHS_TO_RUN,
#             epochs = 2500,
#             epochs_to_run =2, 
            layers = train_layers,
            losses= loss_names
            )
# Out:
# ['mrcnn', 'fpn', 'rpn']
# ['(mrcnn\\_.*)', '(fpn\\_.*)', '(rpn\\_.*)']
# layers regex : (mrcnn\_.*)|(fpn\_.*)|(rpn\_.*)
#  174  fpn_c5p5               (Conv2D              )   TRAIN
#  176  fpn_c4p4               (Conv2D              )   TRAIN
#  179  fpn_c3p3               (Conv2D              )   TRAIN
#  182  fpn_c2p2               (Conv2D              )   TRAIN
#  184  fpn_p5                 (Conv2D              )   TRAIN
#  185  fpn_p2                 (Conv2D              )   TRAIN
#  186  fpn_p3                 (Conv2D              )   TRAIN
#  187  fpn_p4                 (Conv2D              )   TRAIN
#        1  rpn_conv_shared        (Conv2D              )   TRAIN
#        2  rpn_class_raw          (Conv2D              )   TRAIN
#        4  rpn_bbox_pred          (Conv2D              )   TRAIN
#  198  mrcnn_class_conv1      (TimeDistributed     )   TRAIN
#  199  mrcnn_class_bn1        (TimeDistributed     )   TRAIN
#  201  mrcnn_class_conv2      (TimeDistributed     )   TRAIN
#  202  mrcnn_class_bn2        (TimeDistributed     )   TRAIN
#  207  mrcnn_bbox_fc          (TimeDistributed     )   TRAIN
#
#
#  Compile Model :
# ----------------
#     losses        :  ['rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#     learning rate :  1e-06
#     momentum      :  0.9
#
#
#  Add losses:
# ----------------
#     losses:  ['rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#     keras_model.losses           : []
#
#     Loss: rpn_class_loss  Related Layer is : rpn_class_loss
#       >> Add add loss for  Tensor("rpn_class_loss/rpn_class_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: rpn_bbox_loss  Related Layer is : rpn_bbox_loss
#       >> Add add loss for  Tensor("rpn_bbox_loss/rpn_bbox_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: mrcnn_class_loss  Related Layer is : mrcnn_class_loss
#       >> Add add loss for  Tensor("mrcnn_class_loss/mrcnn_class_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: mrcnn_bbox_loss  Related Layer is : mrcnn_bbox_loss
#       >> Add add loss for  Tensor("mrcnn_bbox_loss/mrcnn_bbox_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#
# Keras model.losses :
# ---------------------
#    Tensor("Mean_8:0", shape=(1, 1), dtype=float32)    name: Mean_8:0
#    Tensor("Mean_9:0", shape=(1, 1), dtype=float32)    name: Mean_9:0
#    Tensor("Mean_11:0", shape=(1, 1), dtype=float32)    name: Mean_11:0
#    Tensor("Mean_10:0", shape=(1, 1), dtype=float32)    name: Mean_10:0
#
# Keras_model._losses:
# ---------------------
#    Tensor("Mean_8:0", shape=(1, 1), dtype=float32)    name: Mean_8:0
#    Tensor("Mean_9:0", shape=(1, 1), dtype=float32)    name: Mean_9:0
#    Tensor("Mean_10:0", shape=(1, 1), dtype=float32)    name: Mean_10:0
#    Tensor("Mean_11:0", shape=(1, 1), dtype=float32)    name: Mean_11:0
#
# Keras_model._per_input_losses:
# ------------------------------
#    None    name: <class 'NoneType'>
# {   None: [   <tf.Tensor 'Mean_8:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_9:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_10:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_11:0' shape=(1, 1) dtype=float32>]}
#
# L2 Regularization losses:
# -------------------------
#    Tensor("truediv_28:0", shape=(), dtype=float32)    name: truediv_28:0
#    Tensor("truediv_29:0", shape=(), dtype=float32)    name: truediv_29:0
#    Tensor("truediv_30:0", shape=(), dtype=float32)    name: truediv_30:0
#    Tensor("truediv_31:0", shape=(), dtype=float32)    name: truediv_31:0
#    Tensor("truediv_32:0", shape=(), dtype=float32)    name: truediv_32:0
#    Tensor("truediv_33:0", shape=(), dtype=float32)    name: truediv_33:0
#    Tensor("truediv_34:0", shape=(), dtype=float32)    name: truediv_34:0
#    Tensor("truediv_35:0", shape=(), dtype=float32)    name: truediv_35:0
#    Tensor("truediv_36:0", shape=(), dtype=float32)    name: truediv_36:0
#    Tensor("truediv_37:0", shape=(), dtype=float32)    name: truediv_37:0
#    Tensor("truediv_38:0", shape=(), dtype=float32)    name: truediv_38:0
#    Tensor("truediv_39:0", shape=(), dtype=float32)    name: truediv_39:0
#    Tensor("truediv_40:0", shape=(), dtype=float32)    name: truediv_40:0
#    Tensor("truediv_41:0", shape=(), dtype=float32)    name: truediv_41:0
#    Tensor("truediv_42:0", shape=(), dtype=float32)    name: truediv_42:0
#    Tensor("truediv_43:0", shape=(), dtype=float32)    name: truediv_43:0
#    Tensor("truediv_44:0", shape=(), dtype=float32)    name: truediv_44:0
#    Tensor("truediv_45:0", shape=(), dtype=float32)    name: truediv_45:0
#    Tensor("truediv_46:0", shape=(), dtype=float32)    name: truediv_46:0
#    Tensor("truediv_47:0", shape=(), dtype=float32)    name: truediv_47:0
#    Tensor("truediv_48:0", shape=(), dtype=float32)    name: truediv_48:0
#    Tensor("truediv_49:0", shape=(), dtype=float32)    name: truediv_49:0
#    Tensor("truediv_50:0", shape=(), dtype=float32)    name: truediv_50:0
#    Tensor("truediv_51:0", shape=(), dtype=float32)    name: truediv_51:0
#    Tensor("truediv_52:0", shape=(), dtype=float32)    name: truediv_52:0
#    Tensor("truediv_53:0", shape=(), dtype=float32)    name: truediv_53:0
#    Tensor("truediv_54:0", shape=(), dtype=float32)    name: truediv_54:0
#    Tensor("truediv_55:0", shape=(), dtype=float32)    name: truediv_55:0
#
#     Final list of keras_model.losses
#     --------------------------------
# [   <tf.Tensor 'Mean_8:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'AddN_1:0' shape=() dtype=float32>,
#     <tf.Tensor 'Mean_9:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_11:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_10:0' shape=(1, 1) dtype=float32>]
#
#  Length of Keras_Model.outputs: 19
#  Model.compile (821) Compute total loss:
#     i:  0  targets:  None  outputs:  Tensor("rpn_class_logits/rpn_class_logits:0", shape=(?, ?, 2), dtype=float32)  weighted loss:  None
#     i:  1  targets:  None  outputs:  Tensor("rpn_class/rpn_class:0", shape=(?, ?, 2), dtype=float32)  weighted loss:  None
#     i:  2  targets:  None  outputs:  Tensor("rpn_bbox/rpn_bbox:0", shape=(?, ?, 4), dtype=float32)  weighted loss:  None
#     i:  3  targets:  None  outputs:  Tensor("rpn_proposal_rois/rpn_roi_proposals:0", shape=(2, ?, ?), dtype=float32)  weighted loss:  None
#     i:  4  targets:  None  outputs:  Tensor("proposal_targets/output_rois:0", shape=(2, ?, ?), dtype=float32)  weighted loss:  None
#     i:  5  targets:  None  outputs:  Tensor("proposal_targets/target_class_ids:0", shape=(2, ?), dtype=int32)  weighted loss:  None
#     i:  6  targets:  None  outputs:  Tensor("proposal_targets/target_bbox_deltas:0", shape=(2, ?, ?), dtype=float32)  weighted loss:  None
#     i:  7  targets:  None  outputs:  Tensor("proposal_targets/roi_gt_boxes:0", shape=(2, ?, ?), dtype=float32)  weighted loss:  None
#     i:  8  targets:  None  outputs:  Tensor("mrcnn_class_logits/mrcnn_class_logits:0", shape=(?, 32, 7), dtype=float32)  weighted loss:  None
#     i:  9  targets:  None  outputs:  Tensor("mrcnn_class/mrcnn_class:0", shape=(?, 32, 7), dtype=float32)  weighted loss:  None
#     i:  10  targets:  None  outputs:  Tensor("mrcnn_bbox_regression/mrcnn_bbox:0", shape=(?, 32, 7, 4), dtype=float32)  weighted loss:  None
#     i:  11  targets:  None  outputs:  Tensor("rpn_class_loss/rpn_class_loss:0", shape=(1, 1), dtype=float32)  weighted loss:  None
#     i:  12  targets:  None  outputs:  Tensor("rpn_bbox_loss/rpn_bbox_loss:0", shape=(1, 1), dtype=float32)  weighted loss:  None
#     i:  13  targets:  None  outputs:  Tensor("mrcnn_class_loss/mrcnn_class_loss:0", shape=(1, 1), dtype=float32)  weighted loss:  None
#     i:  14  targets:  None  outputs:  Tensor("mrcnn_bbox_loss/mrcnn_bbox_loss:0", shape=(1, 1), dtype=float32)  weighted loss:  None
#     i:  15  targets:  None  outputs:  Tensor("cntxt_layer/pred_heatmap_norm:0", shape=(2, 128, 128, 7), dtype=float32)  weighted loss:  None
#     i:  16  targets:  None  outputs:  Tensor("cntxt_layer/gt_heatmap_norm:0", shape=(2, 128, 128, 7), dtype=float32)  weighted loss:  None
#     i:  17  targets:  None  outputs:  Tensor("cntxt_layer/pred_heatmap_scores:0", shape=(?, ?, ?, ?), dtype=float32)  weighted loss:  None
#     i:  18  targets:  None  outputs:  Tensor("cntxt_layer/gt_heatmap_scores:0", shape=(?, ?, ?, ?), dtype=float32)  weighted loss:  None
#     Add  Tensor("Mean_8:0", shape=(1, 1), dtype=float32) to total_loss  Mean_8:0
#     Add  Tensor("AddN_1:0", shape=(), dtype=float32) to total_loss  AddN_1:0
#     Add  Tensor("Mean_9:0", shape=(1, 1), dtype=float32) to total_loss  Mean_9:0
#     Add  Tensor("Mean_11:0", shape=(1, 1), dtype=float32) to total_loss  Mean_11:0
#     Add  Tensor("Mean_10:0", shape=(1, 1), dtype=float32) to total_loss  Mean_10:0
#
#  Add Metrics :
# --------------
#  Initial Keras metric_names: ['loss']
#     Loss name : rpn_class_loss  Related Layer is : rpn_class_loss
#       >> Add metric  rpn_class_loss  with metric tensor:  rpn_class_loss/rpn_class_loss:0  to list of metrics ...
#     Loss name : rpn_bbox_loss  Related Layer is : rpn_bbox_loss
#       >> Add metric  rpn_bbox_loss  with metric tensor:  rpn_bbox_loss/rpn_bbox_loss:0  to list of metrics ...
#     Loss name : mrcnn_class_loss  Related Layer is : mrcnn_class_loss
#       >> Add metric  mrcnn_class_loss  with metric tensor:  mrcnn_class_loss/mrcnn_class_loss:0  to list of metrics ...
#     Loss name : mrcnn_bbox_loss  Related Layer is : mrcnn_bbox_loss
#       >> Add metric  mrcnn_bbox_loss  with metric tensor:  mrcnn_bbox_loss/mrcnn_bbox_loss:0  to list of metrics ...
#  Final Keras metric_names:
# ['loss', 'rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#
# Starting at epoch   566 of 866 epochs. LR=1e-06
#
# Steps per epochs    8
# Batch size          2
# Checkpoint Path:    /home/kbardool/models/newshape_fcn/shapes20180621T1554/mask_rcnn_shapes_{epoch:04d}.h5
# Weight Decay:       0.0002
# VALIDATION_STEPS    100
# REDUCE_LR_FACTOR    0.2
# REDUCE_LR_COOLDOWN  30
# REDUCE_LR_PATIENCE  40
# MIN_LR              1e-10
# EARLY_STOP_PATIENCE 70
# /home/kbardool/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
#   Make training function -------------------------------
#  self.total_loss : loss/add_4:0
# <tf.Tensor 'loss/add_4:0' shape=(1, 1) dtype=float32>
#  self.metrics_tensors : Mean_12:0
# [   <tf.Tensor 'Mean_12:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_13:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_14:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_15:0' shape=(1, 1) dtype=float32>]
#  updates :
# [   <tf.Tensor 'training/SGD/AssignAdd:0' shape=() dtype=int64_ref>,
#     <tf.Tensor 'training/SGD/Assign:0' shape=(1, 1, 2048, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_1:0' shape=(1, 1, 2048, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_2:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_3:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_4:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_5:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_6:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_7:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_8:0' shape=(1, 1, 512, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_9:0' shape=(1, 1, 512, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_10:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_11:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_12:0' shape=(1, 1, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_13:0' shape=(1, 1, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_14:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_15:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_16:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_17:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_18:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_19:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_20:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_21:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_22:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_23:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_24:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_25:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_26:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_27:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_28:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_29:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_30:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_31:0' shape=(256,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_32:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_33:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_34:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_35:0' shape=(512,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_36:0' shape=(1, 1, 512, 6) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_37:0' shape=(1, 1, 512, 6) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_38:0' shape=(6,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_39:0' shape=(6,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_40:0' shape=(1, 1, 512, 12) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_41:0' shape=(1, 1, 512, 12) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_42:0' shape=(12,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_43:0' shape=(12,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_44:0' shape=(7, 7, 256, 1024) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_45:0' shape=(7, 7, 256, 1024) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_46:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_47:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_48:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_49:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_50:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_51:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_52:0' shape=(1, 1, 1024, 1024) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_53:0' shape=(1, 1, 1024, 1024) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_54:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_55:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_56:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_57:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_58:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_59:0' shape=(1024,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_60:0' shape=(1024, 28) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_61:0' shape=(1024, 28) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_62:0' shape=(28,) dtype=float32_ref>,
#     <tf.Tensor 'training/SGD/Assign_63:0' shape=(28,) dtype=float32_ref>]
#   ------------------------------------------------------
# Epoch 567/866
# train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3007]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0112]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1544]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0907]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0443]]
# 1/8 [==>...........................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.3007]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0112]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.1544]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0907]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0443]], dtype=float32), 1]
#  - ETA: 28s - loss: 0.3007 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.1544 - mrcnn_class_loss: 0.0907 - mrcnn_bbox_loss: 0.0443train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.5845]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0373]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3406]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1255]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0811]]
# 2/8 [======>.......................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.8852]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0485]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.495]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2162]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1254]], dtype=float32), 2]
#  - ETA: 12s - loss: 0.4426 - rpn_class_loss: 0.0242 - rpn_bbox_loss: 0.2475 - mrcnn_class_loss: 0.1081 - mrcnn_bbox_loss: 0.0627train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4132]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.019]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1932]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1453]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0557]]
# 3/8 [==========>...................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.2984]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0675]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.6882]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3614]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1811]], dtype=float32), 3]
#  - ETA: 7s - loss: 0.4328 - rpn_class_loss: 0.0225 - rpn_bbox_loss: 0.2294 - mrcnn_class_loss: 0.1205 - mrcnn_bbox_loss: 0.0604 train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2627]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0121]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2019]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0129]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0358]]
# 4/8 [==============>...............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.5611]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0795]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.8901]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3743]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2169]], dtype=float32), 4]
#  - ETA: 4s - loss: 0.3903 - rpn_class_loss: 0.0199 - rpn_bbox_loss: 0.2225 - mrcnn_class_loss: 0.0936 - mrcnn_bbox_loss: 0.0542train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0651]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0052]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.028]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0121]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0198]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.6263]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0847]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.9181]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3864]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2368]], dtype=float32), 5]
#  - ETA: 2s - loss: 0.3253 - rpn_class_loss: 0.0169 - rpn_bbox_loss: 0.1836 - mrcnn_class_loss: 0.0773 - mrcnn_bbox_loss: 0.0474train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2326]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0229]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1144]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0481]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0472]]
# 6/8 [=====================>........]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.8588]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1076]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.0325]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.4345]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2839]], dtype=float32), 6]
#  - ETA: 1s - loss: 0.3098 - rpn_class_loss: 0.0179 - rpn_bbox_loss: 0.1721 - mrcnn_class_loss: 0.0724 - mrcnn_bbox_loss: 0.0473train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2916]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0078]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1728]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.05]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0611]]
# 7/8 [=========================>....]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.1505]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1153]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.2053]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.4845]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.345]], dtype=float32), 7]
#  - ETA: 0s - loss: 0.3072 - rpn_class_loss: 0.0165 - rpn_bbox_loss: 0.1722 - mrcnn_class_loss: 0.0692 - mrcnn_bbox_loss: 0.0493train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4205]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0236]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.278]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0634]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0556]]
# 8/8 [==============================]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.8924]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1563]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.6687]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.6163]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.4506]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ val_loss ]    self._values[k]:  [array([[0.4512]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_class_loss ]    self._values[k]:  [array([[0.0249]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_bbox_loss ]    self._values[k]:  [array([[0.31]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_class_loss ]    self._values[k]:  [array([[0.0543]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_bbox_loss ]    self._values[k]:  [array([[0.062]], dtype=float32), 1]
#  - 6s 729ms/step - loss: 0.3214 - rpn_class_loss: 0.0174 - rpn_bbox_loss: 0.1854 - mrcnn_class_loss: 0.0685 - mrcnn_bbox_loss: 0.0501 - val_loss: 0.4512 - val_rpn_class_loss: 0.0249 - val_rpn_bbox_loss: 0.3100 - val_mrcnn_class_loss: 0.0543 - val_mrcnn_bbox_loss: 0.0620
#
# Epoch 00567: val_loss imp from inf to 0.45116168, saving model to /home/kbardool/models/newshape_fcn/shapes20180621T1554/mask_rcnn_shapes_0567.h5
# Epoch 568/866
# train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1486]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0036]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1093]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0061]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0296]]
# 1/8 [==>...........................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.1486]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0036]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.1093]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0061]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0296]], dtype=float32), 1]
#  - ETA: 0s - loss: 0.1486 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.1093 - mrcnn_class_loss: 0.0061 - mrcnn_bbox_loss: 0.0296train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1546]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0023]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0946]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0241]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0334]]
# 2/8 [======>.......................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.3032]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0059]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.2039]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0303]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.063]], dtype=float32), 2]
#  - ETA: 0s - loss: 0.1516 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1020 - mrcnn_class_loss: 0.0151 - mrcnn_bbox_loss: 0.0315train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3863]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0219]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1159]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1608]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0876]]
# 3/8 [==========>...................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.6895]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0278]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.3199]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.191]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1507]], dtype=float32), 3]
#  - ETA: 0s - loss: 0.2298 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.1066 - mrcnn_class_loss: 0.0637 - mrcnn_bbox_loss: 0.0502train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0901]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0051]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0646]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0039]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0165]]
# 4/8 [==============>...............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.7796]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0329]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.3844]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.1949]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1671]], dtype=float32), 4]
#  - ETA: 0s - loss: 0.1949 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.0961 - mrcnn_class_loss: 0.0487 - mrcnn_bbox_loss: 0.0418train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2214]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0082]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1397]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0247]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0486]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.0009]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0411]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.5241]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2197]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2158]], dtype=float32), 5]
#  - ETA: 0s - loss: 0.2002 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.1048 - mrcnn_class_loss: 0.0439 - mrcnn_bbox_loss: 0.0432train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2359]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0153]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1583]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0138]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0483]]
# 6/8 [=====================>........]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.2368]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0564]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.6825]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2335]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2641]], dtype=float32), 6]
#  - ETA: 0s - loss: 0.2061 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.1137 - mrcnn_class_loss: 0.0389 - mrcnn_bbox_loss: 0.0440train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1403]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0098]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0762]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0248]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0294]]
# 7/8 [=========================>....]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.3771]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0662]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.7586]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2584]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2935]], dtype=float32), 7]
#  - ETA: 0s - loss: 0.1967 - rpn_class_loss: 0.0095 - rpn_bbox_loss: 0.1084 - mrcnn_class_loss: 0.0369 - mrcnn_bbox_loss: 0.0419train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.5377]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0264]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2823]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1635]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0654]]
# 8/8 [==============================]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.1541]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1042]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.1711]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.4746]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.4038]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ val_loss ]    self._values[k]:  [array([[0.5652]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_class_loss ]    self._values[k]:  [array([[0.0249]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_bbox_loss ]    self._values[k]:  [array([[0.31]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_class_loss ]    self._values[k]:  [array([[0.117]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1133]], dtype=float32), 1]
#  - 1s 144ms/step - loss: 0.2393 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.1301 - mrcnn_class_loss: 0.0527 - mrcnn_bbox_loss: 0.0449 - val_loss: 0.5652 - val_rpn_class_loss: 0.0249 - val_rpn_bbox_loss: 0.3100 - val_mrcnn_class_loss: 0.1170 - val_mrcnn_bbox_loss: 0.1133
#
# Epoch 00568: val_loss did not improve
# Epoch 569/866
# train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3703]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0219]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.267]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0163]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.065]]
# 1/8 [==>...........................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.3703]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0219]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.267]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0163]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.065]], dtype=float32), 1]
#  - ETA: 0s - loss: 0.3703 - rpn_class_loss: 0.0219 - rpn_bbox_loss: 0.2670 - mrcnn_class_loss: 0.0163 - mrcnn_bbox_loss: 0.0650train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.11]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0019]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0837]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0063]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.018]]
# 2/8 [======>.......................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.4802]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0238]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.3507]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0226]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0831]], dtype=float32), 2]
#  - ETA: 0s - loss: 0.2401 - rpn_class_loss: 0.0119 - rpn_bbox_loss: 0.1753 - mrcnn_class_loss: 0.0113 - mrcnn_bbox_loss: 0.0415train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.5813]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0097]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.458]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0656]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0479]]
# 3/8 [==========>...................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.0616]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0335]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.8087]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0882]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.131]], dtype=float32), 3]
#  - ETA: 0s - loss: 0.3539 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.2696 - mrcnn_class_loss: 0.0294 - mrcnn_bbox_loss: 0.0437train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2868]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0168]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2066]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0097]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0537]]
# 4/8 [==============>...............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.3484]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0503]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.0154]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0979]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1846]], dtype=float32), 4]
#  - ETA: 0s - loss: 0.3371 - rpn_class_loss: 0.0126 - rpn_bbox_loss: 0.2538 - mrcnn_class_loss: 0.0245 - mrcnn_bbox_loss: 0.0462train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2037]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0282]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0964]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0223]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0567]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.5521]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0785]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.1118]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.1202]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2414]], dtype=float32), 5]
#  - ETA: 0s - loss: 0.3104 - rpn_class_loss: 0.0157 - rpn_bbox_loss: 0.2224 - mrcnn_class_loss: 0.0240 - mrcnn_bbox_loss: 0.0483train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.5892]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0137]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4195]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0652]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0908]]
# 6/8 [=====================>........]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.1413]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0922]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.5313]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.1854]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.3321]], dtype=float32), 6]
#  - ETA: 0s - loss: 0.3569 - rpn_class_loss: 0.0154 - rpn_bbox_loss: 0.2552 - mrcnn_class_loss: 0.0309 - mrcnn_bbox_loss: 0.0554train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2153]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0054]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1127]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0571]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0401]]
# 7/8 [=========================>....]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.3567]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0976]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.6439]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2425]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.3723]], dtype=float32), 7]
#  - ETA: 0s - loss: 0.3367 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.2348 - mrcnn_class_loss: 0.0346 - mrcnn_bbox_loss: 0.0532train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2698]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0135]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2303]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0073]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0187]]
# 8/8 [==============================]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.9548]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1249]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[2.1085]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.281]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.4399]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ val_loss ]    self._values[k]:  [array([[0.4653]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_class_loss ]    self._values[k]:  [array([[0.0249]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_bbox_loss ]    self._values[k]:  [array([[0.31]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_class_loss ]    self._values[k]:  [array([[0.0666]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0638]], dtype=float32), 1]
#  - 1s 135ms/step - loss: 0.3283 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.2343 - mrcnn_class_loss: 0.0312 - mrcnn_bbox_loss: 0.0489 - val_loss: 0.4653 - val_rpn_class_loss: 0.0249 - val_rpn_bbox_loss: 0.3100 - val_mrcnn_class_loss: 0.0666 - val_mrcnn_bbox_loss: 0.0638
#
# Epoch 00569: val_loss did not improve
# Epoch 570/866
# train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.267]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0123]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1759]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0131]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0656]]
# 1/8 [==>...........................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.267]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0123]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.1759]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0131]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0656]], dtype=float32), 1]
#  - ETA: 0s - loss: 0.2670 - rpn_class_loss: 0.0123 - rpn_bbox_loss: 0.1759 - mrcnn_class_loss: 0.0131 - mrcnn_bbox_loss: 0.0656train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2942]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0118]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1693]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.039]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.074]]
# 2/8 [======>.......................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.5611]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0241]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.3452]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0521]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1397]], dtype=float32), 2]
#  - ETA: 0s - loss: 0.2806 - rpn_class_loss: 0.0120 - rpn_bbox_loss: 0.1726 - mrcnn_class_loss: 0.0261 - mrcnn_bbox_loss: 0.0698train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4953]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0236]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2096]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1761]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.086]]
# 3/8 [==========>...................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.0565]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0477]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.5548]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2282]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2257]], dtype=float32), 3]
#  - ETA: 0s - loss: 0.3522 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.1849 - mrcnn_class_loss: 0.0761 - mrcnn_bbox_loss: 0.0752train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2968]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0157]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1313]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1045]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0453]]
# 4/8 [==============>...............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.3533]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0633]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.6861]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3327]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2709]], dtype=float32), 4]
#  - ETA: 0s - loss: 0.3383 - rpn_class_loss: 0.0158 - rpn_bbox_loss: 0.1715 - mrcnn_class_loss: 0.0832 - mrcnn_bbox_loss: 0.0677train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4376]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0234]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1686]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.165]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0805]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.7909]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0868]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.8546]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.4978]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.3515]], dtype=float32), 5]
# ...
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.1775]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3267]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2725]], dtype=float32), 4]
#  - ETA: 0s - loss: 0.4737 - rpn_class_loss: 0.0294 - rpn_bbox_loss: 0.2944 - mrcnn_class_loss: 0.0817 - mrcnn_bbox_loss: 0.0681train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1973]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0098]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1303]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0214]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0357]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.0919]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1275]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.3079]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.3481]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.3083]], dtype=float32), 5]
#  - ETA: 0s - loss: 0.4184 - rpn_class_loss: 0.0255 - rpn_bbox_loss: 0.2616 - mrcnn_class_loss: 0.0696 - mrcnn_bbox_loss: 0.0617train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.5714]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0304]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2949]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1498]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0962]]
# 6/8 [=====================>........]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[2.6634]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1579]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.6028]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.4978]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.4045]], dtype=float32), 6]
#  - ETA: 0s - loss: 0.4439 - rpn_class_loss: 0.0263 - rpn_bbox_loss: 0.2671 - mrcnn_class_loss: 0.0830 - mrcnn_bbox_loss: 0.0674train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3866]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.02]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2002]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1322]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0342]]
# 7/8 [=========================>....]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[3.0499]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.178]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.803]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.63]], dtype=float32), 7]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.4387]], dtype=float32), 7]
#  - ETA: 0s - loss: 0.4357 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.2576 - mrcnn_class_loss: 0.0900 - mrcnn_bbox_loss: 0.0627train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.46]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0131]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2605]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1031]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0832]]
# 8/8 [==============================]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[3.9487]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.215]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[2.3214]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.8247]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.5871]], dtype=float32), 9]
#
#  Prog bar Update:  Key: [ val_loss ]    self._values[k]:  [array([[0.4743]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_class_loss ]    self._values[k]:  [array([[0.0248]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_rpn_bbox_loss ]    self._values[k]:  [array([[0.3097]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_class_loss ]    self._values[k]:  [array([[0.042]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ val_mrcnn_bbox_loss ]    self._values[k]:  [array([[0.0976]], dtype=float32), 1]
#  - 1s 129ms/step - loss: 0.4387 - rpn_class_loss: 0.0239 - rpn_bbox_loss: 0.2579 - mrcnn_class_loss: 0.0916 - mrcnn_bbox_loss: 0.0652 - val_loss: 0.4743 - val_rpn_class_loss: 0.0248 - val_rpn_bbox_loss: 0.3097 - val_mrcnn_class_loss: 0.0420 - val_mrcnn_bbox_loss: 0.0976
#
# Epoch 00686: val_loss did not improve
# Epoch 687/866
# train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3307]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0161]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2266]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0439]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.044]]
# 1/8 [==>...........................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.3307]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0161]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.2266]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.0439]], dtype=float32), 1]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.044]], dtype=float32), 1]
#  - ETA: 0s - loss: 0.3307 - rpn_class_loss: 0.0161 - rpn_bbox_loss: 0.2266 - mrcnn_class_loss: 0.0439 - mrcnn_bbox_loss: 0.0440train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.4994]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0231]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2412]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1473]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0878]]
# 2/8 [======>.......................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[0.8301]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0392]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.4678]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.1912]], dtype=float32), 2]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1318]], dtype=float32), 2]
#  - ETA: 0s - loss: 0.4150 - rpn_class_loss: 0.0196 - rpn_bbox_loss: 0.2339 - mrcnn_class_loss: 0.0956 - mrcnn_bbox_loss: 0.0659train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2743]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0323]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1735]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.008]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0604]]
# 3/8 [==========>...................]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.1043]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0715]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.6413]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.1991]], dtype=float32), 3]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.1922]], dtype=float32), 3]
#  - ETA: 0s - loss: 0.3681 - rpn_class_loss: 0.0238 - rpn_bbox_loss: 0.2138 - mrcnn_class_loss: 0.0664 - mrcnn_bbox_loss: 0.0641train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2713]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0164]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1875]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0163]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0511]]
# 4/8 [==============>...............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.3756]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.0878]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[0.8288]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2154]], dtype=float32), 4]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2433]], dtype=float32), 4]
#  - ETA: 0s - loss: 0.3439 - rpn_class_loss: 0.0220 - rpn_bbox_loss: 0.2072 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.0608train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.3003]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0192]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.2186]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0315]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0309]]
# 5/8 [=================>............]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.6759]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1071]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.0474]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.247]], dtype=float32), 5]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.2742]], dtype=float32), 5]
#  - ETA: 0s - loss: 0.3352 - rpn_class_loss: 0.0214 - rpn_bbox_loss: 0.2095 - mrcnn_class_loss: 0.0494 - mrcnn_bbox_loss: 0.0548train_on_batch(1929) outputs:  <class 'list'>  len:  5
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1842]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0105]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.1282]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0042]]
#    type: <class 'numpy.ndarray'>   shape:  (1, 1) [[0.0413]]
# 6/8 [=====================>........]
#  Prog bar Update:  Key: [ loss ]    self._values[k]:  [array([[1.8601]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_class_loss ]    self._values[k]:  [array([[0.1176]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ rpn_bbox_loss ]    self._values[k]:  [array([[1.1756]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_class_loss ]    self._values[k]:  [array([[0.2511]], dtype=float32), 6]
#
#  Prog bar Update:  Key: [ mrcnn_bbox_loss ]    self._values[k]:  [array([[0.3155]], dtype=float32), 6]
#  - ETA: 0s - loss: 0.3100 - rpn_class_loss: 0.0196 - rpn_bbox_loss: 0.1959 - mrcnn_class_loss: 0.0419 - mrcnn_bbox_loss: 0.0526
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b87b2a522481> in <module>()
#      16 #             epochs_to_run =2,
#      17             layers = train_layers,
# ---> 18             losses= loss_names
#      19             )
#
# ~/git_projs/mrcnn3/mrcnn/model_mod2.py in train(self, train_dataset, val_dataset, learning_rate, layers, losses, epochs, epochs_to_run, batch_size, steps_per_epoch, min_lr)
#    1459             max_queue_size=100,
#    1460             workers=1,                                  # max(self.config.BATCH_SIZE // 2, 2),
# -> 1461             use_multiprocessing=False
#    1462         )
#    1463         self.epoch = max(self.epoch, epochs)
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2288                     outs = self.train_on_batch(x, y,
#    2289                                                sample_weight=sample_weight,
# -> 2290                                                class_weight=class_weight)
#    2291                     # print('---------self.train_on_batch complete -----------------')
#    2292                     if not isinstance(outs, list):
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1927         self._make_train_function()
#    1928
# -> 1929         outputs = self.train_function(ins)
#    1930
#    1931         print('train_on_batch(1929) outputs: ', type(outputs) , ' len: ', len(outputs))
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## - Training heads using train_in_batches ()
#
# We need to use this method for the time being as the fit generator does not have provide EASY access to the output in Keras call backs. By training in batches, we pass a batch through the network, pick up the generated RoI detections and bounding boxes and generate our semantic / gaussian tensors ...

# %%
model.train_in_batches(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/6, 
            epochs_to_run = 3,
            layers='heads')

# %% [markdown]
# ## Training - FCN
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
#     - #### Or now we can pass a list of layers we want to train in layers !
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
model.config.MIN_LR

# %%
train_layers = ['fcn']
loss_names   = ["fcn_norm_loss"]
# config.VALIDATION_STEPS= 125
# config.EPOCHS_TO_RUN          = 100
config.STEPS_PER_EPOCH        = 1
         
model.epoch = 0

model.train(dataset_train, dataset_val, 
            learning_rate = config.LEARNING_RATE, 
            epochs_to_run = config.EPOCHS_TO_RUN,
#             epochs = 25,            # total number of epochs to run (accross multiple trainings)
            layers = train_layers,
            losses = loss_names)

# %% [markdown]
# ## Fine Tuning
# Fine tune all layers

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=211,
            layers="all")

# %% [markdown]
# ## Save

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes_2500.h5")
model.keras_model.save_weights(model_path)

# %% [markdown]
# ###  Define Data Generators, get next shapes from generator and display loaded shapes

# %% [markdown]
# ### Define Data Generator

# %%
train_generator = data_generator(dataset_train, model.config, shuffle=True,
                                 batch_size=model.config.BATCH_SIZE,
                                 augment = False)
val_generator = data_generator(dataset_val, model.config, shuffle=True, 
                                batch_size=model.config.BATCH_SIZE,
                                augment=False)

# %% [markdown]
# ### Get next shapes from generator and display loaded shapes

# %%
train_batch_x, train_batch_y = next(train_generator)

# %%
# train_batch_x, train_batch_y = next(train_generator)
imgmeta_idx = model.keras_model.input_names.index('input_image_meta')
img_meta    = train_batch_x[imgmeta_idx]

for img_idx in range(config.BATCH_SIZE):
    image_id = img_meta[img_idx,0]
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    print('Image id: ',image_id)
    print('Image meta', img_meta[img_idx])
    print('Classes (1: circle, 2: square, 3: triangle ): ',class_ids)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %% [markdown]
# ### Push Data thru model using get_layer_output()

# %%
layers_out = get_layer_output_2(model.keras_model, train_batch_x, 1)

# %%
input_gt_class_ids = train_batch_x[4]

target_class_ids = layers_out[5]
mrcnn_class_logits = layers_out[9]
rpn_class_loss   = layers_out[13]
rpn_bbox_loss    = layers_out[14]
mrcnn_class_loss = layers_out[15]
mrcnn_bbox_loss  = layers_out[16]
mrcnn_mask_loss  = layers_out[17]
active_class_ids = layers_out[20]
# pred_masks = tf.identity(layers_out[18])
# gt_masks   = tf.identity(layers_out[19])

# shape = KB.int_shape(pred_masks)

# %%
print(rpn_class_loss, rpn_bbox_loss)
print(mrcnn_class_loss, mrcnn_bbox_loss, mrcnn_mask_loss)
print(active_class_ids)
print()
print(target_class_ids[1])
print()
print(mrcnn_class_logits[1])
print('gt class ids')
print(input_gt_class_ids)

# %% [markdown]
# ###  Simulate `mrcnn_class_loss` computation

# %%
print('\n>>> mrcnn_class_loss_graph ' )
print('    target_class_ids  size :', target_class_ids.shape)
print('    pred_class_logits size :', mrcnnpred_class_logits.shape)
print('    active_class_ids  size :', active_class_ids.shape)    
target_class_ids = tf.cast(target_class_ids, 'int64')

# Find predictions of classes that are not in the dataset.

pred_class_ids = tf.argmax(pred_class_logits, axis=2)

# TODO: Update this line to work with batch > 1. Right now it assumes all
#       images in a batch have the same active_class_ids
pred_active = tf.gather(active_class_ids[0], pred_class_ids)

# Loss
loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=target_class_ids, logits=pred_class_logits)

# Erase losses of predictions of classes that are not in the active
# classes of the image.
loss = loss * pred_active

# Computer loss mean. Use only predictions that contribute
# to the loss to get a correct mean.
loss = tf.reduce_sum(loss) / tf.reduce_sum(pred_active)
loss = KB.reshape(loss, [1, 1])
return loss

# %% [markdown]
# ## Plot Predicted and Ground Truth Probability Heatmaps `pred_gaussian` and `gt_gaussian` (Tensorflow)
#
# `pred_gaussian2` and `gt_gaussian2` from Tensorflow PCN layer

# %%
# gt_heatmap  = layers_out[27]     # gt_gaussiam 
# pred_heatmap= layers_out[24]  # pred_gaussian
gt_heatmap  = layers_out[21]     # gt_gaussiam 
pred_heatmap= layers_out[18]  # pred_gaussian
print('gt_gaussian heatmap shape : ', gt_heatmap.shape, ' pred_gaussian heatmap shape: ', pred_heatmap.shape)
num_images = 1 # config.IMAGES_PER_GPU
num_classes = config.NUM_CLASSES

img = 2

image_id = img_meta[img,0]
print('Image id: ',image_id)
print('Classes (1: circle, 2: square, 3: triangle ): ')
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)
visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)


for cls in range(num_classes):
    ttl = 'GROUND TRUTH HEATMAP - image :  {} class: {} '.format(img,cls)
    print(' *** Zout  ', gt_heatmap[img,:,:,cls].shape, ttl)   
    plot_gaussian( gt_heatmap[img,:,:,cls], title = ttl)
    
    ttl = 'PREDICTED heatmap  - image :  {} class: {} '.format(img,cls)     
    print(' *** pred_heatmap ', pred_heatmap[img,:,:,cls].shape, ttl)   
    plot_gaussian(pred_heatmap[img,:,:,cls], title = ttl)

# %% [markdown]
# ### Plot Output from FCN network `fcn_bilinear` and compare with `pred_gaussian`

# %%
from mrcnn.visualize import plot_gaussian
import matplotlib as plt

# %matplotlib inline
img = 2
image_id = img_meta[img,0]
print('Image id: ',image_id)
print('Classes (1: circle, 2: square, 3: triangle ): ')
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)
visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)


Zout  = layers_out[21]     # gt_gaussiam 
Zout2 = layers_out[12]     # fcn_bilinear

print(Zout.shape, Zout2.shape)
num_images = config.IMAGES_PER_GPU
num_classes = config.NUM_CLASSES


for cls in range(num_classes):
    ttl = 'GroundTruth - image :  {} class: {} '.format(img,cls)
    print(' *** Zout  ', Zout[img,:,:,cls].shape, ttl)   
    plot_gaussian( Zout[img,:,:,cls], title = ttl)
    
    ttl = 'FCN_Bilinear- image :  {} class: {} '.format(img,cls)     
    print(' *** Zout2 ', Zout2[img,:,:,cls].shape, ttl)   
    plot_gaussian(Zout2[img,:,:,cls], title = ttl)

# %% [markdown]
# ### Display ground truth bboxes from Shapes database (using `load_image_gt` )
#
# Here we are displaying the ground truth bounding boxes as provided by the dataset

# %%
img = 0
image_id = img_meta[img,0]
print('Image id: ',image_id)
p_original_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
# print(p_gt_class_id.shape, p_gt_bbox.shape, p_gt_mask.shape)
print(p_gt_bbox[0:3,:])
print(p_gt_class_id)
visualize.draw_boxes(p_original_image, p_gt_bbox[0:3])

# image_id = img_meta[img,0]
# print('Image id: ',image_id)
# p_original_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
#             load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
# # print(p_gt_class_id.shape, p_gt_bbox.shape, p_gt_mask.shape)
# print(p_gt_bbox)
# print(p_gt_class_id)
# visualize.draw_boxes(p_original_image, p_gt_bbox)

# %% [markdown]
# ### Display Predicted  Ground Truth Bounding Boxes  `gt_tensor` and `gt_tensor2`
#
# layers_out[22]  `gt_tensor` is based on input_gt_class_ids and input_normlzd_gt_boxes
# layers_out[28]  `gt_tensor2` is based on input_gt_class_ids and input_normlzd_gt_boxes, generated using Tensorflow
#
# Display the Ground Truth bounding boxes from the tensor we've constructed

# %%
from mrcnn.utils  import stack_tensors, stack_tensors_3d
# print(gt_bboxes)
# visualize.display_instances(p_original_image, p_gt_bbox, p_gt_mask, p_gt_class_id, 
#                             dataset_train.class_names, figsize=(8, 8))
# pp.pprint(gt_bboxes)
img = 0
image_id = img_meta[img,0]

print('Image id: ',image_id)
p_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)   
gt_bboxes_stacked = stack_tensors_3d(layers_out[22][img])
print(gt_bboxes_stacked)
visualize.draw_boxes(p_image, gt_bboxes_stacked[0:2,2:6])

# %% [markdown]
# ## Display RoI proposals `pred_bboxes` generated for one class
#
# Display bounding boxes from tensor of proposals produced by the network
# Square: 1 , Circle:2 , Triangle 3

# %%
img = 0
cls = 1 # <==== Class to display
pred_tensor = layers_out[19]   # numpy pred_tesnor
# pred_tensor = layers_out[25]   # tensorflow pred_tensor 

image_id = img_meta[img,0]
print('Image id: ',image_id)
p_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
print(p_image_meta)
print(pred_tensor[img,cls,:].shape)
print(pred_tensor[img,cls])
#+'-'+str(np.around(int(x[1]),decimals = 3))
# class id: str(int(x[6]))+'-'+
caps = [str(int(x[0]))+'-'+str(np.around(x[1],decimals = 3))  for x in pred_tensor[img,cls,:].tolist() ]
print(caps)

visualize.draw_boxes(p_image, pred_tensor[img,cls,:,2:6], captions = caps)

# %%
layers_out[0][0] * [128, 128,128,128]   #output_rois*

# %% [markdown]
# ### Calculate  mrcnn_bbox_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids = layers_out[1][0:1]
target_bbox      = layers_out[2][0:1]
mrcnn_bbox       = layers_out[10][0:1]
mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids

print('target_class_ids', target_class_ids.shape)
print(target_class_ids)  # tgt_class_ids
print(' class with max probability', mrcnn_class_ids.shape)
print(mrcnn_class_ids)
print('target_bboxes', target_bbox.shape)
# print(target_bbox)  # tgt_bounding boxes
print('mrcnn_bboxes',mrcnn_bbox.shape)
# print(mrcnn_bbox)  #mrcnn_bboxes
pred_bbox = mrcnn_bbox

# calc mrcnn_bbox_loss
target_class_ids = K.reshape(target_class_ids, (-1,))
print(target_class_ids.shape)
target_bbox      = K.reshape(target_bbox, (-1, 4))
print('target_bboxx: ', target_bbox.shape)
pred_bbox        = K.reshape(pred_bbox, (-1, pred_bbox.shape[2], 4))
print('pred_bbox : ', pred_bbox.shape)

positive_roi_ix        = tf.where(target_class_ids > 0)[:, 0]
print(positive_roi_ix.eval())
positive_roi_class_ids = tf.cast( tf.gather(target_class_ids, positive_roi_ix), tf.int64)
print(positive_roi_class_ids.eval())
indices                = tf.stack([positive_roi_ix, positive_roi_class_ids], axis=1)
print(indices.eval())


target_bbox = tf.gather(target_bbox, positive_roi_ix)
print(target_bbox.eval())
pred_bbox   = tf.gather_nd(pred_bbox, indices)
print(pred_bbox.eval())

print('tf.size ',tf.size(target_bbox).eval())

diff = K.abs(target_bbox - pred_bbox)
print(diff.eval())

less_than_one = K.cast(K.less(diff, 1.0), "float32")
# print(less_than_one.eval())

loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
# print( (1-less_than_one).eval())



# loss        = K.switch(tf.size(target_bbox) > 0,
#                 smooth_l1_loss(y_true=target_bbox, y_pred=pred_bbox),
#                 tf.constant(0.0))
print(loss.eval())
sumloss = K.sum(loss)
print(sumloss.eval())
print((sumloss/40).eval())
meanloss        = K.mean(loss)
print(meanloss.eval())

# %% [markdown]
# ###  Calculate mrcnn_class_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids = layers_out[1][0:1]
pred_class_logits = layers_out[8][0:1]
active_class_ids    = np.array([1,1,1,1])

# mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids

print(' target_class_ids', target_class_ids.shape)
print(target_class_ids)  # tgt_class_ids
print(' class logits', pred_class_logits.shape)
print(pred_class_logits)
print(' active, class_ids ', active_class_ids.shape)
print(active_class_ids)  # tgt_bounding boxes

pred_class_ids = tf.argmax(pred_class_logits, axis=2)
print(pred_class_ids.eval())  #mrcnn_bboxes
mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids
print(mrcnn_class_ids)
# pred_bbox = mrcnn_bbox
pred_active = tf.to_float(tf.gather(active_class_ids, pred_class_ids))
print(pred_active.eval())
# calc mrcnn_bbox_loss
loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
       labels=target_class_ids, logits=pred_class_logits)
print(loss.eval())

loss = loss * tf.to_float(pred_active)
print(loss.eval())

print(tf.reduce_sum(loss).eval())
print(tf.reduce_sum(pred_active).eval())
loss = tf.reduce_sum(loss) / tf.reduce_sum(pred_active)
print(loss.eval())

# %% [markdown]
# ###  Calculate mrcnn_mask_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids    = layers_out[1][0:3]
target_masks        = layers_out[3][0:3]
pred_masks          = layers_out[11][0:3]
# mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids
print('    target_class_ids shape :', target_class_ids.shape)
print('    target_masks     shape :', target_masks.shape)
print('    pred_masks       shape :', pred_masks.shape)    


target_class_ids = K.reshape(target_class_ids, (-1,))
print('    target_class_ids shape :', target_class_ids.shape, '\n', target_class_ids.eval())

mask_shape       = tf.shape(target_masks)
print('    mask_shape       shape :', mask_shape.shape, mask_shape.eval())    

target_masks     = K.reshape(target_masks, (-1, mask_shape[2], mask_shape[3]))
print('    target_masks     shape :', tf.shape(target_masks).eval())        

pred_shape       = tf.shape(pred_masks)
print('    pred_shape       shape :', pred_shape.shape, pred_shape.eval())        

pred_masks       = K.reshape(pred_masks, (-1, pred_shape[2], pred_shape[3], pred_shape[4]))
print('    pred_masks       shape :', tf.shape(pred_masks).eval())        


pred_masks = tf.transpose(pred_masks, [0, 3, 1, 2])
print('    pred_masks       shape :', tf.shape(pred_masks).eval())        

# Only positive ROIs contribute to the loss. And only
# the class specific mask of each ROI.
positive_ix        = tf.where(target_class_ids > 0)[:, 0]
positive_class_ids = tf.cast(tf.gather(target_class_ids, positive_ix), tf.int64)
indices            = tf.stack([positive_ix, positive_class_ids], axis=1)
print(indices.eval())



y_true = tf.gather(target_masks, positive_ix)
print('     y_true shape:', tf.shape(y_true).eval())
y_pred = tf.gather_nd(pred_masks, indices)
print('     y_pred shape:', tf.shape(y_pred).eval())

loss = K.switch(tf.size(y_true) > 0,
                K.binary_crossentropy(target=y_true, output=y_pred),
                tf.constant(0.0))
print(tf.shape(loss).eval())

loss = K.mean(loss)
print('     final loss shape:', tf.shape(loss).eval())
print(loss.eval())
loss = K.reshape(loss, [1, 1])
print('     final loss shape:', tf.shape(loss).eval())
print(loss.eval())

# %% [markdown]
# ### Calculate a pixel loss on fcn_gaussian and gt_gaussian

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss
pred_masks          = layers_out[12][0:3]
target_masks        = layers_out[27][0:3]

print('    target_masks     shape :', tf.shape(target_masks).eval())
print('    pred_masks       shape :', tf.shape(pred_masks).eval())    

diff = K.abs(target_masks - pred_masks)
print(tf.shape(diff).eval())

less_than_one = K.cast(K.less(diff, 1.0), "float32")
print(tf.shape(less_than_one).eval())

loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
print(tf.shape(loss).eval())

# print( (1-less_than_one).eval())

# loss = K.switch(tf.size(y_true) > 0,
#                 K.binary_crossentropy(target=y_true, output=y_pred),
#                 tf.constant(0.0))
meanloss = K.mean(loss)
print(tf.shape(meanloss).eval())
print(meanloss.eval())
# loss = K.reshape(loss, [1, 1])
# print('     final loss shape:', loss.get_shape())
# return loss


mask_shape       = tf.shape(target_masks)
print('    mask_shape       shape :', tf.shape(mask_shape).eval())    

target_masks     = K.reshape(target_masks, (-1, mask_shape[1], mask_shape[2]))
print('    target_masks     shape :', tf.shape(target_masks).eval())        

pred_shape       = tf.shape(pred_masks)
print('    pred_shape       shape :', tf.shape(pred_shape).eval())        

pred_masks       = K.reshape(pred_masks, (-1, pred_shape[1], pred_shape[2]))
print('    pred_masks       shape :', tf.shape(pred_masks).eval())
# Permute predicted masks to [N, num_classes, height, width]
# diff = K.abs(target_masks - pred_masks)
# print(tf.shape(diff).eval())

# less_than_one = K.cast(K.less(diff, 1.0), "float32")
# print(tf.shape(less_than_one).eval())

# loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
# print(tf.shape(loss).eval())

# meanloss = K.mean(loss)
# print(tf.shape(meanloss).eval())
# print(meanloss.eval())

loss = K.switch(tf.size(target_masks) > 0,
                smooth_l1_loss(y_true=target_masks, y_pred=pred_masks),
                tf.constant(0.0))
loss = K.mean(loss)
loss = K.reshape(loss, [1, 1])
print('     final loss shape:', loss.get_shape())
print(loss.eval())

# %% [markdown]
# ###  Mean values of GT, Pred, and FCN heatmaps

# %%
pred_masks = tf.identity(layers_out[24])
gt_masks = tf.identity(layers_out[27])
fcn_masks = tf.identity(layers_out[12])
print(gt_masks.shape, fcn_masks.shape)
for img in range(5):
    for cls in range(4):
        gt_mean = K.mean(gt_masks[img,:,:,cls])
        fcn_mean= K.mean(fcn_masks[img,:,:,cls])
        pred_mean= K.mean(pred_masks[img,:,:,cls])
        print('Img/Cls: ', img, '/', cls,'    gtmean: ', gt_mean.eval(), '\t fcn : ' , fcn_mean.eval(), '\t pred :', pred_mean.eval())

# %%
img  = 0
class_probs = layers_out[9][img]   # mrcnn_class
deltas      = layers_out[10][img]       # mrcnn_bbox

print(class_probs.shape)
print('class probabilities')
print(class_probs)
class_ids = np.argmax(layers_out[9][img],axis = 1)     # mrcnn_class_ids
print(' class with max probability')
print(class_ids)


# layers_out[10][2,0,3]
print('deltas.shape :', deltas.shape)
print(deltas[0:4])

deltas_specific = deltas[np.arange(32),class_ids]
print('deltas of max prob class: ', deltas_specific.shape)
print(deltas_specific[0:5])
output_rois = layers_out[0][img]*[128,128,128,128]
print('output_rois: ', output_rois.shape)
print(output_rois[0:])

refined_rois    = apply_box_deltas(output_rois, deltas_specific * config.BBOX_STD_DEV)
print('refined rois: ',refined_rois.shape)
print(refined_rois)

# %%
img = 0
cls = 0
fcn_out = layers_out[12][img]
fcn_sum = np.sum(fcn_out, axis=(0,1))
print(fcn_sum)
for cls in range(4):
    print('min :', np.min(fcn_out[:,:,cls]), 'max :', np.max(fcn_out[:,:,cls]), )

# %%
print(train_batch_x[4][2])
print(train_batch_x[5][2]/[128,128,128,128])
