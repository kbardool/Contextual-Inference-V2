# %% [markdown]
# ## Mask R-CNN - Train on NewShapes V2 Dataset

# %% [markdown]
# ### Notes from implementation
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os, sys, math, io, time, gc, argparse, platform, pprint, pickle
import numpy as np
import tensorflow as tf
import keras
import keras.backend as KB
sys.path.append('../')

import mrcnn.utils        as utils
import mrcnn.visualize    as visualize
import mrcnn.prep_notebook as prep

from datetime            import datetime   
from mrcnn.utils         import command_line_parser, Paths
from mrcnn.datagen       import data_generator, load_image_gt, data_gen_simulate
from mrcnn.newshapes     import prep_newshape_dataset

pp = pprint.PrettyPrinter(indent=2, width=100)
np.set_printoptions(linewidth=100,precision=4,threshold=1000, suppress = True)
start_time = datetime.now().strftime("%m-%d-%Y @ %H:%M:%S")
print()
print('--> Execution started at:', start_time)
print("    Tensorflow Version: {}   Keras Version : {} ".format(tf.__version__,keras.__version__))

##------------------------------------------------------------------------------------
## Parse command line arguments
##------------------------------------------------------------------------------------
parser = command_line_parser()
input_parms = " --epochs           2 "
input_parms +=" --steps_in_epoch   100 "
input_parms +=" --last_epoch       222" 
input_parms +=" --batch_size       4 " 
input_parms +=" --lr               0.0001 "
input_parms +=" --val_steps        8 " 
input_parms +=" --mrcnn_logs_dir   train_mrcnn "
input_parms +=" --mrcnn_model      init "
input_parms +=" --mrcnn_layers     res3+"
input_parms +=" --scale_factor     1 "
input_parms +=" --opt              adam "
input_parms +=" --sysout           screen "
input_parms +=" --toy_dataset      newshapes2"
input_parms +=" --new_log_folder    "
# input_parms +=" --fcn_logs_dir   train_fcn8_newshapes "
# input_parms +=" --fcn_model      init "
# input_parms +=" --fcn_arch       fcn8 " 
# input_parms +=" --fcn_layers     all " 
# input_parms +="--fcn_model /home/kbardool/models/train_fcn_adagrad/shapes20180709T1732/fcn_shapes_1167.h5"
 
args = parser.parse_args(input_parms.split())
utils.display_input_parms(args)
# Out:
# <style>.container { width:95% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# --> Execution started at: 03-18-2019 @ 12:54:27
#     Tensorflow Version: 1.8.0   Keras Version : 2.1.6
#
#    Arguments passed :
#    --------------------
#    batch_size                     4
#    coco_classes                   None
#    epochs                         2
#    evaluate_method                1
#    fcn_arch                       FCN32
#    fcn_bce_loss_class             0
#    fcn_bce_loss_method            1
#    fcn_layers                     ['fcn32+']
#    fcn_logs_dir                   train_fcn
#    fcn_losses                     fcn_BCE_loss
#    fcn_model                      last
#    last_epoch                     222
#    lr                             0.0001
#    mrcnn_exclude_layers           None
#    mrcnn_layers                   ['res3+']
#    mrcnn_logs_dir                 train_mrcnn
#    mrcnn_model                    init
#    new_log_folder                 True
#    opt                            ADAM
#    scale_factor                   1
#    steps_in_epoch                 100
#    sysout                         SCREEN
#    toy_dataset                    newshapes2
#    val_steps                      8

# %% [markdown]
# ###  Build Model

# %%
mrcnn_model= prep.build_mrcnn_training_pipeline_newshapes(args = args, verbose = True)
# Out:
# --> Execution started at: 03-18-2019 @ 13:00:34
#     Tensorflow Version: 1.8.0   Keras Version : 2.1.6
#     Build_mrcnn_inference_pipeline_newshapes MODE is : training shapes:  newshapes2
#
#    Arguments passed :
#    --------------------
#    batch_size                     4
#    coco_classes                   None
#    epochs                         2
#    evaluate_method                1
#    fcn_arch                       FCN32
#    fcn_bce_loss_class             0
#    fcn_bce_loss_method            1
#    fcn_layers                     ['fcn32+']
#    fcn_logs_dir                   train_fcn
#    fcn_losses                     fcn_BCE_loss
#    fcn_model                      last
#    last_epoch                     222
#    lr                             0.0001
#    mrcnn_exclude_layers           None
#    mrcnn_layers                   ['res3+']
#    mrcnn_logs_dir                 train_mrcnn
#    mrcnn_model                    init
#    new_log_folder                 True
#    opt                            ADAM
#    scale_factor                   1
#    steps_in_epoch                 100
#    sysout                         SCREEN
#    toy_dataset                    newshapes2
#    val_steps                      8
#
#
# >>> Initialize Paths
#  Linx  Linux
#
#    Arguments passed :
#    --------------------
#    batch_size                     4
#    coco_classes                   None
#    epochs                         2
#    evaluate_method                1
#    fcn_arch                       FCN32
#    fcn_bce_loss_class             0
#    fcn_bce_loss_method            1
#    fcn_layers                     ['fcn32+']
#    fcn_logs_dir                   train_fcn
#    fcn_losses                     fcn_BCE_loss
#    fcn_model                      last
#    last_epoch                     222
#    lr                             0.0001
#    mrcnn_exclude_layers           None
#    mrcnn_layers                   ['res3+']
#    mrcnn_logs_dir                 train_mrcnn
#    mrcnn_model                    init
#    new_log_folder                 True
#    opt                            ADAM
#    scale_factor                   1
#    steps_in_epoch                 100
#    sysout                         SCREEN
#    toy_dataset                    newshapes2
#    val_steps                      8
#
#
#
#    Paths:
#    -------------------------
#    COCO_DATASET_PATH              /home/kbardool/MLDatasets/newshapes2/coco2014
#    COCO_MODEL_PATH                /home/kbardool/PretrainedModels/mask_rcnn_coco.h5
#    DIR_DATASET                    /home/kbardool/MLDatasets/newshapes2
#    DIR_PRETRAINED                 /home/kbardool/PretrainedModels
#    DIR_ROOT                       /home/kbardool/git_projs/mrcnn3/notebooks
#    DIR_TRAINING                   /home/kbardool/models_newshapes2
#    FCN_TRAINING_PATH              /home/kbardool/models_newshapes2/train_fcn
#    FCN_VGG16_MODEL_PATH           /home/kbardool/PretrainedModels/fcn_vgg16_weights_tf_dim_ordering_tf_kernels.h5
#    MRCNN_TRAINING_PATH            /home/kbardool/models_newshapes2/train_mrcnn
#    RESNET_MODEL_PATH              /home/kbardool/PretrainedModels/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#    SHAPES_MODEL_PATH              /home/kbardool/PretrainedModels/mask_rcnn_shapes.h5
#    VGG16_MODEL_PATH               /home/kbardool/PretrainedModels/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
#
# >>> Initialize ModelBase model
#    Mode      :  training
#    Model dir :  /home/kbardool/models_newshapes2/train_mrcnn
# >>> set_log_dir(): model_path:  None
#     set_log_dir(): model_path has NOT been provided : None
#                    NewFolder: False  config.NEW_LOG_FOLDER: True
#     set_log_dir(): weight file template (self.checkpoint_path): /home/kbardool/models_newshapes2/train_mrcnn/mrcnn20190318T1300/mrcnn_{epoch:04d}.h5
#     set_log_dir(): weight file dir      (self.log_dir)        : /home/kbardool/models_newshapes2/train_mrcnn/mrcnn20190318T1300
#     set_log_dir(): Last completed epoch (self.epoch)          : 0
# >>> ModelBase initialiation complete
# >>> ---Initialize MRCNN model, mode:  training
#
# ----------------------------
# >>> Resnet Graph
# ----------------------------
#      Input_image shape : (?, 128, 128, 3)
#     After ZeroPadding2D            :  shape: (?, 134, 134, 3)      KB.shape:(None, 134, 134, 3)   Keras Tensor: True
#     After Conv2D padding :         :  shape: (?, 64, 64, 64)       KB.shape:(None, 64, 64, 64)    Keras Tensor: True
#     After BatchNorm                :  shape: (?, 64, 64, 64)       KB.shape:(None, 64, 64, 64)    Keras Tensor: True
#     C1                             :  shape: (?, 32, 32, 64)       KB.shape:(None, 32, 32, 64)    Keras Tensor: True
#     C2                             :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#     C3                             :  shape: (?, 16, 16, 512)      KB.shape:(None, 16, 16, 512)   Keras Tensor: True
#     C4                             :  shape: (?, 8, 8, 1024)       KB.shape:(None, 8, 8, 1024)    Keras Tensor: True
#     C5                             :  shape: (?, 4, 4, 2048)       KB.shape:(None, 4, 4, 2048)    Keras Tensor: True
# self.verbose: True
#
# >>> Feature Pyramid Network (FPN) Graph
#     Input FPN C5                   :  shape: (?, 4, 4, 2048)       KB.shape:(None, 4, 4, 2048)    Keras Tensor: True
#     Input FPN C4                   :  shape: (?, 8, 8, 1024)       KB.shape:(None, 8, 8, 1024)    Keras Tensor: True
#     Input FPN C3                   :  shape: (?, 16, 16, 512)      KB.shape:(None, 16, 16, 512)   Keras Tensor: True
#     Input FPN C2                   :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#     FPN P5                         :  shape: (?, 4, 4, 256)        KB.shape:(None, 4, 4, 256)     Keras Tensor: True
#     Upsampled P5 (x)               :  shape: (?, 8, 8, 256)        KB.shape:(None, 8, 8, 256)     Keras Tensor: True
#     Conv2D    C4 (y)               :  shape: (?, 8, 8, 256)        KB.shape:(None, 8, 8, 256)     Keras Tensor: True
#     FPN P4 (x+y)                   :  shape: (?, 8, 8, 256)        KB.shape:(None, 8, 8, 256)     Keras Tensor: True
#     Upsampled P4 (x)               :  shape: (?, 16, 16, 256)      KB.shape:(None, 16, 16, 256)   Keras Tensor: True
#     Conv2D    C3 (y)               :  shape: (?, 16, 16, 256)      KB.shape:(None, 16, 16, 256)   Keras Tensor: True
#     FPN P3 (x+y)                   :  shape: (?, 16, 16, 256)      KB.shape:(None, 16, 16, 256)   Keras Tensor: True
#     Upsampled P3 (x)               :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#     Conv2D    C2 (y)               :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#     FPN P2 (x+y)                   :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#
#     FPN Final output
#     FPN P6 (Maxpool2D of P5 w/ stride 2):  shape: (?, 2, 2, 256)        KB.shape:(None, 2, 2, 256)     Keras Tensor: True
#     FPN P5 (Conv2D (3,3) of P5)    :  shape: (?, 4, 4, 256)        KB.shape:(None, 4, 4, 256)     Keras Tensor: True
#     FPN P4 (Conv2D (3,3) of P4)    :  shape: (?, 8, 8, 256)        KB.shape:(None, 8, 8, 256)     Keras Tensor: True
#     FPN P3 (Conv2D (3,3) of P3)    :  shape: (?, 16, 16, 256)      KB.shape:(None, 16, 16, 256)   Keras Tensor: True
#     FPN P2 (Conv2D (3,3) of P2)    :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#
# >>> RPN Layer
#      append Tensor("fpn_p2/BiasAdd:0", shape=(?, 32, 32, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p3/BiasAdd:0", shape=(?, 16, 16, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p4/BiasAdd:0", shape=(?, 8, 8, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p5/BiasAdd:0", shape=(?, 4, 4, 256), dtype=float32) to layer_outputs
#      append Tensor("fpn_p6/MaxPool:0", shape=(?, 2, 2, 256), dtype=float32) to layer_outputs
#
# >>> RPN Outputs  <class 'list'>
#       rpn_class_logits/rpn_class_logits:0
#       rpn_class/rpn_class:0
#       rpn_bbox/rpn_bbox:0
#
# >>> Proposal Layer - generate  2000  proposals
#     Init complete. Size of anchors:  (4092, 4)
#      Scores :  (4, 4092)
#      Deltas :  (4, 4092, 4)
#      Anchors:  (4, 4092, 4)
#      Boxes shape / type after processing:
#      Output: Proposals shape :  (4, ?, ?) (4, None, None)
#
# >>> Detection Target Layer (Training Mode)
#     Detection Target Layer : call()  <class 'list'> 3
#      proposals.shape    : (4, ?, ?) (4, ?, ?) (None, 2000, 4)
#      gt_class_ids.shape : (?, ?) (?, ?) (None, None)
#      gt_bboxes.shape    : (?, ?, 4) (?, ?, 4) (None, None, 4)
#     Detection Target Layer : return  <class 'list'> 4
#      output 0  shape (4, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 1  shape (4, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 2  shape (4, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#      output 3  shape (4, ?, ?)  type <class 'tensorflow.python.framework.ops.Tensor'>
#
# >>> FPN Classifier Graph verbose: True
#     INPUT: rois shape              :  shape: (4, ?, ?)             KB.shape:(None, 32, 4)         Keras Tensor: True
#     INPUT: mrcnn feature_maps      :  value: 4
#     -      feature_map P2          :  shape: (?, 32, 32, 256)      KB.shape:(None, 32, 32, 256)   Keras Tensor: True
#     -      feature_map P3          :  shape: (?, 16, 16, 256)      KB.shape:(None, 16, 16, 256)   Keras Tensor: True
#     -      feature_map P4          :  shape: (?, 8, 8, 256)        KB.shape:(None, 8, 8, 256)     Keras Tensor: True
#     -      feature_map P5          :  shape: (?, 4, 4, 256)        KB.shape:(None, 4, 4, 256)     Keras Tensor: True
#     INPUT: image_shape             :  shape: (3,)
#     INPUT: pool_size               :  value: 7
#     INPUT: num_classes             :  value: 9
#     roi_align_classifier           :  shape: (1, ?, 7, 7, 256)     KB.shape:(None, 32, 7, 7, 256)  Keras Tensor: True
#     mrcnn_class_conv1              :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#     mrcnn_class_bn1                :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#     mrcnn_class_relu1              :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#
#     mrcnn_class_conv2              :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#     mrcnn_class_bn2                :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#     mrcnn_class_relu2              :  shape: (?, 32, 1, 1, 1024)   KB.shape:(None, 32, 1, 1, 1024)  Keras Tensor: True
#
#     pool_squeeze(Shared)           :  shape: (?, 32, 1024)         KB.shape:(None, 32, 1024)      Keras Tensor: True
#     mrcnn_class_logits             :  shape: (?, 32, 9)            KB.shape:(None, 32, 9)         Keras Tensor: True
#     mrcnn_class_logits (final)     :  shape: (?, 32, 9)            KB.shape:(None, 32, 9)         Keras Tensor: True
#     mrcnn_probs                    :  shape: (?, 32, 9)            KB.shape:(None, 32, 9)         Keras Tensor: True
#     mrcnn_probs (final)            :  shape: (?, 32, 9)            KB.shape:(None, 32, 9)         Keras Tensor: True
#     mrcnn_bbox_fc                  :  shape: (?, 32, 36)           KB.shape:(None, 32, 36)        Keras Tensor: True
#     mrcnn_bbox_fc reshaped output  :  shape: (?, 32, 9, 4)         KB.shape:(None, 32, 9, 4)      Keras Tensor: True
#     mrcnn_bbox (final)             :  shape: (?, 32, 9, 4)         KB.shape:(None, 32, 9, 4)      Keras Tensor: True
# -----------------------------------------
# >>>  CHM Layer (Prediction Generation)
# -----------------------------------------
#     > CHMLayer Call()              :  list length: 4
#     mrcnn_class                    :  shape: (?, 32, 9)            KB.shape:(None, 32, 9)         Keras Tensor: True
#     mrcnn_bbox                     :  shape: (?, 32, 9, 4)         KB.shape:(None, 32, 9, 4)      Keras Tensor: True
#     output_rois                    :  shape: (4, ?, ?)             KB.shape:(None, 32, 4)         Keras Tensor: True
#     target_class_ids               :  shape: (4, ?)                KB.shape:(None, 32)            Keras Tensor: True
#     pr tensor                      :  shape: (?, 9, 32, 9)         KB.shape:(None, 9, 32, 9)      Keras Tensor: False
#
#
#   > build_pr_heatmap() for :  ['pred_heatmap']
#     in_tensor shape        :  (?, 9, 32, 9)
#     num bboxes per class   :  32
#     heatmap scale          :  1 Dimensions:  w: 128  h: 128
#     pt2_sum                        :  shape: (?, 9, 32)            KB.shape:(None, 9, 32)         Keras Tensor: False
#     pt2_ind                        :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     pt2_dense                      :  shape: (?, 9)                KB.shape:(None, 9)             Keras Tensor: False
#     X/Y shapes : (128, 128) (128, 128)
#     Ones:     (?, 1, 1)
#     ones_exp * X (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     ones_exp * Y (?, 1, 1) * (128, 128) =  (?, 128, 128)
#     pos_grid before transpse       :  shape: (?, 128, 128, 2)      KB.shape:(None, 128, 128, 2)   Keras Tensor: False
#     pos_grid after transpose       :  shape: (128, 128, ?, 2)      KB.shape:(128, 128, None, 2)   Keras Tensor: False
#     Input to MVN.PROB: pos_grid (meshgrid):  shape: (128, 128, ?, 2)      KB.shape:(128, 128, None, 2)   Keras Tensor: False
#     Prob_grid shape from mvn.probe :  shape: (128, 128, ?)         KB.shape:(128, 128, None)      Keras Tensor: False
#     Prob_grid shape after tanspose :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     Output probabilities shape     :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     old_style_scores        :      :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     prob_grid_clipped :            :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     normalization ------------------------------------------------------
#     normalizer     :               :  shape: (?, 1, 1)             KB.shape:(None, 1, 1)          Keras Tensor: False
#     prob_grid_cns: clipped/normed/scaled ::  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     alt_scores_1                   :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     alt_scores_1(by class)         :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     alt_scores_1_norm(by_class)    :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     Scatter out the probability distributions based on class --------------
#     pt2_ind shape                  :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     prob_grid_clippped             :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     gauss_heatmap                  :  shape: (4, 9, 32, 128, 128)  KB.shape:(4, 9, 32, 128, 128)  Keras Tensor: False
#     Reduce SUM based on class and normalize within each class -----------------------
#     gaussian_heatmap_sum           :  shape: (4, 9, 128, 128)      KB.shape:(4, 9, 128, 128)      Keras Tensor: False
#     normalizer shape   :           :  shape: (4, 9, 1, 1)          KB.shape:(4, 9, 1, 1)          Keras Tensor: False
#     normalized heatmap :           :  shape: (4, 9, 128, 128)      KB.shape:(4, 9, 128, 128)      Keras Tensor: False
#     hm_indices                     :  shape: (?, 2)                KB.shape:(None, 2)             Keras Tensor: False
#     pt2_heatmaps                   :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     alt_scores_2    :              :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     alt_scores_2(scattered)        :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     alt_scores_2_norm(by_class)    :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     reshaped heatmap               :  shape: (4, 128, 128, 9)      KB.shape:(4, 128, 128, 9)      Keras Tensor: False
#     gauss_scores    :              :  shape: (4, 9, 32, 24)        KB.shape:(4, 9, 32, 24)        Keras Tensor: False
#     complete
#
#     pred_refined_heatmap           :  shape: (4, 128, 128, 9)      KB.shape:(4, 128, 128, 9)      Keras Tensor: False
#     pred_refnined_heatmap_scores   :  shape: (4, 9, 32, 24)        KB.shape:(4, 9, 32, 24)        Keras Tensor: False
#     complete
#     > CHMLayer compute_output_shape()
# input:  0       <class 'tuple'> (None, 32, 9)
# input:  1       <class 'tuple'> (None, 32, 9, 4)
# input:  2       <class 'tuple'> (None, 32, 4)
# input:  3       <class 'tuple'> (None, 32)
#
# -----------------------------------------
# >>>  CHM Layer (Ground Truth Generation)
# -----------------------------------------
#     > CHMLayerTgt Call()   :       :  list length: 2
#     tgt_class_ids.shape  :         :  shape: (4, ?)                KB.shape:(None, 32)            Keras Tensor: True
#     tgt_bboxes.shape     :         :  shape: (4, ?, ?)             KB.shape:(None, 32, 4)         Keras Tensor: True
#
#
#   > BUILD_GROUND TRUTH_TF()
#     num_bboxes             :  32 (building  gt_tensor )
#     gt_class_ids shape     :  (4, ?)    (None, 32)
#     norm_gt_bboxes.shape   :  (4, ?, ?)    (None, 32, 4)
#     gt_bboxes.shape        :  (4, 32, 4)    (4, 32, 4)
#     gt_classes_exp                 :  shape: (4, ?, 1)             KB.shape:(4, None, 1)          Keras Tensor: False
#     gt_scores_exp                  :  shape: (4, ?, 1)             KB.shape:(4, None, 1)          Keras Tensor: False
#     flag:                          :  shape: (4, ?, 1)             KB.shape:(4, None, 1)          Keras Tensor: False
#     gt_array                       :  shape: (4, 32, 9)            KB.shape:(4, 32, 9)            Keras Tensor: False
#     scatter_ind                    :  shape: (4, 32, 3)            KB.shape:(4, 32, 3)            Keras Tensor: False
#     gt_array                       :  shape: (4, 32, 9)            KB.shape:(4, 32, 9)            Keras Tensor: False
#     gt_scatter                     :  shape: (4, 9, 32, 9)         KB.shape:(4, 9, 32, 9)         Keras Tensor: False
#     sort_inds                      :  shape: (4, 9, 32)            KB.shape:(4, 9, 32)            Keras Tensor: False
#     class_grid                     :  shape: (4, 9, 32)            KB.shape:(4, 9, 32)            Keras Tensor: False
#     batch_grid                     :  shape: (4, 9, 32)            KB.shape:(4, 9, 32)            Keras Tensor: False
#     gather_inds                    :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     gt_tensor                      :  shape: (4, 9, 32, 9)         KB.shape:(4, 9, 32, 9)         Keras Tensor: False
#
#
#   > build_heatmap() for  ['gt_heatmap']
#     in_tensor shape        :  (4, 9, 32, 9)
#     num bboxes per class   :  32
#     heatmap scale        :  1 Dimensions:  w: 128  h: 128
#     pt2_sum                        :  shape: (4, 9, 32)            KB.shape:(4, 9, 32)            Keras Tensor: False
#     pt2_ind                        :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     pt2_dense                      :  shape: (?, 9)                KB.shape:(None, 9)             Keras Tensor: False
#     Prob_grid                      :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     prob_grid_clipped              :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     old_style_scores               :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     alt_scores_1                   :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     alt_scores_1(by class)         :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     alt_scores_1_norm(by_class)    :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     Scatter out the probability distributions based on class --------------
#     pt2_ind                        :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     prob_grid                      :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     gauss_heatmap                  :  shape: (4, 9, 32, 128, 128)  KB.shape:(4, 9, 32, 128, 128)  Keras Tensor: False
#     Reduce MAX based on class -------------------------------------
#     gaussian_heatmap :             :  shape: (4, 9, 128, 128)      KB.shape:(4, 9, 128, 128)      Keras Tensor: False
#     hm_indices                     :  shape: (?, 2)                KB.shape:(None, 2)             Keras Tensor: False
#     pt2_heatmaps                   :  shape: (?, 128, 128)         KB.shape:(None, 128, 128)      Keras Tensor: False
#     alt_scores_2                   :  shape: (?, 3)                KB.shape:(None, 3)             Keras Tensor: False
#     alt_scores_2(by class)       : :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     alt_scores_2_norm(by_class)  : :  shape: (4, 9, 32, 3)         KB.shape:(4, 9, 32, 3)         Keras Tensor: False
#     gauss_heatmap                  :  shape: (4, 128, 128, 9)      KB.shape:(4, 128, 128, 9)      Keras Tensor: False
#     gauss_scores                   :  shape: (4, 9, 32, 24)        KB.shape:(4, 9, 32, 24)        Keras Tensor: False
#     complete
#
#     gt_heatmap                     :  shape: (4, 128, 128, 9)      KB.shape:(4, 128, 128, 9)      Keras Tensor: False
#     gt_heatmap_scores              :  shape: (4, 9, 32, 24)        KB.shape:(4, 9, 32, 24)        Keras Tensor: False
#     complete
#     pr_hm                          :  shape: (4, 128, 128, 9)      KB.shape:(None, 128, 128, 9)   Keras Tensor: True
#     gt_hm                          :  shape: (4, 128, 128, 9)      KB.shape:(None, 128, 128, 9)   Keras Tensor: True
#  GT HM.op_type()       : Transpose
#  GT HM SCORES.op_type(): ConcatV2
#
#
# ---------------------------------------------------
#     building Loss Functions
# ---------------------------------------------------
#
# >>> rpn_class_loss_graph
#     rpn_match size : (?, ?, 1)
#     tf default session:  None
#     loss      : (?,) Tensor("rpn_class_loss/Shape:0", shape=(1,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("rpn_class_loss/Shape_1:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("rpn_class_loss/Shape_2:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> rpn_class_loss_graph
#     rpn_match size : (?, ?, 1)
#     tf default session:  None
#     loss      : (?,) Tensor("rpn_class_loss/Shape_3:0", shape=(1,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("rpn_class_loss/Shape_4:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("rpn_class_loss/Shape_5:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> rpn_bbox_loss_graph
#     rpn_match size : (?, ?)
#     rpn_bbox  size : (?, ?, 4)
#     loss      : <unknown> Tensor("rpn_bbox_loss/Shape:0", shape=(?,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("rpn_bbox_loss/Shape_1:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("rpn_bbox_loss/Shape_2:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> rpn_bbox_loss_graph
#     rpn_match size : (?, ?)
#     rpn_bbox  size : (?, ?, 4)
#     loss      : <unknown> Tensor("rpn_bbox_loss/Shape_3:0", shape=(?,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("rpn_bbox_loss/Shape_4:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("rpn_bbox_loss/Shape_5:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> mrcnn_class_loss_graph
#     target_class_ids  size : (4, ?)
#     pred_class_logits size : (?, 32, 9)
#     active_class_ids  size : (?, ?)
#     loss      : (4, 32) Tensor("mrcnn_class_loss/Shape:0", shape=(2,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("mrcnn_class_loss/Shape_1:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("mrcnn_class_loss/Shape_2:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> mrcnn_class_loss_graph
#     target_class_ids  size : (?, 32)
#     pred_class_logits size : (?, 32, 9)
#     active_class_ids  size : (?, ?)
#     loss      : (?, 32) Tensor("mrcnn_class_loss/Shape_3:0", shape=(2,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("mrcnn_class_loss/Shape_4:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("mrcnn_class_loss/Shape_5:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> mrcnn_bbox_loss_graph
#     target_class_ids  size : (4, ?)
#     pred_bbox size         : (?, 32, 9, 4)
#     target_bbox size       : (4, ?, ?)
#     reshpaed pred_bbox size         : (?, 9, 4)
#     reshaped target_bbox size       : (?, 4)
#     pred_bbox size         : (?, 4)
#     target_bbox size       : (?, 4)
#     loss      : <unknown> Tensor("mrcnn_bbox_loss/Shape:0", shape=(?,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("mrcnn_bbox_loss/Shape_1:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("mrcnn_bbox_loss/Shape_2:0", shape=(2,), dtype=int32) KerasTensor:  False
#
# >>> mrcnn_bbox_loss_graph
#     target_class_ids  size : (?, 32)
#     pred_bbox size         : (?, 32, 9, 4)
#     target_bbox size       : (?, 32, 4)
#     reshpaed pred_bbox size         : (?, 9, 4)
#     reshaped target_bbox size       : (?, 4)
#     pred_bbox size         : (?, 4)
#     target_bbox size       : (?, 4)
#     loss      : <unknown> Tensor("mrcnn_bbox_loss/Shape_3:0", shape=(?,), dtype=int32) KerasTensor:  False
#     mean loss : () Tensor("mrcnn_bbox_loss/Shape_4:0", shape=(0,), dtype=int32) KerasTensor:  False
#     reshaped mean loss : (1, 1) Tensor("mrcnn_bbox_loss/Shape_5:0", shape=(2,), dtype=int32) KerasTensor:  False
#  ================================================================
#  self.keras_model.losses :  0
# []
#  ================================================================
#
# >>> Build MaskRCNN build complete. mode:  training
# >>> MaskRCNN initialiation complete. Mode:  training
#
# MRCNN Configuration Parameters:
# -------------------------------
# BACKBONE_SHAPES                [[32 32]
#  [16 16]
#  [ 8  8]
#  [ 4  4]
#  [ 2  2]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     4
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        64
# DETECTION_MIN_CONFIDENCE       0.1
# DETECTION_NMS_THRESHOLD        0.3
# DETECTION_PER_CLASS            64
# DIR_DATASET                    /home/kbardool/MLDatasets/newshapes2
# DIR_PRETRAINED                 /home/kbardool/PretrainedModels
# DIR_TRAINING                   /home/kbardool/models_newshapes2
# EARLY_STOP_MIN_DELTA           0.0001
# EARLY_STOP_PATIENCE            120
# EPOCHS_TO_RUN                  2
# FCN_INPUT_SHAPE                [128 128]
# GPU_COUNT                      1
# HEATMAP_SCALE_FACTOR           1
# IMAGES_PER_GPU                 4
# IMAGE_BUFFER                   20
# IMAGE_MAX_DIM                  128
# IMAGE_MIN_DIM                  128
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [128 128   3]
# INPUT_DATASET_PATH             /home/kbardool/MLDatasets/newshapes2
# LAST_EPOCH_RAN                 222
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.0001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MAX_SHAPES_PER_IMAGE           15
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# MIN_LR                         1e-10
# MIN_SHAPES_PER_IMAGE           2
# NAME                           mrcnn
# NEW_LOG_FOLDER                 True
# NUM_CLASSES                    9
# OPTIMIZER                      ADAM
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# REDUCE_LR_COOLDOWN             30
# REDUCE_LR_FACTOR               0.5
# REDUCE_LR_PATIENCE             60
# RESNET_MODEL_PATH              /home/kbardool/PretrainedModels/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# ROI_GT_IOU_THRESHOLD           0.2
# ROI_POSITIVE_RATIO             0.33
# ROI_PROPOSAL_AREA_THRESHOLD    0
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# SHAPES_MODEL_PATH              /home/kbardool/PretrainedModels/mask_rcnn_shapes.h5
# STEPS_PER_EPOCH                100
# SYSOUT                         SCREEN
# TOY_DATASET                    newshapes2
# TRAINING_PATH                  /home/kbardool/models_newshapes2/train_mrcnn
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               8
# VERBOSE                        True
# VGG16_MODEL_PATH               /home/kbardool/PretrainedModels/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# WEIGHT_DECAY                   0.0001
#
#
# MRCNN IO Layers :
# -----------------
#  Inputs:
#  -------
#  index:  0    input name : input_image:0                              Type: float32           Shape: (?, 128, 128, 3)
#  index:  1    input name : input_image_meta:0                         Type: float32           Shape: (?, ?)
#  index:  2    input name : input_rpn_match:0                          Type: int32             Shape: (?, ?, 1)
#  index:  3    input name : input_rpn_bbox:0                           Type: float32           Shape: (?, ?, 4)
#  index:  4    input name : input_gt_class_ids:0                       Type: int32             Shape: (?, ?)
#  index:  5    input name : input_gt_boxes:0                           Type: float32           Shape: (?, ?, 4)
#  Outputs:
#  --------
#  layer:  0    output name: cntxt_layer/pred_heatmap:0                 Type: float32           Shape: (4, 128, 128, 9)
#  layer:  1    output name: cntxt_layer/pred_heatmap_scores:0          Type: float32           Shape: (4, 9, 32, 24)
#  layer:  2    output name: cntxt_layer_gt/gt_heatmap:0                Type: float32           Shape: (4, 128, 128, 9)
#  layer:  3    output name: cntxt_layer_gt/gt_heatmap_scores:0         Type: float32           Shape: (4, 9, 32, 24)
#  layer:  4    output name: mrcnn_class_lambda/mrcnn_class:0           Type: float32           Shape: (?, 32, 9)
#  layer:  5    output name: mrcnn_bbox_lambda/mrcnn_bbox:0             Type: float32           Shape: (?, 32, 9, 4)
#  layer:  6    output name: proposal_targets/output_rois:0             Type: float32           Shape: (4, ?, ?)
#  layer:  7    output name: proposal_targets/target_class_ids:0        Type: int32             Shape: (4, ?)
#  layer:  8    output name: proposal_targets/target_bbox_deltas:0      Type: float32           Shape: (4, ?, ?)
#  layer:  9    output name: proposal_targets/roi_gt_boxes:0            Type: float32           Shape: (4, ?, ?)
#  layer: 10    output name: mrcnn_logits_lambda/mrcnn_class_logits:0   Type: float32           Shape: (?, 32, 9)
#  layer: 11    output name: active_class_ids/strided_slice_3:0         Type: float32           Shape: (?, ?)
#  layer: 12    output name: ROI/rpn_roi_proposals:0                    Type: float32           Shape: (4, ?, ?)
#  layer: 13    output name: cntxt_layer/pr_tensor:0                    Type: float32           Shape: (?, 9, 32, 9)
#  layer: 14    output name: cntxt_layer_gt/gt_tensor:0                 Type: float32           Shape: (4, 9, 32, 9)
#  layer: 15    output name: rpn_class_loss/rpn_class_loss:0            Type: float32           Shape: (1, 1)
#  layer: 16    output name: rpn_bbox_loss/rpn_bbox_loss:0              Type: float32           Shape: (1, 1)
#  layer: 17    output name: mrcnn_class_loss/mrcnn_class_loss:0        Type: float32           Shape: (1, 1)
#  layer: 18    output name: mrcnn_bbox_loss/mrcnn_bbox_loss:0          Type: float32           Shape: (1, 1)
#  mrcnn_model = init --> MRCNN Training starting from randomly initialized weights ...

# %% [markdown]
# ###  Print some model information

# %%
mrcnn_model.display_layer_info()
# Out:
# MRCNN IO Layers :
# -----------------
#  Inputs:
#  -------
#  index:  0    input name : input_image:0                              Type: float32           Shape: (?, 128, 128, 3)
#  index:  1    input name : input_image_meta:0                         Type: float32           Shape: (?, ?)
#  index:  2    input name : input_rpn_match:0                          Type: int32             Shape: (?, ?, 1)
#  index:  3    input name : input_rpn_bbox:0                           Type: float32           Shape: (?, ?, 4)
#  index:  4    input name : input_gt_class_ids:0                       Type: int32             Shape: (?, ?)
#  index:  5    input name : input_gt_boxes:0                           Type: float32           Shape: (?, ?, 4)
#  Outputs:
#  --------
#  layer:  0    output name: cntxt_layer/pred_heatmap:0                 Type: float32           Shape: (4, 128, 128, 9)
#  layer:  1    output name: cntxt_layer/pred_heatmap_scores:0          Type: float32           Shape: (4, 9, 32, 24)
#  layer:  2    output name: cntxt_layer_gt/gt_heatmap:0                Type: float32           Shape: (4, 128, 128, 9)
#  layer:  3    output name: cntxt_layer_gt/gt_heatmap_scores:0         Type: float32           Shape: (4, 9, 32, 24)
#  layer:  4    output name: mrcnn_class_lambda/mrcnn_class:0           Type: float32           Shape: (?, 32, 9)
#  layer:  5    output name: mrcnn_bbox_lambda/mrcnn_bbox:0             Type: float32           Shape: (?, 32, 9, 4)
#  layer:  6    output name: proposal_targets/output_rois:0             Type: float32           Shape: (4, ?, ?)
#  layer:  7    output name: proposal_targets/target_class_ids:0        Type: int32             Shape: (4, ?)
#  layer:  8    output name: proposal_targets/target_bbox_deltas:0      Type: float32           Shape: (4, ?, ?)
#  layer:  9    output name: proposal_targets/roi_gt_boxes:0            Type: float32           Shape: (4, ?, ?)
#  layer: 10    output name: mrcnn_logits_lambda/mrcnn_class_logits:0   Type: float32           Shape: (?, 32, 9)
#  layer: 11    output name: active_class_ids/strided_slice_3:0         Type: float32           Shape: (?, ?)
#  layer: 12    output name: ROI/rpn_roi_proposals:0                    Type: float32           Shape: (4, ?, ?)
#  layer: 13    output name: cntxt_layer/pr_tensor:0                    Type: float32           Shape: (?, 9, 32, 9)
#  layer: 14    output name: cntxt_layer_gt/gt_tensor:0                 Type: float32           Shape: (4, 9, 32, 9)
#  layer: 15    output name: rpn_class_loss/rpn_class_loss:0            Type: float32           Shape: (1, 1)
#  layer: 16    output name: rpn_bbox_loss/rpn_bbox_loss:0              Type: float32           Shape: (1, 1)
#  layer: 17    output name: mrcnn_class_loss/mrcnn_class_loss:0        Type: float32           Shape: (1, 1)
#  layer: 18    output name: mrcnn_bbox_loss/mrcnn_bbox_loss:0          Type: float32           Shape: (1, 1)

# %%
# t1 = mrcnn_model.get_trainable_layers()
# for i, tt in enumerate(t1):
#     print(i, tt.name)

# %% [markdown]
# ### Load saved weights

# %%
##------------------------------------------------------------------------------------
## Load Mask RCNN Model Weight file
##------------------------------------------------------------------------------------
## WHEN RUNNING TRAINING AND INITIALIZING WEIGHTS FROM From mask_rcnn_shapes.h5
## MUST EXCLUDE "mrcnn_class_logits" and "mrcnn_bbox_fc" layers
exclude_list = ["mrcnn_class_logits", "mrcnn_bbox_fc"] 
mrcnn_model.load_model_weights(init_with = 'shapes', exclude = exclude_list, verbose = 1)   

## Not required after INIT epoch, as now weights have been initialized properly. 

# mrcnn_model.load_model_weights(init_with = 'last',verbose = 1)

# %% [markdown]
# ### Build newshape datasets

# %%
# del dataset_train, dataset_val, train_generator, val_generator
# from mrcnn.prep_notebook import prep_newshape_dataset
##------------------------------------------------------------------------------------
## Build & Load Training and Validation datasets
##------------------------------------------------------------------------------------
# dataset_train, train_generator = prep_newshape_dataset( mrcnn_model.config, 10000, generator=True)
# dataset_val  , val_generator   = prep_newshape_dataset( mrcnn_model.config,  2500, generator=True)
# with open('E:\\git_projs\\MRCNN3\\train_newshapes\\newshapes_training_dataset_10000_A.pkl', 'wb') as outfile:
#     pickle.dump(dataset_train, outfile)
# with open('E:\\git_projs\\MRCNN3\\train_newshapes\\newshapes_validation_dataset_2500_A.pkl', 'wb') as outfile:
#     pickle.dump(dataset_val, outfile)

## -- OR --
# dataset_path = 'E:\\git_projs\\mrcnn3\\train_newshapes_2'
dataset_path = '/home/kbardool/git_projs/mrcnn3/train_newshapes_2'
with open(os.path.join(dataset_path, 'newshapes2_training_dataset_15000_A.pkl'), 'rb') as outfile:
    dataset_train = pickle.load(outfile)
with open(os.path.join(dataset_path, 'newshapes2_validation_dataset_2500_A.pkl'), 'rb') as outfile:
    dataset_val = pickle.load(outfile)

# %%
print(type(dataset_train))
print(type(dataset_val))
# print(type(train_generator),type(val_generator))
print(len(dataset_train.image_info))
print(len(dataset_val.image_info))
print(len(dataset_train.image_ids), len(dataset_val.image_info))
# dataset_train.display_active_class_info()
print(dataset_train.class_from_source_map)
print(dataset_train.class_info)
# Out:
# <class 'mrcnn.newshapes2.NewImagesDataset'>
# <class 'mrcnn.newshapes2.NewImagesDataset'>
# 15000
# 2500
# 15000 2500
# {'newshapes2.2': 2, 'newshapes2.5': 5, 'newshapes2.8': 8, 'newshapes2.6': 6, 'newshapes2.7': 7, 'newshapes2.4': 4, '.0': 0, 'newshapes2.1': 1, 'newshapes2.3': 3}
# [{'category': 'background', 'name': 'BG', 'internal_id': 0, 'id': 0, 'img_count': 0, 'source': ''}, {'category': None, 'name': 'person', 'internal_id': 1, 'id': 1, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'car', 'internal_id': 2, 'id': 2, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'sun', 'internal_id': 3, 'id': 3, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'building', 'internal_id': 4, 'id': 4, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'tree', 'internal_id': 5, 'id': 5, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'cloud', 'internal_id': 6, 'id': 6, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'airplane', 'internal_id': 7, 'id': 7, 'img_count': 0, 'source': 'newshapes2'}, {'category': None, 'name': 'truck', 'internal_id': 8, 'id': 8, 'img_count': 0, 'source': 'newshapes2'}]

# %%
## If we desire a generator, here it is:    
train_generator = data_generator(dataset_train, mrcnn_model.config, batch_size=mrcnn_model.config.BATCH_SIZE,
                                   shuffle = True, augment = False) 
val_generator = data_generator(dataset_val, mrcnn_model.config, batch_size=mrcnn_model.config.BATCH_SIZE,
                                   shuffle = True, augment = False) 
class_names = dataset_train.class_names
# dataset_train.display_active_classes()
print(mrcnn_model.config.BATCH_SIZE)
print(len(dataset_train.image_ids), len(dataset_val.image_ids))

# %% [markdown]
# ###  Display some images from dataset

# %%
image_list = list(range(0,40))
image_titles = [str(i) for i in image_list]
images = prep.get_image_batch(dataset_train, image_list)
visualize.display_images(images, titles = image_titles, cols = 8, width = 24)

# %% [markdown]
# ####  another method

# %%
image_list = dataset_train.image_ids.tolist()[-40:] ## [-4:]
dataset_train.display_image(image_list, grid = False)

# %% [markdown]
# ####  Display next image from generator

# %%
train_batch_x, train_batch_y = next(train_generator)
visualize.display_training_batch(dataset_train, train_batch_x)

# %% [markdown]
# #### Load a specific image using image_id

# %%
IMAGE_LIST = [2000,4000,5000,6000]
print(dataset_train.image_info[2000]['source'])
train_batch_x, train_batch_y = test_batch_x, test_batch_y = data_gen_simulate(dataset_train, mrcnn_model.config, IMAGE_LIST)
visualize.display_training_batch(dataset_train, train_batch_x)

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names, limit=6)

# %% [markdown]
# ## Training mrcnn, fpn, rpn layers
#
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# - Or now we can pass a list of layers we want to train in layers !
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
# Wed 09-05-2018
# config.STEPS_PER_EPOCH        = 8
# config.EARLY_STOP_PATIENCE    = 70
# train_layers = [ 'mrcnn', 'fpn','rpn']   ## equivalent to "heads"
train_layers = ['all']
loss_names   = [ "rpn_class_loss", "rpn_bbox_loss" , "mrcnn_class_loss", "mrcnn_bbox_loss"]
# train_layers = [ 'mrcnn']
# loss_names   = [ "mrcnn_class_loss", "mrcnn_bbox_loss"]

mrcnn_model.config.LAST_EPOCH_RAN  =  0 #222
mrcnn_model.config.EPOCHS_TO_RUN   =  1 # 100
mrcnn_model.config.LEARNING_RATE   = 0.0001
# mrcnn_model.config.STEPS_PER_EPOCH = 2
# mrcnn_model.config.SYSOUT = 'screen'
 
print('    last epoch ran : ',mrcnn_model.config.LAST_EPOCH_RAN)
print('    epochs to run  : ',mrcnn_model.config.EPOCHS_TO_RUN)
print('    steps per epoch: ',mrcnn_model.config.STEPS_PER_EPOCH)
print('    learning rate  : ', mrcnn_model.config.LEARNING_RATE)
print('    momentum       : ', mrcnn_model.config.LEARNING_MOMENTUM)
print('    weight decay   : ',mrcnn_model.config.WEIGHT_DECAY)
# Out:
#     last epoch ran :  0
#     epochs to run  :  1
#     steps per epoch:  100
#     learning rate  :  0.0001
#     momentum       :  0.9
#     weight decay   :  0.0001

# %%
mrcnn_model.epoch = mrcnn_model.config.LAST_EPOCH_RAN
mrcnn_model.train(dataset_train, 
            dataset_val, 
            learning_rate = mrcnn_model.config.LEARNING_RATE, 
            epochs_to_run = mrcnn_model.config.EPOCHS_TO_RUN,
            layers = train_layers,
            losses = loss_names)
# Out:
# ['all']
# ['.*']
# layers regex : .*
# type train_dataset: <class 'mrcnn.newshapes2.NewImagesDataset'>
# type val_dataset: <class 'mrcnn.newshapes2.NewImagesDataset'>
#     learning rate :  0.0001
#     momentum      :  0.9
#
#
# Selecting layers to train
# -------------------------
# Layer    Layer Name               Layer Type
#    0  input_image            (InputLayer          )   ............................no weights to train ]
#    1  zero_padding2d_1       (ZeroPadding2D       )   ............................no weights to train ]
#    2  conv1                  (Conv2D              )   TRAIN
#    3  bn_conv1               (BatchNorm           )   TRAIN
#    4  activation_1           (Activation          )   ............................no weights to train ]
#    5  max_pooling2d_1        (MaxPooling2D        )   ............................no weights to train ]
#    6  res2a_branch2a         (Conv2D              )   TRAIN
#    7  bn2a_branch2a          (BatchNorm           )   TRAIN
#    8  activation_2           (Activation          )   ............................no weights to train ]
#    9  res2a_branch2b         (Conv2D              )   TRAIN
#   10  bn2a_branch2b          (BatchNorm           )   TRAIN
#   11  activation_3           (Activation          )   ............................no weights to train ]
#   12  res2a_branch2c         (Conv2D              )   TRAIN
#   13  res2a_branch1          (Conv2D              )   TRAIN
#   14  bn2a_branch2c          (BatchNorm           )   TRAIN
#   15  bn2a_branch1           (BatchNorm           )   TRAIN
#   16  add_1                  (Add                 )   ............................no weights to train ]
#   17  res2a_out              (Activation          )   ............................no weights to train ]
#   18  res2b_branch2a         (Conv2D              )   TRAIN
#   19  bn2b_branch2a          (BatchNorm           )   TRAIN
#   20  activation_4           (Activation          )   ............................no weights to train ]
#   21  res2b_branch2b         (Conv2D              )   TRAIN
#   22  bn2b_branch2b          (BatchNorm           )   TRAIN
#   23  activation_5           (Activation          )   ............................no weights to train ]
#   24  res2b_branch2c         (Conv2D              )   TRAIN
#   25  bn2b_branch2c          (BatchNorm           )   TRAIN
#   26  add_2                  (Add                 )   ............................no weights to train ]
#   27  res2b_out              (Activation          )   ............................no weights to train ]
#   28  res2c_branch2a         (Conv2D              )   TRAIN
#   29  bn2c_branch2a          (BatchNorm           )   TRAIN
#   30  activation_6           (Activation          )   ............................no weights to train ]
#   31  res2c_branch2b         (Conv2D              )   TRAIN
#   32  bn2c_branch2b          (BatchNorm           )   TRAIN
#   33  activation_7           (Activation          )   ............................no weights to train ]
#   34  res2c_branch2c         (Conv2D              )   TRAIN
#   35  bn2c_branch2c          (BatchNorm           )   TRAIN
#   36  add_3                  (Add                 )   ............................no weights to train ]
#   37  res2c_out              (Activation          )   ............................no weights to train ]
#   38  res3a_branch2a         (Conv2D              )   TRAIN
#   39  bn3a_branch2a          (BatchNorm           )   TRAIN
#   40  activation_8           (Activation          )   ............................no weights to train ]
#   41  res3a_branch2b         (Conv2D              )   TRAIN
#   42  bn3a_branch2b          (BatchNorm           )   TRAIN
#   43  activation_9           (Activation          )   ............................no weights to train ]
#   44  res3a_branch2c         (Conv2D              )   TRAIN
#   45  res3a_branch1          (Conv2D              )   TRAIN
#   46  bn3a_branch2c          (BatchNorm           )   TRAIN
#   47  bn3a_branch1           (BatchNorm           )   TRAIN
#   48  add_4                  (Add                 )   ............................no weights to train ]
#   49  res3a_out              (Activation          )   ............................no weights to train ]
#   50  res3b_branch2a         (Conv2D              )   TRAIN
#   51  bn3b_branch2a          (BatchNorm           )   TRAIN
#   52  activation_10          (Activation          )   ............................no weights to train ]
#   53  res3b_branch2b         (Conv2D              )   TRAIN
#   54  bn3b_branch2b          (BatchNorm           )   TRAIN
#   55  activation_11          (Activation          )   ............................no weights to train ]
#   56  res3b_branch2c         (Conv2D              )   TRAIN
#   57  bn3b_branch2c          (BatchNorm           )   TRAIN
#   58  add_5                  (Add                 )   ............................no weights to train ]
#   59  res3b_out              (Activation          )   ............................no weights to train ]
#   60  res3c_branch2a         (Conv2D              )   TRAIN
#   61  bn3c_branch2a          (BatchNorm           )   TRAIN
#   62  activation_12          (Activation          )   ............................no weights to train ]
#   63  res3c_branch2b         (Conv2D              )   TRAIN
#   64  bn3c_branch2b          (BatchNorm           )   TRAIN
#   65  activation_13          (Activation          )   ............................no weights to train ]
#   66  res3c_branch2c         (Conv2D              )   TRAIN
#   67  bn3c_branch2c          (BatchNorm           )   TRAIN
#   68  add_6                  (Add                 )   ............................no weights to train ]
#   69  res3c_out              (Activation          )   ............................no weights to train ]
#   70  res3d_branch2a         (Conv2D              )   TRAIN
#   71  bn3d_branch2a          (BatchNorm           )   TRAIN
#   72  activation_14          (Activation          )   ............................no weights to train ]
#   73  res3d_branch2b         (Conv2D              )   TRAIN
#   74  bn3d_branch2b          (BatchNorm           )   TRAIN
#   75  activation_15          (Activation          )   ............................no weights to train ]
#   76  res3d_branch2c         (Conv2D              )   TRAIN
#   77  bn3d_branch2c          (BatchNorm           )   TRAIN
#   78  add_7                  (Add                 )   ............................no weights to train ]
#   79  res3d_out              (Activation          )   ............................no weights to train ]
#   80  res4a_branch2a         (Conv2D              )   TRAIN
#   81  bn4a_branch2a          (BatchNorm           )   TRAIN
#   82  activation_16          (Activation          )   ............................no weights to train ]
#   83  res4a_branch2b         (Conv2D              )   TRAIN
#   84  bn4a_branch2b          (BatchNorm           )   TRAIN
#   85  activation_17          (Activation          )   ............................no weights to train ]
#   86  res4a_branch2c         (Conv2D              )   TRAIN
#   87  res4a_branch1          (Conv2D              )   TRAIN
#   88  bn4a_branch2c          (BatchNorm           )   TRAIN
#   89  bn4a_branch1           (BatchNorm           )   TRAIN
#   90  add_8                  (Add                 )   ............................no weights to train ]
#   91  res4a_out              (Activation          )   ............................no weights to train ]
#   92  res4b_branch2a         (Conv2D              )   TRAIN
#   93  bn4b_branch2a          (BatchNorm           )   TRAIN
#   94  activation_18          (Activation          )   ............................no weights to train ]
#   95  res4b_branch2b         (Conv2D              )   TRAIN
#   96  bn4b_branch2b          (BatchNorm           )   TRAIN
#   97  activation_19          (Activation          )   ............................no weights to train ]
#   98  res4b_branch2c         (Conv2D              )   TRAIN
#   99  bn4b_branch2c          (BatchNorm           )   TRAIN
#  100  add_9                  (Add                 )   ............................no weights to train ]
#  101  res4b_out              (Activation          )   ............................no weights to train ]
#  102  res4c_branch2a         (Conv2D              )   TRAIN
#  103  bn4c_branch2a          (BatchNorm           )   TRAIN
#  104  activation_20          (Activation          )   ............................no weights to train ]
#  105  res4c_branch2b         (Conv2D              )   TRAIN
#  106  bn4c_branch2b          (BatchNorm           )   TRAIN
#  107  activation_21          (Activation          )   ............................no weights to train ]
#  108  res4c_branch2c         (Conv2D              )   TRAIN
#  109  bn4c_branch2c          (BatchNorm           )   TRAIN
#  110  add_10                 (Add                 )   ............................no weights to train ]
#  111  res4c_out              (Activation          )   ............................no weights to train ]
#  112  res4d_branch2a         (Conv2D              )   TRAIN
#  113  bn4d_branch2a          (BatchNorm           )   TRAIN
#  114  activation_22          (Activation          )   ............................no weights to train ]
#  115  res4d_branch2b         (Conv2D              )   TRAIN
#  116  bn4d_branch2b          (BatchNorm           )   TRAIN
#  117  activation_23          (Activation          )   ............................no weights to train ]
#  118  res4d_branch2c         (Conv2D              )   TRAIN
#  119  bn4d_branch2c          (BatchNorm           )   TRAIN
#  120  add_11                 (Add                 )   ............................no weights to train ]
#  121  res4d_out              (Activation          )   ............................no weights to train ]
#  122  res4e_branch2a         (Conv2D              )   TRAIN
#  123  bn4e_branch2a          (BatchNorm           )   TRAIN
#  124  activation_24          (Activation          )   ............................no weights to train ]
#  125  res4e_branch2b         (Conv2D              )   TRAIN
#  126  bn4e_branch2b          (BatchNorm           )   TRAIN
#  127  activation_25          (Activation          )   ............................no weights to train ]
#  128  res4e_branch2c         (Conv2D              )   TRAIN
#  129  bn4e_branch2c          (BatchNorm           )   TRAIN
#  130  add_12                 (Add                 )   ............................no weights to train ]
#  131  res4e_out              (Activation          )   ............................no weights to train ]
#  132  res4f_branch2a         (Conv2D              )   TRAIN
#  133  bn4f_branch2a          (BatchNorm           )   TRAIN
#  134  activation_26          (Activation          )   ............................no weights to train ]
#  135  res4f_branch2b         (Conv2D              )   TRAIN
#  136  bn4f_branch2b          (BatchNorm           )   TRAIN
#  137  activation_27          (Activation          )   ............................no weights to train ]
#  138  res4f_branch2c         (Conv2D              )   TRAIN
#  139  bn4f_branch2c          (BatchNorm           )   TRAIN
#  140  add_13                 (Add                 )   ............................no weights to train ]
#  141  res4f_out              (Activation          )   ............................no weights to train ]
#  142  res4g_branch2a         (Conv2D              )   TRAIN
#  143  bn4g_branch2a          (BatchNorm           )   TRAIN
#  144  activation_28          (Activation          )   ............................no weights to train ]
#  145  res4g_branch2b         (Conv2D              )   TRAIN
#  146  bn4g_branch2b          (BatchNorm           )   TRAIN
#  147  activation_29          (Activation          )   ............................no weights to train ]
#  148  res4g_branch2c         (Conv2D              )   TRAIN
#  149  bn4g_branch2c          (BatchNorm           )   TRAIN
#  150  add_14                 (Add                 )   ............................no weights to train ]
#  151  res4g_out              (Activation          )   ............................no weights to train ]
#  152  res4h_branch2a         (Conv2D              )   TRAIN
#  153  bn4h_branch2a          (BatchNorm           )   TRAIN
#  154  activation_30          (Activation          )   ............................no weights to train ]
#  155  res4h_branch2b         (Conv2D              )   TRAIN
#  156  bn4h_branch2b          (BatchNorm           )   TRAIN
#  157  activation_31          (Activation          )   ............................no weights to train ]
#  158  res4h_branch2c         (Conv2D              )   TRAIN
#  159  bn4h_branch2c          (BatchNorm           )   TRAIN
#  160  add_15                 (Add                 )   ............................no weights to train ]
#  161  res4h_out              (Activation          )   ............................no weights to train ]
#  162  res4i_branch2a         (Conv2D              )   TRAIN
#  163  bn4i_branch2a          (BatchNorm           )   TRAIN
#  164  activation_32          (Activation          )   ............................no weights to train ]
#  165  res4i_branch2b         (Conv2D              )   TRAIN
#  166  bn4i_branch2b          (BatchNorm           )   TRAIN
#  167  activation_33          (Activation          )   ............................no weights to train ]
#  168  res4i_branch2c         (Conv2D              )   TRAIN
#  169  bn4i_branch2c          (BatchNorm           )   TRAIN
#  170  add_16                 (Add                 )   ............................no weights to train ]
#  171  res4i_out              (Activation          )   ............................no weights to train ]
#  172  res4j_branch2a         (Conv2D              )   TRAIN
#  173  bn4j_branch2a          (BatchNorm           )   TRAIN
#  174  activation_34          (Activation          )   ............................no weights to train ]
#  175  res4j_branch2b         (Conv2D              )   TRAIN
#  176  bn4j_branch2b          (BatchNorm           )   TRAIN
#  177  activation_35          (Activation          )   ............................no weights to train ]
#  178  res4j_branch2c         (Conv2D              )   TRAIN
#  179  bn4j_branch2c          (BatchNorm           )   TRAIN
#  180  add_17                 (Add                 )   ............................no weights to train ]
#  181  res4j_out              (Activation          )   ............................no weights to train ]
#  182  res4k_branch2a         (Conv2D              )   TRAIN
#  183  bn4k_branch2a          (BatchNorm           )   TRAIN
#  184  activation_36          (Activation          )   ............................no weights to train ]
#  185  res4k_branch2b         (Conv2D              )   TRAIN
#  186  bn4k_branch2b          (BatchNorm           )   TRAIN
#  187  activation_37          (Activation          )   ............................no weights to train ]
#  188  res4k_branch2c         (Conv2D              )   TRAIN
#  189  bn4k_branch2c          (BatchNorm           )   TRAIN
#  190  add_18                 (Add                 )   ............................no weights to train ]
#  191  res4k_out              (Activation          )   ............................no weights to train ]
#  192  res4l_branch2a         (Conv2D              )   TRAIN
#  193  bn4l_branch2a          (BatchNorm           )   TRAIN
#  194  activation_38          (Activation          )   ............................no weights to train ]
#  195  res4l_branch2b         (Conv2D              )   TRAIN
#  196  bn4l_branch2b          (BatchNorm           )   TRAIN
#  197  activation_39          (Activation          )   ............................no weights to train ]
#  198  res4l_branch2c         (Conv2D              )   TRAIN
#  199  bn4l_branch2c          (BatchNorm           )   TRAIN
#  200  add_19                 (Add                 )   ............................no weights to train ]
#  201  res4l_out              (Activation          )   ............................no weights to train ]
#  202  res4m_branch2a         (Conv2D              )   TRAIN
#  203  bn4m_branch2a          (BatchNorm           )   TRAIN
#  204  activation_40          (Activation          )   ............................no weights to train ]
#  205  res4m_branch2b         (Conv2D              )   TRAIN
#  206  bn4m_branch2b          (BatchNorm           )   TRAIN
#  207  activation_41          (Activation          )   ............................no weights to train ]
#  208  res4m_branch2c         (Conv2D              )   TRAIN
#  209  bn4m_branch2c          (BatchNorm           )   TRAIN
#  210  add_20                 (Add                 )   ............................no weights to train ]
#  211  res4m_out              (Activation          )   ............................no weights to train ]
#  212  res4n_branch2a         (Conv2D              )   TRAIN
#  213  bn4n_branch2a          (BatchNorm           )   TRAIN
#  214  activation_42          (Activation          )   ............................no weights to train ]
#  215  res4n_branch2b         (Conv2D              )   TRAIN
#  216  bn4n_branch2b          (BatchNorm           )   TRAIN
#  217  activation_43          (Activation          )   ............................no weights to train ]
#  218  res4n_branch2c         (Conv2D              )   TRAIN
#  219  bn4n_branch2c          (BatchNorm           )   TRAIN
#  220  add_21                 (Add                 )   ............................no weights to train ]
#  221  res4n_out              (Activation          )   ............................no weights to train ]
#  222  res4o_branch2a         (Conv2D              )   TRAIN
#  223  bn4o_branch2a          (BatchNorm           )   TRAIN
#  224  activation_44          (Activation          )   ............................no weights to train ]
#  225  res4o_branch2b         (Conv2D              )   TRAIN
#  226  bn4o_branch2b          (BatchNorm           )   TRAIN
#  227  activation_45          (Activation          )   ............................no weights to train ]
#  228  res4o_branch2c         (Conv2D              )   TRAIN
#  229  bn4o_branch2c          (BatchNorm           )   TRAIN
#  230  add_22                 (Add                 )   ............................no weights to train ]
#  231  res4o_out              (Activation          )   ............................no weights to train ]
#  232  res4p_branch2a         (Conv2D              )   TRAIN
#  233  bn4p_branch2a          (BatchNorm           )   TRAIN
#  234  activation_46          (Activation          )   ............................no weights to train ]
#  235  res4p_branch2b         (Conv2D              )   TRAIN
#  236  bn4p_branch2b          (BatchNorm           )   TRAIN
#  237  activation_47          (Activation          )   ............................no weights to train ]
#  238  res4p_branch2c         (Conv2D              )   TRAIN
#  239  bn4p_branch2c          (BatchNorm           )   TRAIN
#  240  add_23                 (Add                 )   ............................no weights to train ]
#  241  res4p_out              (Activation          )   ............................no weights to train ]
#  242  res4q_branch2a         (Conv2D              )   TRAIN
#  243  bn4q_branch2a          (BatchNorm           )   TRAIN
#  244  activation_48          (Activation          )   ............................no weights to train ]
#  245  res4q_branch2b         (Conv2D              )   TRAIN
#  246  bn4q_branch2b          (BatchNorm           )   TRAIN
#  247  activation_49          (Activation          )   ............................no weights to train ]
#  248  res4q_branch2c         (Conv2D              )   TRAIN
#  249  bn4q_branch2c          (BatchNorm           )   TRAIN
#  250  add_24                 (Add                 )   ............................no weights to train ]
#  251  res4q_out              (Activation          )   ............................no weights to train ]
#  252  res4r_branch2a         (Conv2D              )   TRAIN
#  253  bn4r_branch2a          (BatchNorm           )   TRAIN
#  254  activation_50          (Activation          )   ............................no weights to train ]
#  255  res4r_branch2b         (Conv2D              )   TRAIN
#  256  bn4r_branch2b          (BatchNorm           )   TRAIN
#  257  activation_51          (Activation          )   ............................no weights to train ]
#  258  res4r_branch2c         (Conv2D              )   TRAIN
#  259  bn4r_branch2c          (BatchNorm           )   TRAIN
#  260  add_25                 (Add                 )   ............................no weights to train ]
#  261  res4r_out              (Activation          )   ............................no weights to train ]
#  262  res4s_branch2a         (Conv2D              )   TRAIN
#  263  bn4s_branch2a          (BatchNorm           )   TRAIN
#  264  activation_52          (Activation          )   ............................no weights to train ]
#  265  res4s_branch2b         (Conv2D              )   TRAIN
#  266  bn4s_branch2b          (BatchNorm           )   TRAIN
#  267  activation_53          (Activation          )   ............................no weights to train ]
#  268  res4s_branch2c         (Conv2D              )   TRAIN
#  269  bn4s_branch2c          (BatchNorm           )   TRAIN
#  270  add_26                 (Add                 )   ............................no weights to train ]
#  271  res4s_out              (Activation          )   ............................no weights to train ]
#  272  res4t_branch2a         (Conv2D              )   TRAIN
#  273  bn4t_branch2a          (BatchNorm           )   TRAIN
#  274  activation_54          (Activation          )   ............................no weights to train ]
#  275  res4t_branch2b         (Conv2D              )   TRAIN
#  276  bn4t_branch2b          (BatchNorm           )   TRAIN
#  277  activation_55          (Activation          )   ............................no weights to train ]
#  278  res4t_branch2c         (Conv2D              )   TRAIN
#  279  bn4t_branch2c          (BatchNorm           )   TRAIN
#  280  add_27                 (Add                 )   ............................no weights to train ]
#  281  res4t_out              (Activation          )   ............................no weights to train ]
#  282  res4u_branch2a         (Conv2D              )   TRAIN
#  283  bn4u_branch2a          (BatchNorm           )   TRAIN
#  284  activation_56          (Activation          )   ............................no weights to train ]
#  285  res4u_branch2b         (Conv2D              )   TRAIN
#  286  bn4u_branch2b          (BatchNorm           )   TRAIN
#  287  activation_57          (Activation          )   ............................no weights to train ]
#  288  res4u_branch2c         (Conv2D              )   TRAIN
#  289  bn4u_branch2c          (BatchNorm           )   TRAIN
#  290  add_28                 (Add                 )   ............................no weights to train ]
#  291  res4u_out              (Activation          )   ............................no weights to train ]
#  292  res4v_branch2a         (Conv2D              )   TRAIN
#  293  bn4v_branch2a          (BatchNorm           )   TRAIN
#  294  activation_58          (Activation          )   ............................no weights to train ]
#  295  res4v_branch2b         (Conv2D              )   TRAIN
#  296  bn4v_branch2b          (BatchNorm           )   TRAIN
#  297  activation_59          (Activation          )   ............................no weights to train ]
#  298  res4v_branch2c         (Conv2D              )   TRAIN
#  299  bn4v_branch2c          (BatchNorm           )   TRAIN
#  300  add_29                 (Add                 )   ............................no weights to train ]
#  301  res4v_out              (Activation          )   ............................no weights to train ]
#  302  res4w_branch2a         (Conv2D              )   TRAIN
#  303  bn4w_branch2a          (BatchNorm           )   TRAIN
#  304  activation_60          (Activation          )   ............................no weights to train ]
#  305  res4w_branch2b         (Conv2D              )   TRAIN
#  306  bn4w_branch2b          (BatchNorm           )   TRAIN
#  307  activation_61          (Activation          )   ............................no weights to train ]
#  308  res4w_branch2c         (Conv2D              )   TRAIN
#  309  bn4w_branch2c          (BatchNorm           )   TRAIN
#  310  add_30                 (Add                 )   ............................no weights to train ]
#  311  res4w_out              (Activation          )   ............................no weights to train ]
#  312  res5a_branch2a         (Conv2D              )   TRAIN
#  313  bn5a_branch2a          (BatchNorm           )   TRAIN
#  314  activation_62          (Activation          )   ............................no weights to train ]
#  315  res5a_branch2b         (Conv2D              )   TRAIN
#  316  bn5a_branch2b          (BatchNorm           )   TRAIN
#  317  activation_63          (Activation          )   ............................no weights to train ]
#  318  res5a_branch2c         (Conv2D              )   TRAIN
#  319  res5a_branch1          (Conv2D              )   TRAIN
#  320  bn5a_branch2c          (BatchNorm           )   TRAIN
#  321  bn5a_branch1           (BatchNorm           )   TRAIN
#  322  add_31                 (Add                 )   ............................no weights to train ]
#  323  res5a_out              (Activation          )   ............................no weights to train ]
#  324  res5b_branch2a         (Conv2D              )   TRAIN
#  325  bn5b_branch2a          (BatchNorm           )   TRAIN
#  326  activation_64          (Activation          )   ............................no weights to train ]
#  327  res5b_branch2b         (Conv2D              )   TRAIN
#  328  bn5b_branch2b          (BatchNorm           )   TRAIN
#  329  activation_65          (Activation          )   ............................no weights to train ]
#  330  res5b_branch2c         (Conv2D              )   TRAIN
#  331  bn5b_branch2c          (BatchNorm           )   TRAIN
#  332  add_32                 (Add                 )   ............................no weights to train ]
#  333  res5b_out              (Activation          )   ............................no weights to train ]
#  334  res5c_branch2a         (Conv2D              )   TRAIN
#  335  bn5c_branch2a          (BatchNorm           )   TRAIN
#  336  activation_66          (Activation          )   ............................no weights to train ]
#  337  res5c_branch2b         (Conv2D              )   TRAIN
#  338  bn5c_branch2b          (BatchNorm           )   TRAIN
#  339  activation_67          (Activation          )   ............................no weights to train ]
#  340  res5c_branch2c         (Conv2D              )   TRAIN
#  341  bn5c_branch2c          (BatchNorm           )   TRAIN
#  342  add_33                 (Add                 )   ............................no weights to train ]
#  343  res5c_out              (Activation          )   ............................no weights to train ]
#  344  fpn_c5p5               (Conv2D              )   TRAIN
#  345  fpn_p5upsampled        (UpSampling2D        )   ............................no weights to train ]
#  346  fpn_c4p4               (Conv2D              )   TRAIN
#  347  fpn_p4add              (Add                 )   ............................no weights to train ]
#  348  fpn_p4upsampled        (UpSampling2D        )   ............................no weights to train ]
#  349  fpn_c3p3               (Conv2D              )   TRAIN
#  350  fpn_p3add              (Add                 )   ............................no weights to train ]
#  351  fpn_p3upsampled        (UpSampling2D        )   ............................no weights to train ]
#  352  fpn_c2p2               (Conv2D              )   TRAIN
#  353  fpn_p2add              (Add                 )   ............................no weights to train ]
#  354  fpn_p5                 (Conv2D              )   TRAIN
#  355  fpn_p2                 (Conv2D              )   TRAIN
#  356  fpn_p3                 (Conv2D              )   TRAIN
#  357  fpn_p4                 (Conv2D              )   TRAIN
#  358  fpn_p6                 (MaxPooling2D        )   ............................no weights to train ]
# Entering model layer:  rpn_model ------------------------------
#        0  input_rpn_feature_map   (InputLayer          )   ............................no weights to train ]
#        1  rpn_conv_shared        (Conv2D              )   TRAIN
#        2  rpn_class_raw          (Conv2D              )   TRAIN
#        3  lambda_1               (Lambda              )   ............................no weights to train ]
#        4  rpn_bbox_pred          (Conv2D              )   TRAIN
#        5  rpn_class_xxx          (Activation          )   ............................no weights to train ]
#        6  lambda_2               (Lambda              )   ............................no weights to train ]
# Exiting model layer  rpn_model --------------------------------
#  360  rpn_class              (Lambda              )   ............................no weights to train ]
#  361  rpn_bbox               (Lambda              )   ............................no weights to train ]
#  362  input_gt_boxes         (InputLayer          )   ............................no weights to train ]
#  363  ROI                    (ProposalLayer       )   ............................no weights to train ]
#  364  input_gt_class_ids     (InputLayer          )   ............................no weights to train ]
#  365  input_normalized_gt_boxes   (Lambda              )   ............................no weights to train ]
#  366  proposal_targets       (DetectionTargetLayer)   ............................no weights to train ]
#  367  roi_align_classifier   (PyramidROIAlign     )   ............................no weights to train ]
#  368  mrcnn_class_conv1      (TimeDistributed     )   TRAIN
#  369  mrcnn_class_bn1        (TimeDistributed     )   TRAIN
#  370  activation_68          (Activation          )   ............................no weights to train ]
#  371  mrcnn_class_conv2      (TimeDistributed     )   TRAIN
#  372  mrcnn_class_bn2        (TimeDistributed     )   TRAIN
#  373  activation_69          (Activation          )   ............................no weights to train ]
#  374  pool_squeeze           (Lambda              )   ............................no weights to train ]
#  375  mrcnn_class_logits     (TimeDistributed     )   TRAIN
#  376  mrcnn_logits_lambda    (Lambda              )   ............................no weights to train ]
#  377  mrcnn_bbox_fc          (TimeDistributed     )   TRAIN
#  378  mrcnn_class_act        (TimeDistributed     )   ............................no weights to train ]
#  379  mrcnn_bbox_rs          (Reshape             )   ............................no weights to train ]
#  380  input_image_meta       (InputLayer          )   ............................no weights to train ]
#  381  mrcnn_class_lambda     (Lambda              )   ............................no weights to train ]
#  382  mrcnn_bbox_lambda      (Lambda              )   ............................no weights to train ]
#  383  active_class_ids       (Lambda              )   ............................no weights to train ]
#  384  input_rpn_match        (InputLayer          )   ............................no weights to train ]
#  385  rpn_class_logits       (Lambda              )   ............................no weights to train ]
#  386  input_rpn_bbox         (InputLayer          )   ............................no weights to train ]
#  387  cntxt_layer            (CHMLayer            )   ............................no weights to train ]
#  388  cntxt_layer_gt         (CHMLayerTarget      )   ............................no weights to train ]
#  389  rpn_class_loss         (Lambda              )   ............................no weights to train ]
#  390  rpn_bbox_loss          (Lambda              )   ............................no weights to train ]
#  391  mrcnn_class_loss       (Lambda              )   ............................no weights to train ]
#  392  mrcnn_bbox_loss        (Lambda              )   ............................no weights to train ]
#     learning rate :  0.0001
#     momentum      :  0.9
#
#
#
#  Compile Model :
# ----------------
#     losses        :  ['rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#     optimizer     :  <keras.optimizers.Adam object at 0x7fb1515d8080>
#     learning rate :  0.0001
#     momentum      :  0.9
#
#  Add losses:
# ----------------
#     losses:  ['rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#     keras_model.losses           : []
#
#     Loss: rpn_class_loss  Related Layer is : rpn_class_loss
#       >> Add add loss for  Tensor("rpn_class_loss/rpn_class_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: rpn_bbox_loss  Related Layer is : rpn_bbox_loss
#       >> Add add loss for  Tensor("rpn_bbox_loss/rpn_bbox_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: mrcnn_class_loss  Related Layer is : mrcnn_class_loss
#       >> Add add loss for  Tensor("mrcnn_class_loss/mrcnn_class_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#     Loss: mrcnn_bbox_loss  Related Layer is : mrcnn_bbox_loss
#       >> Add add loss for  Tensor("mrcnn_bbox_loss/mrcnn_bbox_loss:0", shape=(1, 1), dtype=float32)  to list of losses...
#
# Keras model.losses :
# ---------------------
#    Tensor("Mean:0", shape=(1, 1), dtype=float32)    name: Mean:0
#    Tensor("Mean_3:0", shape=(1, 1), dtype=float32)    name: Mean_3:0
#    Tensor("Mean_1:0", shape=(1, 1), dtype=float32)    name: Mean_1:0
#    Tensor("Mean_2:0", shape=(1, 1), dtype=float32)    name: Mean_2:0
#
# Keras_model._losses:
# ---------------------
#    Tensor("Mean:0", shape=(1, 1), dtype=float32)    name: Mean:0
#    Tensor("Mean_1:0", shape=(1, 1), dtype=float32)    name: Mean_1:0
#    Tensor("Mean_2:0", shape=(1, 1), dtype=float32)    name: Mean_2:0
#    Tensor("Mean_3:0", shape=(1, 1), dtype=float32)    name: Mean_3:0
#
# Keras_model._per_input_losses:
# ------------------------------
#    None    name: <class 'NoneType'>
# {   None: [   <tf.Tensor 'Mean:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_1:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_2:0' shape=(1, 1) dtype=float32>,
#               <tf.Tensor 'Mean_3:0' shape=(1, 1) dtype=float32>]}
# L2 Regularization losses:
# -------------------------
#    Tensor("truediv:0", shape=(), dtype=float32)    name: truediv:0
#    Tensor("truediv_1:0", shape=(), dtype=float32)    name: truediv_1:0
#    Tensor("truediv_2:0", shape=(), dtype=float32)    name: truediv_2:0
#    Tensor("truediv_3:0", shape=(), dtype=float32)    name: truediv_3:0
#    Tensor("truediv_4:0", shape=(), dtype=float32)    name: truediv_4:0
#    Tensor("truediv_5:0", shape=(), dtype=float32)    name: truediv_5:0
#    Tensor("truediv_6:0", shape=(), dtype=float32)    name: truediv_6:0
#    Tensor("truediv_7:0", shape=(), dtype=float32)    name: truediv_7:0
#    Tensor("truediv_8:0", shape=(), dtype=float32)    name: truediv_8:0
#    Tensor("truediv_9:0", shape=(), dtype=float32)    name: truediv_9:0
#    Tensor("truediv_10:0", shape=(), dtype=float32)    name: truediv_10:0
#    Tensor("truediv_11:0", shape=(), dtype=float32)    name: truediv_11:0
#    Tensor("truediv_12:0", shape=(), dtype=float32)    name: truediv_12:0
#    Tensor("truediv_13:0", shape=(), dtype=float32)    name: truediv_13:0
#    Tensor("truediv_14:0", shape=(), dtype=float32)    name: truediv_14:0
#    Tensor("truediv_15:0", shape=(), dtype=float32)    name: truediv_15:0
#    Tensor("truediv_16:0", shape=(), dtype=float32)    name: truediv_16:0
#    Tensor("truediv_17:0", shape=(), dtype=float32)    name: truediv_17:0
#    Tensor("truediv_18:0", shape=(), dtype=float32)    name: truediv_18:0
#    Tensor("truediv_19:0", shape=(), dtype=float32)    name: truediv_19:0
#    Tensor("truediv_20:0", shape=(), dtype=float32)    name: truediv_20:0
#    Tensor("truediv_21:0", shape=(), dtype=float32)    name: truediv_21:0
#    Tensor("truediv_22:0", shape=(), dtype=float32)    name: truediv_22:0
#    Tensor("truediv_23:0", shape=(), dtype=float32)    name: truediv_23:0
#    Tensor("truediv_24:0", shape=(), dtype=float32)    name: truediv_24:0
#    Tensor("truediv_25:0", shape=(), dtype=float32)    name: truediv_25:0
#    Tensor("truediv_26:0", shape=(), dtype=float32)    name: truediv_26:0
#    Tensor("truediv_27:0", shape=(), dtype=float32)    name: truediv_27:0
#    Tensor("truediv_28:0", shape=(), dtype=float32)    name: truediv_28:0
#    Tensor("truediv_29:0", shape=(), dtype=float32)    name: truediv_29:0
#    Tensor("truediv_30:0", shape=(), dtype=float32)    name: truediv_30:0
#    Tensor("truediv_31:0", shape=(), dtype=float32)    name: truediv_31:0
#    Tensor("truediv_32:0", shape=(), dtype=float32)    name: truediv_32:0
#    Tensor("truediv_33:0", shape=(), dtype=float32)    name: truediv_33:0
#    Tensor("truediv_34:0", shape=(), dtype=float32)    name: truediv_34:0
#    Tensor("truediv_35:0", shape=(), dtype=float32)    name: truediv_35:0
#    Tensor("truediv_36:0", shape=(), dtype=float32)    name: truediv_36:0
#    Tensor("truediv_37:0", shape=(), dtype=float32)    name: truediv_37:0
#    Tensor("truediv_38:0", shape=(), dtype=float32)    name: truediv_38:0
#    Tensor("truediv_39:0", shape=(), dtype=float32)    name: truediv_39:0
#    Tensor("truediv_40:0", shape=(), dtype=float32)    name: truediv_40:0
#    Tensor("truediv_41:0", shape=(), dtype=float32)    name: truediv_41:0
#    Tensor("truediv_42:0", shape=(), dtype=float32)    name: truediv_42:0
#    Tensor("truediv_43:0", shape=(), dtype=float32)    name: truediv_43:0
#    Tensor("truediv_44:0", shape=(), dtype=float32)    name: truediv_44:0
#    Tensor("truediv_45:0", shape=(), dtype=float32)    name: truediv_45:0
#    Tensor("truediv_46:0", shape=(), dtype=float32)    name: truediv_46:0
#    Tensor("truediv_47:0", shape=(), dtype=float32)    name: truediv_47:0
#    Tensor("truediv_48:0", shape=(), dtype=float32)    name: truediv_48:0
#    Tensor("truediv_49:0", shape=(), dtype=float32)    name: truediv_49:0
#    Tensor("truediv_50:0", shape=(), dtype=float32)    name: truediv_50:0
#    Tensor("truediv_51:0", shape=(), dtype=float32)    name: truediv_51:0
#    Tensor("truediv_52:0", shape=(), dtype=float32)    name: truediv_52:0
#    Tensor("truediv_53:0", shape=(), dtype=float32)    name: truediv_53:0
#    Tensor("truediv_54:0", shape=(), dtype=float32)    name: truediv_54:0
#    Tensor("truediv_55:0", shape=(), dtype=float32)    name: truediv_55:0
#    Tensor("truediv_56:0", shape=(), dtype=float32)    name: truediv_56:0
#    Tensor("truediv_57:0", shape=(), dtype=float32)    name: truediv_57:0
#    Tensor("truediv_58:0", shape=(), dtype=float32)    name: truediv_58:0
#    Tensor("truediv_59:0", shape=(), dtype=float32)    name: truediv_59:0
#    Tensor("truediv_60:0", shape=(), dtype=float32)    name: truediv_60:0
#    Tensor("truediv_61:0", shape=(), dtype=float32)    name: truediv_61:0
#    Tensor("truediv_62:0", shape=(), dtype=float32)    name: truediv_62:0
#    Tensor("truediv_63:0", shape=(), dtype=float32)    name: truediv_63:0
#    Tensor("truediv_64:0", shape=(), dtype=float32)    name: truediv_64:0
#    Tensor("truediv_65:0", shape=(), dtype=float32)    name: truediv_65:0
#    Tensor("truediv_66:0", shape=(), dtype=float32)    name: truediv_66:0
#    Tensor("truediv_67:0", shape=(), dtype=float32)    name: truediv_67:0
#    Tensor("truediv_68:0", shape=(), dtype=float32)    name: truediv_68:0
#    Tensor("truediv_69:0", shape=(), dtype=float32)    name: truediv_69:0
#    Tensor("truediv_70:0", shape=(), dtype=float32)    name: truediv_70:0
#    Tensor("truediv_71:0", shape=(), dtype=float32)    name: truediv_71:0
#    Tensor("truediv_72:0", shape=(), dtype=float32)    name: truediv_72:0
#    Tensor("truediv_73:0", shape=(), dtype=float32)    name: truediv_73:0
#    Tensor("truediv_74:0", shape=(), dtype=float32)    name: truediv_74:0
#    Tensor("truediv_75:0", shape=(), dtype=float32)    name: truediv_75:0
#    Tensor("truediv_76:0", shape=(), dtype=float32)    name: truediv_76:0
#    Tensor("truediv_77:0", shape=(), dtype=float32)    name: truediv_77:0
#    Tensor("truediv_78:0", shape=(), dtype=float32)    name: truediv_78:0
#    Tensor("truediv_79:0", shape=(), dtype=float32)    name: truediv_79:0
#    Tensor("truediv_80:0", shape=(), dtype=float32)    name: truediv_80:0
#    Tensor("truediv_81:0", shape=(), dtype=float32)    name: truediv_81:0
#    Tensor("truediv_82:0", shape=(), dtype=float32)    name: truediv_82:0
#    Tensor("truediv_83:0", shape=(), dtype=float32)    name: truediv_83:0
#    Tensor("truediv_84:0", shape=(), dtype=float32)    name: truediv_84:0
#    Tensor("truediv_85:0", shape=(), dtype=float32)    name: truediv_85:0
#    Tensor("truediv_86:0", shape=(), dtype=float32)    name: truediv_86:0
#    Tensor("truediv_87:0", shape=(), dtype=float32)    name: truediv_87:0
#    Tensor("truediv_88:0", shape=(), dtype=float32)    name: truediv_88:0
#    Tensor("truediv_89:0", shape=(), dtype=float32)    name: truediv_89:0
#    Tensor("truediv_90:0", shape=(), dtype=float32)    name: truediv_90:0
#    Tensor("truediv_91:0", shape=(), dtype=float32)    name: truediv_91:0
#    Tensor("truediv_92:0", shape=(), dtype=float32)    name: truediv_92:0
#    Tensor("truediv_93:0", shape=(), dtype=float32)    name: truediv_93:0
#    Tensor("truediv_94:0", shape=(), dtype=float32)    name: truediv_94:0
#    Tensor("truediv_95:0", shape=(), dtype=float32)    name: truediv_95:0
#    Tensor("truediv_96:0", shape=(), dtype=float32)    name: truediv_96:0
#    Tensor("truediv_97:0", shape=(), dtype=float32)    name: truediv_97:0
#    Tensor("truediv_98:0", shape=(), dtype=float32)    name: truediv_98:0
#    Tensor("truediv_99:0", shape=(), dtype=float32)    name: truediv_99:0
#    Tensor("truediv_100:0", shape=(), dtype=float32)    name: truediv_100:0
#    Tensor("truediv_101:0", shape=(), dtype=float32)    name: truediv_101:0
#    Tensor("truediv_102:0", shape=(), dtype=float32)    name: truediv_102:0
#    Tensor("truediv_103:0", shape=(), dtype=float32)    name: truediv_103:0
#    Tensor("truediv_104:0", shape=(), dtype=float32)    name: truediv_104:0
#    Tensor("truediv_105:0", shape=(), dtype=float32)    name: truediv_105:0
#    Tensor("truediv_106:0", shape=(), dtype=float32)    name: truediv_106:0
#    Tensor("truediv_107:0", shape=(), dtype=float32)    name: truediv_107:0
#    Tensor("truediv_108:0", shape=(), dtype=float32)    name: truediv_108:0
#    Tensor("truediv_109:0", shape=(), dtype=float32)    name: truediv_109:0
#    Tensor("truediv_110:0", shape=(), dtype=float32)    name: truediv_110:0
#    Tensor("truediv_111:0", shape=(), dtype=float32)    name: truediv_111:0
#    Tensor("truediv_112:0", shape=(), dtype=float32)    name: truediv_112:0
#    Tensor("truediv_113:0", shape=(), dtype=float32)    name: truediv_113:0
#    Tensor("truediv_114:0", shape=(), dtype=float32)    name: truediv_114:0
#    Tensor("truediv_115:0", shape=(), dtype=float32)    name: truediv_115:0
#    Tensor("truediv_116:0", shape=(), dtype=float32)    name: truediv_116:0
#    Tensor("truediv_117:0", shape=(), dtype=float32)    name: truediv_117:0
#    Tensor("truediv_118:0", shape=(), dtype=float32)    name: truediv_118:0
#    Tensor("truediv_119:0", shape=(), dtype=float32)    name: truediv_119:0
#    Tensor("truediv_120:0", shape=(), dtype=float32)    name: truediv_120:0
#    Tensor("truediv_121:0", shape=(), dtype=float32)    name: truediv_121:0
#    Tensor("truediv_122:0", shape=(), dtype=float32)    name: truediv_122:0
#    Tensor("truediv_123:0", shape=(), dtype=float32)    name: truediv_123:0
#    Tensor("truediv_124:0", shape=(), dtype=float32)    name: truediv_124:0
#    Tensor("truediv_125:0", shape=(), dtype=float32)    name: truediv_125:0
#    Tensor("truediv_126:0", shape=(), dtype=float32)    name: truediv_126:0
#    Tensor("truediv_127:0", shape=(), dtype=float32)    name: truediv_127:0
#    Tensor("truediv_128:0", shape=(), dtype=float32)    name: truediv_128:0
#    Tensor("truediv_129:0", shape=(), dtype=float32)    name: truediv_129:0
#    Tensor("truediv_130:0", shape=(), dtype=float32)    name: truediv_130:0
#    Tensor("truediv_131:0", shape=(), dtype=float32)    name: truediv_131:0
#    Tensor("truediv_132:0", shape=(), dtype=float32)    name: truediv_132:0
#    Tensor("truediv_133:0", shape=(), dtype=float32)    name: truediv_133:0
#    Tensor("truediv_134:0", shape=(), dtype=float32)    name: truediv_134:0
#    Tensor("truediv_135:0", shape=(), dtype=float32)    name: truediv_135:0
#    Tensor("truediv_136:0", shape=(), dtype=float32)    name: truediv_136:0
#    Tensor("truediv_137:0", shape=(), dtype=float32)    name: truediv_137:0
#    Tensor("truediv_138:0", shape=(), dtype=float32)    name: truediv_138:0
#    Tensor("truediv_139:0", shape=(), dtype=float32)    name: truediv_139:0
#    Tensor("truediv_140:0", shape=(), dtype=float32)    name: truediv_140:0
#    Tensor("truediv_141:0", shape=(), dtype=float32)    name: truediv_141:0
#    Tensor("truediv_142:0", shape=(), dtype=float32)    name: truediv_142:0
#    Tensor("truediv_143:0", shape=(), dtype=float32)    name: truediv_143:0
#    Tensor("truediv_144:0", shape=(), dtype=float32)    name: truediv_144:0
#    Tensor("truediv_145:0", shape=(), dtype=float32)    name: truediv_145:0
#    Tensor("truediv_146:0", shape=(), dtype=float32)    name: truediv_146:0
#    Tensor("truediv_147:0", shape=(), dtype=float32)    name: truediv_147:0
#    Tensor("truediv_148:0", shape=(), dtype=float32)    name: truediv_148:0
#    Tensor("truediv_149:0", shape=(), dtype=float32)    name: truediv_149:0
#    Tensor("truediv_150:0", shape=(), dtype=float32)    name: truediv_150:0
#    Tensor("truediv_151:0", shape=(), dtype=float32)    name: truediv_151:0
#    Tensor("truediv_152:0", shape=(), dtype=float32)    name: truediv_152:0
#    Tensor("truediv_153:0", shape=(), dtype=float32)    name: truediv_153:0
#    Tensor("truediv_154:0", shape=(), dtype=float32)    name: truediv_154:0
#    Tensor("truediv_155:0", shape=(), dtype=float32)    name: truediv_155:0
#    Tensor("truediv_156:0", shape=(), dtype=float32)    name: truediv_156:0
#    Tensor("truediv_157:0", shape=(), dtype=float32)    name: truediv_157:0
#    Tensor("truediv_158:0", shape=(), dtype=float32)    name: truediv_158:0
#    Tensor("truediv_159:0", shape=(), dtype=float32)    name: truediv_159:0
#    Tensor("truediv_160:0", shape=(), dtype=float32)    name: truediv_160:0
#    Tensor("truediv_161:0", shape=(), dtype=float32)    name: truediv_161:0
#    Tensor("truediv_162:0", shape=(), dtype=float32)    name: truediv_162:0
#    Tensor("truediv_163:0", shape=(), dtype=float32)    name: truediv_163:0
#    Tensor("truediv_164:0", shape=(), dtype=float32)    name: truediv_164:0
#    Tensor("truediv_165:0", shape=(), dtype=float32)    name: truediv_165:0
#    Tensor("truediv_166:0", shape=(), dtype=float32)    name: truediv_166:0
#    Tensor("truediv_167:0", shape=(), dtype=float32)    name: truediv_167:0
#    Tensor("truediv_168:0", shape=(), dtype=float32)    name: truediv_168:0
#    Tensor("truediv_169:0", shape=(), dtype=float32)    name: truediv_169:0
#    Tensor("truediv_170:0", shape=(), dtype=float32)    name: truediv_170:0
#    Tensor("truediv_171:0", shape=(), dtype=float32)    name: truediv_171:0
#    Tensor("truediv_172:0", shape=(), dtype=float32)    name: truediv_172:0
#    Tensor("truediv_173:0", shape=(), dtype=float32)    name: truediv_173:0
#    Tensor("truediv_174:0", shape=(), dtype=float32)    name: truediv_174:0
#    Tensor("truediv_175:0", shape=(), dtype=float32)    name: truediv_175:0
#    Tensor("truediv_176:0", shape=(), dtype=float32)    name: truediv_176:0
#    Tensor("truediv_177:0", shape=(), dtype=float32)    name: truediv_177:0
#    Tensor("truediv_178:0", shape=(), dtype=float32)    name: truediv_178:0
#    Tensor("truediv_179:0", shape=(), dtype=float32)    name: truediv_179:0
#    Tensor("truediv_180:0", shape=(), dtype=float32)    name: truediv_180:0
#    Tensor("truediv_181:0", shape=(), dtype=float32)    name: truediv_181:0
#    Tensor("truediv_182:0", shape=(), dtype=float32)    name: truediv_182:0
#    Tensor("truediv_183:0", shape=(), dtype=float32)    name: truediv_183:0
#    Tensor("truediv_184:0", shape=(), dtype=float32)    name: truediv_184:0
#    Tensor("truediv_185:0", shape=(), dtype=float32)    name: truediv_185:0
#    Tensor("truediv_186:0", shape=(), dtype=float32)    name: truediv_186:0
#    Tensor("truediv_187:0", shape=(), dtype=float32)    name: truediv_187:0
#    Tensor("truediv_188:0", shape=(), dtype=float32)    name: truediv_188:0
#    Tensor("truediv_189:0", shape=(), dtype=float32)    name: truediv_189:0
#    Tensor("truediv_190:0", shape=(), dtype=float32)    name: truediv_190:0
#    Tensor("truediv_191:0", shape=(), dtype=float32)    name: truediv_191:0
#    Tensor("truediv_192:0", shape=(), dtype=float32)    name: truediv_192:0
#    Tensor("truediv_193:0", shape=(), dtype=float32)    name: truediv_193:0
#    Tensor("truediv_194:0", shape=(), dtype=float32)    name: truediv_194:0
#    Tensor("truediv_195:0", shape=(), dtype=float32)    name: truediv_195:0
#    Tensor("truediv_196:0", shape=(), dtype=float32)    name: truediv_196:0
#    Tensor("truediv_197:0", shape=(), dtype=float32)    name: truediv_197:0
#    Tensor("truediv_198:0", shape=(), dtype=float32)    name: truediv_198:0
#    Tensor("truediv_199:0", shape=(), dtype=float32)    name: truediv_199:0
#    Tensor("truediv_200:0", shape=(), dtype=float32)    name: truediv_200:0
#    Tensor("truediv_201:0", shape=(), dtype=float32)    name: truediv_201:0
#    Tensor("truediv_202:0", shape=(), dtype=float32)    name: truediv_202:0
#    Tensor("truediv_203:0", shape=(), dtype=float32)    name: truediv_203:0
#    Tensor("truediv_204:0", shape=(), dtype=float32)    name: truediv_204:0
#    Tensor("truediv_205:0", shape=(), dtype=float32)    name: truediv_205:0
#    Tensor("truediv_206:0", shape=(), dtype=float32)    name: truediv_206:0
#    Tensor("truediv_207:0", shape=(), dtype=float32)    name: truediv_207:0
#    Tensor("truediv_208:0", shape=(), dtype=float32)    name: truediv_208:0
#    Tensor("truediv_209:0", shape=(), dtype=float32)    name: truediv_209:0
#    Tensor("truediv_210:0", shape=(), dtype=float32)    name: truediv_210:0
#    Tensor("truediv_211:0", shape=(), dtype=float32)    name: truediv_211:0
#    Tensor("truediv_212:0", shape=(), dtype=float32)    name: truediv_212:0
#    Tensor("truediv_213:0", shape=(), dtype=float32)    name: truediv_213:0
#    Tensor("truediv_214:0", shape=(), dtype=float32)    name: truediv_214:0
#    Tensor("truediv_215:0", shape=(), dtype=float32)    name: truediv_215:0
#    Tensor("truediv_216:0", shape=(), dtype=float32)    name: truediv_216:0
#    Tensor("truediv_217:0", shape=(), dtype=float32)    name: truediv_217:0
#    Tensor("truediv_218:0", shape=(), dtype=float32)    name: truediv_218:0
#    Tensor("truediv_219:0", shape=(), dtype=float32)    name: truediv_219:0
#    Tensor("truediv_220:0", shape=(), dtype=float32)    name: truediv_220:0
#    Tensor("truediv_221:0", shape=(), dtype=float32)    name: truediv_221:0
#    Tensor("truediv_222:0", shape=(), dtype=float32)    name: truediv_222:0
#    Tensor("truediv_223:0", shape=(), dtype=float32)    name: truediv_223:0
#    Tensor("truediv_224:0", shape=(), dtype=float32)    name: truediv_224:0
#    Tensor("truediv_225:0", shape=(), dtype=float32)    name: truediv_225:0
#    Tensor("truediv_226:0", shape=(), dtype=float32)    name: truediv_226:0
#    Tensor("truediv_227:0", shape=(), dtype=float32)    name: truediv_227:0
#    Tensor("truediv_228:0", shape=(), dtype=float32)    name: truediv_228:0
#    Tensor("truediv_229:0", shape=(), dtype=float32)    name: truediv_229:0
#    Tensor("truediv_230:0", shape=(), dtype=float32)    name: truediv_230:0
#    Tensor("truediv_231:0", shape=(), dtype=float32)    name: truediv_231:0
#    Tensor("truediv_232:0", shape=(), dtype=float32)    name: truediv_232:0
#    Tensor("truediv_233:0", shape=(), dtype=float32)    name: truediv_233:0
#    Tensor("truediv_234:0", shape=(), dtype=float32)    name: truediv_234:0
#    Tensor("truediv_235:0", shape=(), dtype=float32)    name: truediv_235:0
#    Tensor("truediv_236:0", shape=(), dtype=float32)    name: truediv_236:0
#    Tensor("truediv_237:0", shape=(), dtype=float32)    name: truediv_237:0
#
#     Final list of keras_model.losses
#     --------------------------------
# [   <tf.Tensor 'Mean:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'AddN:0' shape=() dtype=float32>,
#     <tf.Tensor 'Mean_3:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_1:0' shape=(1, 1) dtype=float32>,
#     <tf.Tensor 'Mean_2:0' shape=(1, 1) dtype=float32>]
#
#  Length of Keras_Model.outputs: 19
#
#  Add Metrics :
# --------------
#  Initial Keras metric_names: ['loss']
#     Loss name : rpn_class_loss  Related Layer is : rpn_class_loss
#       >> Add metric  rpn_class_loss  with metric tensor:  rpn_class_loss/rpn_class_loss:0  to list of metrics ...
#     Loss name : rpn_bbox_loss  Related Layer is : rpn_bbox_loss
#       >> Add metric  rpn_bbox_loss  with metric tensor:  rpn_bbox_loss/rpn_bbox_loss:0  to list of metrics ...
#     Loss name : mrcnn_class_loss  Related Layer is : mrcnn_class_loss
#       >> Add metric  mrcnn_class_loss  with metric tensor:  mrcnn_class_loss/mrcnn_class_loss:0  to list of metrics ...
#     Loss name : mrcnn_bbox_loss  Related Layer is : mrcnn_bbox_loss
#       >> Add metric  mrcnn_bbox_loss  with metric tensor:  mrcnn_bbox_loss/mrcnn_bbox_loss:0  to list of metrics ...
#
#  Final Keras metric_names:
#  -------------------------
# ['loss', 'rpn_class_loss', 'rpn_bbox_loss', 'mrcnn_class_loss', 'mrcnn_bbox_loss']
#
# Starting at epoch   0 of 1 epochs. LR=0.0001
#
# Steps per epoch     100
# Batch size          4
# Checkpoint Path:    /home/kbardool/models_newshapes2/train_mrcnn/mrcnn20190318T1254/mrcnn_{epoch:04d}.h5
# Learning Rate       0.0001
# Momentum            0.9
# Weight Decay:       0.0001
# VALIDATION_STEPS    8
# REDUCE_LR_FACTOR    0.5
# REDUCE_LR_COOLDOWN  30
# REDUCE_LR_PATIENCE  60
# MIN_LR              1e-10
# EARLY_STOP_PATIENCE 120
# /home/kbardool/anaconda3/envs/TFG/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
#  summary merge all
# Epoch 1/1
# 100/100 [==============================] - 83s 834ms/step - loss: 9.7641 - rpn_class_loss: 0.4190 - rpn_bbox_loss: 3.5593 - mrcnn_class_loss: 3.0707 - mrcnn_bbox_loss: 2.7151 - val_loss: 3.3755 - val_rpn_class_loss: 0.1130 - val_rpn_bbox_loss: 1.2962 - val_mrcnn_class_loss: 0.6180 - val_mrcnn_bbox_loss: 1.3483
#
# Epoch 00001: val_loss improved from inf to 3.3755360, saving model to /home/kbardool/models_newshapes2/train_mrcnn/mrcnn20190318T1254/mrcnn_0001.h5
# Final : self.epoch 1   epochs 1

# %%
pp.pprint(mrcnn_model.keras_model._feed_inputs)
pp.pprint(mrcnn_model.keras_model._feed_targets)
pp.pprint(mrcnn_model.keras_model._feed_loss_fns)
pp.pprint(mrcnn_model.keras_model._feed_outputs)
pp.pprint(mrcnn_model.keras_model._feed_sample_weights)
pp.pprint(mrcnn_model.keras_model.updates)

# %% [markdown]
# ## Fine Tuning
# Fine tune all layers
#
#     - #### Or now we can pass a list of layers we want to train in layers !
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
# model.train(dataset_train, dataset_val, learning_rate=config.LEARNING_RATE / 10, epochs=211, layers="all")

train_layers = [ 'all']   ## equivalent to "heads"
loss_names   = [ "rpn_class_loss", "rpn_bbox_loss" , "mrcnn_class_loss", "mrcnn_bbox_loss"]

mrcnn_model.config.LAST_EPOCH_RAN = 122
mrcnn_model.config.EPOCHS_TO_RUN  = 100
mrcnn_model.config.LEARNING_RATE   = 0.001
# mrcnn_model.config.STEPS_PER_EPOCH = config.STEPS_PER_EPOCH

mrcnn_model.epoch = mrcnn_model.config.LAST_EPOCH_RAN
mrcnn_model.train(dataset_train, 
            dataset_val, 
            learning_rate = mrcnn_model.config.LEARNING_RATE / 10, 
            epochs_to_run = mrcnn_model.config.EPOCHS_TO_RUN,
            layers = train_layers,
            losses = loss_names)                  
#             epochs = 25,            # total number of epochs to run (accross multiple trainings)
#             batch_size = 0
#             steps_per_epoch = 0

# %% [markdown]
# ### Save

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes_2500.h5")
model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Push Data thru model using get_layer_output()

# %% [markdown]
# ## Plot Heatmaps `pr_heatmap` and `gt_heatmap`
#
# `pred_gaussian2` and `gt_gaussian2` from Tensorflow PCN layer

# %% [markdown]
# ### Display ground truth bboxes from Shapes database (using `load_image_gt` )
#
# Here we are displaying the ground truth bounding boxes as provided by the dataset

# %%
img = 0
image_id = img_meta[img,0]
print('Image id: ',image_id)
p_original_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
# print(p_gt_class_id.shape, p_gt_bbox.shape, p_gt_mask.shape)
print(p_gt_bbox[0:3,:])
print(p_gt_class_id)
visualize.draw_boxes(p_original_image, p_gt_bbox[0:3])

# image_id = img_meta[img,0]
# print('Image id: ',image_id)
# p_original_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
#             load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
# # print(p_gt_class_id.shape, p_gt_bbox.shape, p_gt_mask.shape)
# print(p_gt_bbox)
# print(p_gt_class_id)
# visualize.draw_boxes(p_original_image, p_gt_bbox)

# %% [markdown]
# ### Display Predicted  Ground Truth Bounding Boxes  `gt_tensor` and `gt_tensor2`
#
# layers_out[22]  `gt_tensor` is based on input_gt_class_ids and input_normlzd_gt_boxes
# layers_out[28]  `gt_tensor2` is based on input_gt_class_ids and input_normlzd_gt_boxes, generated using Tensorflow
#
# Display the Ground Truth bounding boxes from the tensor we've constructed

# %%
from mrcnn.utils  import stack_tensors, stack_tensors_3d
# print(gt_bboxes)
# visualize.display_instances(p_original_image, p_gt_bbox, p_gt_mask, p_gt_class_id, 
#                             dataset_train.class_names, figsize=(8, 8))
# pp.pprint(gt_bboxes)
img = 0
image_id = img_meta[img,0]

print('Image id: ',image_id)
p_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)   
gt_bboxes_stacked = stack_tensors_3d(layers_out[22][img])
print(gt_bboxes_stacked)
visualize.draw_boxes(p_image, gt_bboxes_stacked[0:2,2:6])

# %% [markdown]
# ## Display RoI proposals `pred_bboxes` generated for one class
#
# Display bounding boxes from tensor of proposals produced by the network
# Square: 1 , Circle:2 , Triangle 3

# %%
img = 0
cls = 1 # <==== Class to display
pred_tensor = layers_out[19]   # numpy pred_tesnor
# pred_tensor = layers_out[25]   # tensorflow pred_tensor 

image_id = img_meta[img,0]
print('Image id: ',image_id)
p_image, p_image_meta, p_gt_class_id, p_gt_bbox, p_gt_mask =  \
            load_image_gt(dataset_train, config, image_id, augment=False, use_mini_mask=True)
print(p_image_meta)dd
print(pred_tensor[img,cls,:].shape)
print(pred_tensor[img,cls])
#+'-'+str(np.around(int(x[1]),decimals = 3))
# class id: str(int(x[6]))+'-'+
caps = [str(int(x[0]))+'-'+str(np.around(x[1],decimals = 3))  for x in pred_tensor[img,cls,:].tolist() ]
print(caps)

visualize.draw_boxes(p_image, pred_tensor[img,cls,:,2:6], captions = caps)

# %%
layers_out[0][0] * [128, 128,128,128]   #output_rois*

# %% [markdown]
# ### Calculate  mrcnn_bbox_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids = layers_out[1][0:1]
target_bbox      = layers_out[2][0:1]
mrcnn_bbox       = layers_out[10][0:1]
mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids

print('target_class_ids', target_class_ids.shape)
print(target_class_ids)  # tgt_class_ids
print(' class with max probability', mrcnn_class_ids.shape)
print(mrcnn_class_ids)
print('target_bboxes', target_bbox.shape)
# print(target_bbox)  # tgt_bounding boxes
print('mrcnn_bboxes',mrcnn_bbox.shape)
# print(mrcnn_bbox)  #mrcnn_bboxes
pred_bbox = mrcnn_bbox

# calc mrcnn_bbox_loss
target_class_ids = K.reshape(target_class_ids, (-1,))
print(target_class_ids.shape)
target_bbox      = K.reshape(target_bbox, (-1, 4))
print('target_bboxx: ', target_bbox.shape)
pred_bbox        = K.reshape(pred_bbox, (-1, pred_bbox.shape[2], 4))
print('pred_bbox : ', pred_bbox.shape)

positive_roi_ix        = tf.where(target_class_ids > 0)[:, 0]
print(positive_roi_ix.eval())
positive_roi_class_ids = tf.cast( tf.gather(target_class_ids, positive_roi_ix), tf.int64)
print(positive_roi_class_ids.eval())
indices                = tf.stack([positive_roi_ix, positive_roi_class_ids], axis=1)
print(indices.eval())


target_bbox = tf.gather(target_bbox, positive_roi_ix)
print(target_bbox.eval())
pred_bbox   = tf.gather_nd(pred_bbox, indices)
print(pred_bbox.eval())

print('tf.size ',tf.size(target_bbox).eval())

diff = K.abs(target_bbox - pred_bbox)
print(diff.eval())

less_than_one = K.cast(K.less(diff, 1.0), "float32")
# print(less_than_one.eval())

loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
# print( (1-less_than_one).eval())



# loss        = K.switch(tf.size(target_bbox) > 0,
#                 smooth_l1_loss(y_true=target_bbox, y_pred=pred_bbox),
#                 tf.constant(0.0))
print(loss.eval())
sumloss = K.sum(loss)
print(sumloss.eval())
print((sumloss/40).eval())
meanloss        = K.mean(loss)
print(meanloss.eval())

# %% [markdown]
# ###  Calculate mrcnn_class_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids = layers_out[1][0:1]
pred_class_logits = layers_out[8][0:1]
active_class_ids    = np.array([1,1,1,1])

# mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids

print(' target_class_ids', target_class_ids.shape)
print(target_class_ids)  # tgt_class_ids
print(' class logits', pred_class_logits.shape)
print(pred_class_logits)
print(' active, class_ids ', active_class_ids.shape)
print(active_class_ids)  # tgt_bounding boxes

pred_class_ids = tf.argmax(pred_class_logits, axis=2)
print(pred_class_ids.eval())  #mrcnn_bboxes
mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids
print(mrcnn_class_ids)
# pred_bbox = mrcnn_bbox
pred_active = tf.to_float(tf.gather(active_class_ids, pred_class_ids))
print(pred_active.eval())
# calc mrcnn_bbox_loss
loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
       labels=target_class_ids, logits=pred_class_logits)
print(loss.eval())

loss = loss * tf.to_float(pred_active)
print(loss.eval())

print(tf.reduce_sum(loss).eval())
print(tf.reduce_sum(pred_active).eval())
loss = tf.reduce_sum(loss) / tf.reduce_sum(pred_active)
print(loss.eval())

# %% [markdown]
# ###  Calculate mrcnn_mask_loss

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss

target_class_ids    = layers_out[1][0:3]
target_masks        = layers_out[3][0:3]
pred_masks          = layers_out[11][0:3]
# mrcnn_class_ids  = np.argmax(layers_out[9][0:1],axis = -1)     # mrcnn_class_ids
print('    target_class_ids shape :', target_class_ids.shape)
print('    target_masks     shape :', target_masks.shape)
print('    pred_masks       shape :', pred_masks.shape)    


target_class_ids = K.reshape(target_class_ids, (-1,))
print('    target_class_ids shape :', target_class_ids.shape, '\n', target_class_ids.eval())

mask_shape       = tf.shape(target_masks)
print('    mask_shape       shape :', mask_shape.shape, mask_shape.eval())    

target_masks     = K.reshape(target_masks, (-1, mask_shape[2], mask_shape[3]))
print('    target_masks     shape :', tf.shape(target_masks).eval())        

pred_shape       = tf.shape(pred_masks)
print('    pred_shape       shape :', pred_shape.shape, pred_shape.eval())        

pred_masks       = K.reshape(pred_masks, (-1, pred_shape[2], pred_shape[3], pred_shape[4]))
print('    pred_masks       shape :', tf.shape(pred_masks).eval())        


pred_masks = tf.transpose(pred_masks, [0, 3, 1, 2])
print('    pred_masks       shape :', tf.shape(pred_masks).eval())        

# Only positive ROIs contribute to the loss. And only
# the class specific mask of each ROI.
positive_ix        = tf.where(target_class_ids > 0)[:, 0]
positive_class_ids = tf.cast(tf.gather(target_class_ids, positive_ix), tf.int64)
indices            = tf.stack([positive_ix, positive_class_ids], axis=1)
print(indices.eval())



y_true = tf.gather(target_masks, positive_ix)
print('     y_true shape:', tf.shape(y_true).eval())
y_pred = tf.gather_nd(pred_masks, indices)
print('     y_pred shape:', tf.shape(y_pred).eval())

loss = K.switch(tf.size(y_true) > 0,
                K.binary_crossentropy(target=y_true, output=y_pred),
                tf.constant(0.0))
print(tf.shape(loss).eval())

loss = K.mean(loss)
print('     final loss shape:', tf.shape(loss).eval())
print(loss.eval())
loss = K.reshape(loss, [1, 1])
print('     final loss shape:', tf.shape(loss).eval())
print(loss.eval())

# %% [markdown]
# ### Calculate a pixel loss on fcn_gaussian and gt_gaussian

# %%
import keras.backend as K

from mrcnn.utils import apply_box_deltas
from mrcnn.loss  import smooth_l1_loss
pred_masks          = layers_out[12][0:3]
target_masks        = layers_out[27][0:3]

print('    target_masks     shape :', tf.shape(target_masks).eval())
print('    pred_masks       shape :', tf.shape(pred_masks).eval())    

diff = K.abs(target_masks - pred_masks)
print(tf.shape(diff).eval())

less_than_one = K.cast(K.less(diff, 1.0), "float32")
print(tf.shape(less_than_one).eval())

loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
print(tf.shape(loss).eval())

# print( (1-less_than_one).eval())

# loss = K.switch(tf.size(y_true) > 0,
#                 K.binary_crossentropy(target=y_true, output=y_pred),
#                 tf.constant(0.0))
meanloss = K.mean(loss)
print(tf.shape(meanloss).eval())
print(meanloss.eval())
# loss = K.reshape(loss, [1, 1])
# print('     final loss shape:', loss.get_shape())
# return loss


mask_shape       = tf.shape(target_masks)
print('    mask_shape       shape :', tf.shape(mask_shape).eval())    

target_masks     = K.reshape(target_masks, (-1, mask_shape[1], mask_shape[2]))
print('    target_masks     shape :', tf.shape(target_masks).eval())        

pred_shape       = tf.shape(pred_masks)
print('    pred_shape       shape :', tf.shape(pred_shape).eval())        

pred_masks       = K.reshape(pred_masks, (-1, pred_shape[1], pred_shape[2]))
print('    pred_masks       shape :', tf.shape(pred_masks).eval())
# Permute predicted masks to [N, num_classes, height, width]
# diff = K.abs(target_masks - pred_masks)
# print(tf.shape(diff).eval())

# less_than_one = K.cast(K.less(diff, 1.0), "float32")
# print(tf.shape(less_than_one).eval())

# loss = (less_than_one * 0.5 * diff**2) + (1 - less_than_one) * (diff - 0.5)
# print(tf.shape(loss).eval())

# meanloss = K.mean(loss)
# print(tf.shape(meanloss).eval())
# print(meanloss.eval())

loss = K.switch(tf.size(target_masks) > 0,
                smooth_l1_loss(y_true=target_masks, y_pred=pred_masks),
                tf.constant(0.0))
loss = K.mean(loss)
loss = K.reshape(loss, [1, 1])
print('     final loss shape:', loss.get_shape())
print(loss.eval())

# %% [markdown]
# ###  Mean values of GT, Pred, and FCN heatmaps

# %%
pred_masks = tf.identity(layers_out[24])
gt_masks = tf.identity(layers_out[27])
fcn_masks = tf.identity(layers_out[12])
print(gt_masks.shape, fcn_masks.shape)
for img in range(5):
    for cls in range(4):
        gt_mean = K.mean(gt_masks[img,:,:,cls])
        fcn_mean= K.mean(fcn_masks[img,:,:,cls])
        pred_mean= K.mean(pred_masks[img,:,:,cls])
        print('Img/Cls: ', img, '/', cls,'    gtmean: ', gt_mean.eval(), '\t fcn : ' , fcn_mean.eval(), '\t pred :', pred_mean.eval())

# %%
img  = 0
class_probs = layers_out[9][img]   # mrcnn_class
deltas      = layers_out[10][img]       # mrcnn_bbox

print(class_probs.shape)
print('class probabilities')
print(class_probs)
class_ids = np.argmax(layers_out[9][img],axis = 1)     # mrcnn_class_ids
print(' class with max probability')
print(class_ids)


# layers_out[10][2,0,3]
print('deltas.shape :', deltas.shape)
print(deltas[0:4])

deltas_specific = deltas[np.arange(32),class_ids]
print('deltas of max prob class: ', deltas_specific.shape)
print(deltas_specific[0:5])
output_rois = layers_out[0][img]*[128,128,128,128]
print('output_rois: ', output_rois.shape)
print(output_rois[0:])

refined_rois    = apply_box_deltas(output_rois, deltas_specific * config.BBOX_STD_DEV)
print('refined rois: ',refined_rois.shape)
print(refined_rois)
